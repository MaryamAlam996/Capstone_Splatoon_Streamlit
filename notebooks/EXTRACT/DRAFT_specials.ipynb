# %%
from etl.extract.extract_inkipedia import extract_inkipedia
df_weapons = extract_inkipedia()
display(df_weapons)
# Out:
#     Extra_space                     Name    ID           Sub          Special  \
# 0                        Sploosh-o-matic     0  Curling Bomb      Ultra Stamp
# 1                    Neo Sploosh-o-matic     1  Squid Beakon  Killer Wail 5.1
# 2                       Splattershot Jr.    10    Splat Bomb      Big Bubbler
# 3                Custom Splattershot Jr.    11       Torpedo     Wave Breaker
# 4                         Splash-o-matic    20    Burst Bomb        Crab Tank
# ..          ...                      ...   ...           ...              ...
# 138               Order Splatana Replica  8005    Burst Bomb        Zipcaster
# 139                       Splatana Wiper  8010       Torpedo      Ultra Stamp
# 140                  Splatana Wiper Deco  8011  Squid Beakon   Tenta Missiles
# 141                     Mint Decavitator  8020  Suction Bomb      Big Bubbler
# 142                 Charcoal Decavitator  8021   Splash Wall           Inkjet
#
#     Special_Points Level Price     Class                         Introduced
# 0             180p     9     1   Shooter  Version1.0.0(Drizzle Season 2022)
# 1             170p    13     1   Shooter    Version3.0.0(Fresh Season 2023)
# 2             180p     1         Shooter  Version1.0.0(Drizzle Season 2022)
# 3             190p     6     1   Shooter    Version2.0.0(Chill Season 2022)
# 4             200p    16     1   Shooter  Version1.0.0(Drizzle Season 2022)
# ..             ...   ...   ...       ...                                ...
# 138           210p     1        Splatana           Version7.0.0(Side Order)
# 139           190p     5     1  Splatana  Version1.0.0(Drizzle Season 2022)
# 140           190p    10     1  Splatana   Version4.0.0(Sizzle Season 2023)
# 141           210p    21     1  Splatana   Version8.0.0(Sizzle Season 2024)
# 142           200p    25     1  Splatana   Version8.0.0(Sizzle Season 2024)
#
# [143 rows x 10 columns]

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from etl.extract.url_request import make_request


SPECIALS_GALLERY_PATH = (
    'https://splatoonwiki.org/wiki/Category:Splatoon_3_special_weapon_icons'
)

# obtain a series of distinct special weapons
special_weapons = df_weapons['Special'].unique()
# create a dataframe of distinct special weapons
special_weapons_df = pd.DataFrame(special_weapons, columns=['Special'])

display(special_weapons_df)

soup = BeautifulSoup(make_request(SPECIALS_GALLERY_PATH).text, "html.parser")

images = soup.find_all('img')

image_urls = []

for img in images:
    src = img.get('src')
    if src and 'Special' in src and 'Rainmaker' not in src:   
        if 'Splashdown' not in src:
            image_urls.append('https:' + src)
        elif 'Triple' in src:
            image_urls.append('https:' + src)

image_urls


len(image_urls)
# Out:
#                  Special
# 0            Ultra Stamp
# 1        Killer Wail 5.1
# 2            Big Bubbler
# 3           Wave Breaker
# 4              Crab Tank
# 5       Triple Inkstrike
# 6             Reefslider
# 7            Booyah Bomb
# 8               Trizooka
# 9   Splattercolor Screen
# 10           Tacticooler
# 11           Super Chump
# 12               Ink Vac
# 13         Kraken Royale
# 14             Ink Storm
# 15                Inkjet
# 16             Zipcaster
# 17     Triple Splashdown
# 18        Tenta Missiles
# 19

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from etl.extract.url_request import make_request


SPECIALS_GALLERY_PATH = (
    'https://splatoonwiki.org/wiki/Category:Splatoon_3_special_weapon_icons'
)


# function to extract all special weapon images
# from inkipedia as a dataframe
def extract_specials_images(df_weapons):
    print("\nCreating a dataframe of special weapon images...")
    # first call a function that returns all possible special weapons
    # as a dataframe
    special_weapons_df = find_special_names(df_weapons)
    # find all image urls for special images
    image_urls = find_all_special_images()
    # add these to the original specials dataframe
    special_weapons_df = create_special_df(special_weapons_df, image_urls)
    print("Done! " + str(special_weapons_df.shape[0]) + "/19 images found")
    # check the length
    if special_weapons_df.shape[0] == 19:
        # return the completed abilities dataframe
        return special_weapons_df
    else:
        raise Exception(
            "Error: Special weapons data frame only has " +
            str(special_weapons_df.shape[0]) +
            " Specials, some are missing"
        )


# function to find all possible special weapons
def find_special_names(df_weapons):
    # obtain a series of distinct special weapons
    special_weapons = df_weapons['Special'].unique()
    # create a dataframe of distinct special weapons
    special_weapons_df = pd.DataFrame(special_weapons, columns=['Special'])
    
    # return this dataframe of special weapons
    return special_weapons_df


# function to find all special weapon images
def find_all_special_images():
    # make request to the site
    soup = BeautifulSoup(make_request(SPECIALS_GALLERY_PATH).text, "html.parser")
    # obtain all images
    images = soup.find_all('img')
    image_urls = []  # to store urls
    # loop through images on the page
    for img in images:
        # call a function to add the image url to the list
        image_urls = find_special_image(img, image_urls)
    # return the complete list
    return image_urls

# function to check if the image is a special
# if so add to the list or urls
def find_special_image(img, image_urls):
    src = img.get('src')
    if src and 'Special' in src and 'Rainmaker' not in src:   
        if 'Splashdown' not in src:
            image_urls.append('https:' + src)
        elif 'Triple' in src:
            image_urls.append('https:' + src)
    return image_urls


# function to use both the list of images
# and dataframe of weapon names
# to create a complete dataframe of ability images
def create_special_df(special_weapons_df, image_urls):
    # first order the specials alphabetically
    special_weapons_df = special_weapons_df.sort_values(by='Special')
    # reset the index again
    special_weapons_df.reset_index(drop=True, inplace=True)
    # --- Assistance from ChatGPT ---------------------------------------
    # order the specials
    image_urls = sorted(image_urls, key=lambda img: img.split('/')[-1])
    # -------------------------------------------------------------------
    # add a new column called Image URL
    # add the urls here
    special_weapons_df['Image URL'] = image_urls
    # return the complete dataframe
    return special_weapons_df

# %%
extract_specials_images(df_weapons)
# Out:
# Creating a dataframe of special weapon images...
# Done! 19/19 images found
#                  Special                                          Image URL
# 0            Big Bubbler  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 1            Booyah Bomb  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 2              Crab Tank  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 3              Ink Storm  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 4                Ink Vac  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 5                 Inkjet  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 6        Killer Wail 5.1  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 7          Kraken Royale  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 8             Reefslider  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 9   Splattercolor Screen  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 10           Super Chump  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 11           Tacticooler  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 12        Tenta Missiles  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 13      Triple Inkstrike  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 14     Triple Splashdown  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 15              Trizooka  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 16           Ultra Stamp  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 17          Wave Breaker  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 18             Zipcaster  https://cdn.wikimg.net/en/splatoonwiki/images/...

# %% [markdown]
# # Complete with functions

# %%
from bs4 import BeautifulSoup
import pandas as pd
from etl.extract.url_request import make_request
import time

SPECIALS_GALLERY_PATH = (
    'https://splatoonwiki.org/wiki/Category:Splatoon_3_special_weapon_icons'
)


# function to extract all special weapon images
# from inkipedia as a dataframe
def extract_specials_images(df_weapons):
    print("\nCreating a dataframe of special weapon images...")
    # first call a function that returns all possible special weapons
    # as a dataframe
    special_weapons_df = find_special_names(df_weapons)
    # find all image urls for special images
    image_urls = find_all_special_images()
    # add these to the original specials dataframe
    special_weapons_df = create_special_df(special_weapons_df, image_urls)
    print("Done! " + str(special_weapons_df.shape[0]) + "/19 images found")
    # check the length
    if special_weapons_df.shape[0] == 19:
        # return the completed abilities dataframe
        return special_weapons_df
    else:
        raise Exception(
            "Error: Special weapons data frame only has " +
            str(special_weapons_df.shape[0]) +
            " Specials, some are missing"
        )


# function to find all possible special weapons
def find_special_names(df_weapons):
    # obtain a series of distinct special weapons
    special_weapons = df_weapons['Special'].unique()
    # create a dataframe of distinct special weapons
    special_weapons_df = pd.DataFrame(special_weapons, columns=['Special'])
    # return this dataframe of special weapons
    return special_weapons_df


# function to find all special weapon images
def find_all_special_images():
    # make request to the site
    soup = BeautifulSoup(
        make_request(SPECIALS_GALLERY_PATH).text, "html.parser"
        )
    # obtain all images
    images = soup.find_all('img')
    image_urls = []  # to store urls
    # pause
    time.sleep(1)
    # loop through images on the page
    for img in images:
        # pause
        time.sleep(0.05)
        # call a function to add the image url to the list
        image_urls = find_special_image(img, image_urls)
    # return the complete list
    return image_urls


# function to check if the image is a special
# if so add to the list or urls
def find_special_image(img, image_urls):
    src = img.get('src')
    if src and 'Special' in src and 'Rainmaker' not in src:
        if 'Splashdown' not in src:
            image_urls.append('https:' + src)
        elif 'Triple' in src:
            image_urls.append('https:' + src)
    return image_urls


# function to use both the list of images
# and dataframe of weapon names
# to create a complete dataframe of ability images
def create_special_df(special_weapons_df, image_urls):
    # first order the specials alphabetically
    special_weapons_df = special_weapons_df.sort_values(by='Special')
    # reset the index again
    special_weapons_df.reset_index(drop=True, inplace=True)
    # --- Assistance from ChatGPT ---------------------------------------
    # order the specials
    image_urls = sorted(image_urls, key=lambda img: img.split('/')[-1])
    # -------------------------------------------------------------------
    # add a new column called Image URL
    # add the urls here
    special_weapons_df['Image URL'] = image_urls
    # return the complete dataframe
    return special_weapons_df

# %% [markdown]
# <img height="32" src="//cdn.wikimg.net/en/splatoonwiki/images/7/7f/Site-wordmark.svg" width="152"/>

# %% [markdown]
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/e/ef/S3_Weapon_Special_Big_Bubbler.png/120px-S3_Weapon_Special_Big_Bubbler.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/e/ef/S3_Weapon_Special_Big_Bubbler.png 1.5x" width="120"/>

# %% [markdown]
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/2/23/S3_Weapon_Special_Splashdown.png/120px-S3_Weapon_Special_Splashdown.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/2/23/S3_Weapon_Special_Splashdown.png 1.5x" width="120"/>

# %% [markdown]
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/b/b8/S3_Weapon_Special_Rainmaker.png/120px-S3_Weapon_Special_Rainmaker.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/b/b8/S3_Weapon_Special_Rainmaker.png 1.5x" width="120"/>

# %% [markdown]
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/b/b3/S3_Weapon_Special_Triple_Splashdown.png/120px-S3_Weapon_Special_Triple_Splashdown.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/b/b3/S3_Weapon_Special_Triple_Splashdown.png 1.5x" width="120"/>

# %%
extract_specials_images(df_weapons)
# Out:
# Creating a dataframe of special weapon images...
#
# hello
#
# <img height="32" src="//cdn.wikimg.net/en/splatoonwiki/images/7/7f/Site-wordmark.svg" width="152"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/e/ef/S3_Weapon_Special_Big_Bubbler.png/120px-S3_Weapon_Special_Big_Bubbler.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/e/ef/S3_Weapon_Special_Big_Bubbler.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/0/00/S3_Weapon_Special_Booyah_Bomb.png/120px-S3_Weapon_Special_Booyah_Bomb.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/0/00/S3_Weapon_Special_Booyah_Bomb.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/8/88/S3_Weapon_Special_Crab_Tank.png/120px-S3_Weapon_Special_Crab_Tank.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/8/88/S3_Weapon_Special_Crab_Tank.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/6/69/S3_Weapon_Special_Ink_Storm.png/120px-S3_Weapon_Special_Ink_Storm.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/6/69/S3_Weapon_Special_Ink_Storm.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/c/cf/S3_Weapon_Special_Ink_Vac.png/120px-S3_Weapon_Special_Ink_Vac.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/c/cf/S3_Weapon_Special_Ink_Vac.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/8/80/S3_Weapon_Special_Inkjet.png/120px-S3_Weapon_Special_Inkjet.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/8/80/S3_Weapon_Special_Inkjet.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/1/1a/S3_Weapon_Special_Killer_Wail_5.1.png/120px-S3_Weapon_Special_Killer_Wail_5.1.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/1/1a/S3_Weapon_Special_Killer_Wail_5.1.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/c/c1/S3_Weapon_Special_Kraken_Royale.png/120px-S3_Weapon_Special_Kraken_Royale.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/c/c1/S3_Weapon_Special_Kraken_Royale.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/2/27/S3_Weapon_Special_Rainmaker_Flat.png/120px-S3_Weapon_Special_Rainmaker_Flat.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/thumb/2/27/S3_Weapon_Special_Rainmaker_Flat.png/180px-S3_Weapon_Special_Rainmaker_Flat.png 1.5x, //cdn.wikimg.net/en/splatoonwiki/images/thumb/2/27/S3_Weapon_Special_Rainmaker_Flat.png/240px-S3_Weapon_Special_Rainmaker_Flat.png 2x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/b/b8/S3_Weapon_Special_Rainmaker.png/120px-S3_Weapon_Special_Rainmaker.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/b/b8/S3_Weapon_Special_Rainmaker.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/1/10/S3_Weapon_Special_Reefslider.png/120px-S3_Weapon_Special_Reefslider.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/1/10/S3_Weapon_Special_Reefslider.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/2/23/S3_Weapon_Special_Splashdown.png/120px-S3_Weapon_Special_Splashdown.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/2/23/S3_Weapon_Special_Splashdown.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/5/5c/S3_Weapon_Special_Splattercolor_Screen.png/120px-S3_Weapon_Special_Splattercolor_Screen.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/5/5c/S3_Weapon_Special_Splattercolor_Screen.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/8/8c/S3_Weapon_Special_Super_Chump.png/120px-S3_Weapon_Special_Super_Chump.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/8/8c/S3_Weapon_Special_Super_Chump.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/c/c0/S3_Weapon_Special_Tacticooler.png/120px-S3_Weapon_Special_Tacticooler.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/c/c0/S3_Weapon_Special_Tacticooler.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/3/3b/S3_Weapon_Special_Tenta_Missiles.png/120px-S3_Weapon_Special_Tenta_Missiles.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/3/3b/S3_Weapon_Special_Tenta_Missiles.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/3/3a/S3_Weapon_Special_Triple_Inkstrike.png/120px-S3_Weapon_Special_Triple_Inkstrike.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/3/3a/S3_Weapon_Special_Triple_Inkstrike.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/b/b3/S3_Weapon_Special_Triple_Splashdown.png/120px-S3_Weapon_Special_Triple_Splashdown.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/b/b3/S3_Weapon_Special_Triple_Splashdown.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/9/93/S3_Weapon_Special_Trizooka.png/120px-S3_Weapon_Special_Trizooka.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/9/93/S3_Weapon_Special_Trizooka.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/7/70/S3_Weapon_Special_Ultra_Stamp.png/120px-S3_Weapon_Special_Ultra_Stamp.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/7/70/S3_Weapon_Special_Ultra_Stamp.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/6/67/S3_Weapon_Special_Wave_Breaker.png/120px-S3_Weapon_Special_Wave_Breaker.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/6/67/S3_Weapon_Special_Wave_Breaker.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/9/96/S3_Weapon_Special_Zipcaster.png/120px-S3_Weapon_Special_Zipcaster.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/9/96/S3_Weapon_Special_Zipcaster.png 1.5x" width="120"/>
#
# hello
#
# <img src="//cdn.wikimg.net/en/splatoonwiki/images/e/ea/Site-wiki.svg"/>
#
# hello
#
# <img alt="Creative Commons Attribution-ShareAlike 4.0" height="31" loading="lazy" src="/w/resources/assets/licenses/cc-by-sa.png" width="88"/>
#
# hello
#
# <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/w/resources/assets/poweredby_mediawiki_88x31.png" srcset="/w/resources/assets/poweredby_mediawiki_132x47.png 1.5x, /w/resources/assets/poweredby_mediawiki_176x62.png 2x" width="88"/>
#
# hello
#
# <img alt="Powered by StrategyWiki" height="31" loading="lazy" src="https://cdn.wikimg.net/en/strategywiki/images/e/e5/Powered_by_StrategyWiki_Button.png" srcset="https://cdn.wikimg.net/en/strategywiki/images/f/f0/Powered_by_StrategyWiki_Button2x.png 2x" width="88"/>
# Done! 19/19 images found
#                  Special                                          Image URL
# 0            Big Bubbler  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 1            Booyah Bomb  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 2              Crab Tank  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 3              Ink Storm  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 4                Ink Vac  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 5                 Inkjet  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 6        Killer Wail 5.1  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 7          Kraken Royale  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 8             Reefslider  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 9   Splattercolor Screen  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 10           Super Chump  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 11           Tacticooler  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 12        Tenta Missiles  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 13      Triple Inkstrike  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 14     Triple Splashdown  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 15              Trizooka  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 16           Ultra Stamp  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 17          Wave Breaker  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 18             Zipcaster  https://cdn.wikimg.net/en/splatoonwiki/images/...
