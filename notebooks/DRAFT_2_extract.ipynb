# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"


# function that returns the data extracted from sendou as a data frame


def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    print(path_list)
    print(weapon_list)
    # call function returns the dataframe
    df_builds = create_weapon_build_df(path_list, weapon_list)
    display(df_builds)
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        path, weapon_name = search_for_build_path(link)
        paths = add_to_list(paths, path)
        weapon_names = add_to_list(weapon_names, weapon_name)
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    # define dataframe columns
    df_columns = ['Weapon_name',
    'Main_1', 'Sub_1', 'Sub_2', 'Sub_3',
    'Main_2', 'Sub_4', 'Sub_5', 'Sub_6',
    'Main_3', 'Sub_7', 'Sub_8', 'Sub_9',
    'game_modes']
    
    # Create and empty data frame from the columns
    df_weapon_builds = pd.DataFrame(columns = df_columns) 
    
    count = 0 # counter for what weapon builds page we are currently on
    # repeat for each weapon path
    for path in path_list:
        # pause for each path
        time.sleep(1) 
        
        # if count  > 10:
        #      break
         
        path_soup = BeautifulSoup(make_request(path + '?limit=500').text, "html.parser")
        # message to show what weapon we are currently obtaining info from
        print("Scraping builds for: " + weapon_list[count])
        
        build_entries = path_soup.find_all('div',  class_='build')
    
        for build in build_entries:
            
            abilities = build.find_all('div', class_="build__ability readonly")
            ability_list = []
            
            for a in abilities:
                img_tag = a.find('img')
                alt_text = img_tag['alt']          
        
                ability_list.append((alt_text))
                       
            mode_list = []
            modes = build.find('div', class_='build__modes')
        
            if modes is None:
                mode_list = ['NO MODES LISTED']

            elif modes is not None:
                    
                img_tags = modes.find_all('img')

                for i in img_tags:
                    alt_text = i['alt']
                    mode_list.append(alt_text)
            
            df_weapon_builds.loc[len(df_weapon_builds)] = [weapon_list[count]] + ability_list + [mode_list]
        
        
        count += 1
    return df_weapon_builds

# function to scrape all builds for a single weapon:
def scrape_all_builds(path_soup):
    return None


# function to look at a single build and returns its info
def scrape_a_build():
    return None
    


# function to extract game mode info from a build
def extract_modes():
    return None

# function to extract ability info from a build
def extract_abilities():
    return None

# %%
extract_sendou_data()
# Out:
# ['https://sendou.ink/builds/52-gal', 'https://sendou.ink/builds/52-gal-deco', 'https://sendou.ink/builds/96-gal', 'https://sendou.ink/builds/96-gal-deco', 'https://sendou.ink/builds/aerospray-mg', 'https://sendou.ink/builds/aerospray-rg', 'https://sendou.ink/builds/annaki-splattershot-nova', 'https://sendou.ink/builds/custom-jet-squelcher', 'https://sendou.ink/builds/custom-splattershot-jr', 'https://sendou.ink/builds/foil-squeezer', 'https://sendou.ink/builds/forge-splattershot-pro', 'https://sendou.ink/builds/h-3-nozzlenose', 'https://sendou.ink/builds/h-3-nozzlenose-d', 'https://sendou.ink/builds/jet-squelcher', 'https://sendou.ink/builds/l-3-nozzlenose', 'https://sendou.ink/builds/l-3-nozzlenose-d', 'https://sendou.ink/builds/n-zap-85', 'https://sendou.ink/builds/n-zap-89', 'https://sendou.ink/builds/neo-splash-o-matic', 'https://sendou.ink/builds/neo-sploosh-o-matic', 'https://sendou.ink/builds/splash-o-matic', 'https://sendou.ink/builds/splattershot', 'https://sendou.ink/builds/splattershot-jr', 'https://sendou.ink/builds/splattershot-nova', 'https://sendou.ink/builds/splattershot-pro', 'https://sendou.ink/builds/sploosh-o-matic', 'https://sendou.ink/builds/squeezer', 'https://sendou.ink/builds/tentatek-splattershot', 'https://sendou.ink/builds/blaster', 'https://sendou.ink/builds/clash-blaster', 'https://sendou.ink/builds/clash-blaster-neo', 'https://sendou.ink/builds/custom-blaster', 'https://sendou.ink/builds/custom-range-blaster', 'https://sendou.ink/builds/luna-blaster', 'https://sendou.ink/builds/luna-blaster-neo', 'https://sendou.ink/builds/range-blaster', 'https://sendou.ink/builds/rapid-blaster', 'https://sendou.ink/builds/rapid-blaster-deco', 'https://sendou.ink/builds/rapid-blaster-pro', 'https://sendou.ink/builds/rapid-blaster-pro-deco', 'https://sendou.ink/builds/s-blast-91', 'https://sendou.ink/builds/s-blast-92', 'https://sendou.ink/builds/big-swig-roller', 'https://sendou.ink/builds/big-swig-roller-express', 'https://sendou.ink/builds/carbon-roller', 'https://sendou.ink/builds/carbon-roller-deco', 'https://sendou.ink/builds/dynamo-roller', 'https://sendou.ink/builds/flingza-roller', 'https://sendou.ink/builds/foil-flingza-roller', 'https://sendou.ink/builds/gold-dynamo-roller', 'https://sendou.ink/builds/krak-on-splat-roller', 'https://sendou.ink/builds/splat-roller', 'https://sendou.ink/builds/inkbrush', 'https://sendou.ink/builds/inkbrush-nouveau', 'https://sendou.ink/builds/octobrush', 'https://sendou.ink/builds/octobrush-nouveau', 'https://sendou.ink/builds/painbrush', 'https://sendou.ink/builds/painbrush-nouveau', 'https://sendou.ink/builds/bamboozler-14-mk-i', 'https://sendou.ink/builds/bamboozler-14-mk-ii', 'https://sendou.ink/builds/classic-squiffer', 'https://sendou.ink/builds/custom-e-liter-4k', 'https://sendou.ink/builds/custom-e-liter-4k-scope', 'https://sendou.ink/builds/custom-goo-tuber', 'https://sendou.ink/builds/e-liter-4k', 'https://sendou.ink/builds/e-liter-4k-scope', 'https://sendou.ink/builds/goo-tuber', 'https://sendou.ink/builds/new-squiffer', 'https://sendou.ink/builds/snipewriter-5b', 'https://sendou.ink/builds/snipewriter-5h', 'https://sendou.ink/builds/splat-charger', 'https://sendou.ink/builds/splatterscope', 'https://sendou.ink/builds/zf-splat-charger', 'https://sendou.ink/builds/zf-splatterscope', 'https://sendou.ink/builds/bloblobber', 'https://sendou.ink/builds/bloblobber-deco', 'https://sendou.ink/builds/custom-explosher', 'https://sendou.ink/builds/dread-wringer', 'https://sendou.ink/builds/dread-wringer-d', 'https://sendou.ink/builds/explosher', 'https://sendou.ink/builds/slosher', 'https://sendou.ink/builds/slosher-deco', 'https://sendou.ink/builds/sloshing-machine', 'https://sendou.ink/builds/sloshing-machine-neo', 'https://sendou.ink/builds/tri-slosher', 'https://sendou.ink/builds/tri-slosher-nouveau', 'https://sendou.ink/builds/ballpoint-splatling', 'https://sendou.ink/builds/ballpoint-splatling-nouveau', 'https://sendou.ink/builds/custom-hydra-splatling', 'https://s ...
# ['.52 Gal', '.52 Gal Deco', '.96 Gal', '.96 Gal Deco', 'Aerospray MG', 'Aerospray RG', 'Annaki Splattershot Nova', 'Custom Jet Squelcher', 'Custom Splattershot Jr.', 'Foil Squeezer', 'Forge Splattershot Pro', 'H-3 Nozzlenose', 'H-3 Nozzlenose D', 'Jet Squelcher', 'L-3 Nozzlenose', 'L-3 Nozzlenose D', "N-ZAP '85", "N-ZAP '89", 'Neo Splash-o-matic', 'Neo Sploosh-o-matic', 'Splash-o-matic', 'Splattershot', 'Splattershot Jr.', 'Splattershot Nova', 'Splattershot Pro', 'Sploosh-o-matic', 'Squeezer', 'Tentatek Splattershot', 'Blaster', 'Clash Blaster', 'Clash Blaster Neo', 'Custom Blaster', 'Custom Range Blaster', 'Luna Blaster', 'Luna Blaster Neo', 'Range Blaster', 'Rapid Blaster', 'Rapid Blaster Deco', 'Rapid Blaster Pro', 'Rapid Blaster Pro Deco', "S-BLAST '91", "S-BLAST '92", 'Big Swig Roller', 'Big Swig Roller Express', 'Carbon Roller', 'Carbon Roller Deco', 'Dynamo Roller', 'Flingza Roller', 'Foil Flingza Roller', 'Gold Dynamo Roller', 'Krak-On Splat Roller', 'Splat Roller', 'Inkbrush', 'Inkbrush Nouveau', 'Octobrush', 'Octobrush Nouveau', 'Painbrush', 'Painbrush Nouveau', 'Bamboozler 14 Mk I', 'Bamboozler 14 Mk II', 'Classic Squiffer', 'Custom E-liter 4K', 'Custom E-liter 4K Scope', 'Custom Goo Tuber', 'E-liter 4K', 'E-liter 4K Scope', 'Goo Tuber', 'New Squiffer', 'Snipewriter 5B', 'Snipewriter 5H', 'Splat Charger', 'Splatterscope', 'Z+F Splat Charger', 'Z+F Splatterscope', 'Bloblobber', 'Bloblobber Deco', 'Custom Explosher', 'Dread Wringer', 'Dread Wringer D', 'Explosher', 'Slosher', 'Slosher Deco', 'Sloshing Machine', 'Sloshing Machine Neo', 'Tri-Slosher', 'Tri-Slosher Nouveau', 'Ballpoint Splatling', 'Ballpoint Splatling Nouveau', 'Custom Hydra Splatling', 'Heavy Edit Splatling', 'Heavy Edit Splatling Nouveau', 'Heavy Splatling', 'Heavy Splatling Deco', 'Hydra Splatling', 'Mini Splatling', 'Nautilus 47', 'Nautilus 79', 'Zink Mini Splatling', 'Custom Douser Dualies FF', 'Custom Dualie Squelchers', 'Dapple Dualies', 'Dapple Dualies Nouveau', 'Dark Tetra Dualies', 'Douser Dualies FF', 'Dualie Squelchers', 'Enperry Splat Dualies', 'Glooga Dualies', 'Glooga Dualies Deco', 'Light Tetra Dualies', 'Splat Dualies', 'Recycled Brella 24 Mk I', 'Recycled Brella 24 Mk II', 'Sorella Brella', 'Splat Brella', 'Tenta Brella', 'Tenta Sorella Brella', 'Undercover Brella', 'Undercover Sorella Brella', 'Custom Wellstring V', 'Inkline Tri-Stringer', 'REEF-LUX 450', 'REEF-LUX 450 Deco', 'Tri-Stringer', 'Wellstring V', 'Charcoal Decavitator', 'Mint Decavitator', 'Splatana Stamper', 'Splatana Stamper Nouveau', 'Splatana Wiper', 'Splatana Wiper Deco']
# Scraping builds for: .52 Gal
# Scraping builds for: .52 Gal Deco
# Scraping builds for: .96 Gal
# Scraping builds for: .96 Gal Deco
# Scraping builds for: Aerospray MG
# Scraping builds for: Aerospray RG
# Scraping builds for: Annaki Splattershot Nova
# Scraping builds for: Custom Jet Squelcher
# Scraping builds for: Custom Splattershot Jr.
# Scraping builds for: Foil Squeezer
# Scraping builds for: Forge Splattershot Pro
# Scraping builds for: H-3 Nozzlenose
# Scraping builds for: H-3 Nozzlenose D
# Scraping builds for: Jet Squelcher
# Scraping builds for: L-3 Nozzlenose
# Scraping builds for: L-3 Nozzlenose D
# Scraping builds for: N-ZAP '85
# Scraping builds for: N-ZAP '89
# Scraping builds for: Neo Splash-o-matic
# Scraping builds for: Neo Sploosh-o-matic
# Scraping builds for: Splash-o-matic
# Scraping builds for: Splattershot
# Scraping builds for: Splattershot Jr.
# Scraping builds for: Splattershot Nova
# Scraping builds for: Splattershot Pro
# Scraping builds for: Sploosh-o-matic
# Scraping builds for: Squeezer
# Scraping builds for: Tentatek Splattershot
# Scraping builds for: Blaster
# Scraping builds for: Clash Blaster
# Scraping builds for: Clash Blaster Neo
# Scraping builds for: Custom Blaster
# Scraping builds for: Custom Range Blaster
# Scraping builds for: Luna Blaster
# Scraping builds for: Luna Blaster Neo
# Scraping builds for: Range Blaster
# Scraping builds for: Rapid Blaster
# Scraping builds for: Rapid Blaster Deco
# Scraping builds for: Rapid Blaster Pro
# Scraping builds for: Rapid Blaster Pro Deco
# Scraping builds for: S-BLAST '91
# Scraping builds for: S-BLAST '92
# Scraping builds for: Big Swig Roller
# Scraping builds for: Big Swig Roller Express
# Scraping builds for: Carbon Roller
# Scraping builds for: Carbon Roller Deco
# Scraping builds for: Dynamo Roller
# Scraping builds for: Flingza Roller
# Scraping builds for: Foil Flingza Roller
# Scraping builds for: Gold Dynamo Roller
# Scraping builds for: Krak-On Splat Roller
# Scraping builds for: Splat Roller
# Scraping builds for: Inkbrush
# Scraping builds for: Inkbrush Nouveau
# Scraping builds for: Octobrush
# Scraping builds for: Octobrush Nouveau
# Scraping builds for: Painbrush
# Scraping builds for: Painbrush Nouveau
# Scraping builds for: Bamboozler 14 Mk I
# Scraping builds for: Bamboozler 14 Mk II
# Scraping builds for: Classic Squiffer
# Scraping builds for: Custom E-liter 4K
# Scraping builds for: Custom E-liter 4K Scope
# Scraping builds for: Custom Goo Tuber
# Scraping builds for: E-liter 4K
# Scraping builds for: E-liter 4K Scope
# Scraping builds for: Goo Tuber
# Scraping builds for: New Squiffer
# Scraping builds for: Snipewriter 5B
# Scraping builds for: Snipewriter 5H
# Scraping builds for: Splat Charger
# Scraping builds for: Splatterscope
# Scraping builds for: Z+F Splat Charger
# Scraping builds for: Z+F Splatterscope
# Scraping builds for: Bloblobber
# Scraping builds for: Bloblobber Deco
# Scraping builds for: Custom Explosher
# Scraping builds for: Dread Wringer
# Scraping builds for: Dread Wringer D
# Scraping builds for: Explosher
# Scraping builds for: Slosher
# Scraping builds for: Slosher Deco
# Scraping builds for: Sloshing Machine
# Scraping builds for: Sloshing Machine Neo
# Scraping builds for: Tri-Slosher
# Scraping builds for: Tri-Slosher Nouveau
# Scraping builds for: Ballpoint Splatling
# Scraping builds for: Ballpoint Splatling Nouveau
# Scraping builds for: Custom Hydra Splatling
# Scraping builds for: Heavy Edit Splatling
# Scraping builds for: Heavy Edit Splatling Nouveau
# Scraping builds for: Heavy Splatling
# Scraping builds for: Heavy Splatling Deco
# Scraping builds for: Hydra Splatling
# Scraping builds for: Mini Splatling
# Scraping builds for: Nautilus 47
# Scraping builds for: Nautilus 79
# Scraping builds for: Zink Mini Splatling
# Scraping builds for: Custom Douser Dualies FF
# Scraping builds for: Custom Dualie Squelchers
# Scraping builds for: Dapple Dualies
# Scraping builds for: Dapple Dualies Nouveau
# Scraping builds for: Dark Tetra Dualies
# Scraping builds for: Douser Dualies FF
# Scraping builds for: Dualie Squelchers
# Scraping builds for: Enperry Splat Dualies
# Scraping builds for: Glooga Dualies
# Scraping builds for: Glooga Dualies Deco
# Scraping builds for: Light Tetra Dualies
# Scraping builds for: Splat Dualies
# Scraping builds for: Recycled Brella 24 Mk I
# Scraping builds for: Recycled Brella 24 Mk II
# Scraping builds for: Sorella Brella
# Scraping builds for: Splat Brella
# Scraping builds for: Tenta Brella
# Scraping builds for: Tenta Sorella Brella
# Scraping builds for: Undercover Brella
# Scraping builds for: Undercover Sorella Brella
# Scraping builds for: Custom Wellstring V
# Scraping builds for: Inkline Tri-Stringer
# Scraping builds for: REEF-LUX 450
# Scraping builds for: REEF-LUX 450 Deco
# Scraping builds for: Tri-Stringer
# Scraping builds for: Wellstring V
# Scraping builds for: Charcoal Decavitator
# Scraping builds for: Mint Decavitator
# Scraping builds for: Splatana Stamper
# Scraping builds for: Splatana Stamper Nouveau
# Scraping builds for: Splatana Wiper
# Scraping builds for: Splatana Wiper Deco
#                Weapon_name          Main_1              Sub_1  \
# 0                  .52 Gal  Opening Gambit   Intensify Action
# 1                  .52 Gal        Comeback   Intensify Action
# 2                  .52 Gal   Swim Speed Up   Intensify Action
# 3                  .52 Gal        Comeback   Intensify Action
# 4                  .52 Gal  Opening Gambit   Intensify Action
# ...                    ...             ...                ...
# 30300  Splatana Wiper Deco    Sub Power Up    Ink Saver (Sub)
# 30301  Splatana Wiper Deco        Comeback      Quick Respawn
# 30302  Splatana Wiper Deco        Comeback      Quick Respawn
# 30303  Splatana Wiper Deco    Sub Power Up       Sub Power Up
# 30304  Splatana Wiper Deco        Comeback  Special Charge Up
#
#                    Sub_2              Sub_3         Main_2              Sub_4  \
# 0       Intensify Action   Intensify Action  Swim Speed Up      Swim Speed Up
# 1       Intensify Action   Intensify Action  Swim Speed Up      Swim Speed Up
# 2       Intensify Action   Intensify Action  Swim Speed Up    Ink Recovery Up
# 3       Intensify Action   Intensify Action  Swim Speed Up      Swim Speed Up
# 4       Intensify Action   Intensify Action  Swim Speed Up      Swim Speed Up
# ...                  ...                ...            ...                ...
# 30300    Ink Saver (Sub)    Ink Saver (Sub)  Swim Speed Up      Swim Speed Up
# 30301      Quick Respawn      Quick Respawn          Haunt      Swim Speed Up
# 30302      Quick Respawn      Quick Respawn   Sub Power Up  Special Charge Up
# 30303       Sub Power Up   Quick Super Jump  Swim Speed Up      Swim Speed Up
# 30304  Special Charge Up  Special Charge Up    Ninja Squid      Quick Respawn
#
#                    Sub_5              Sub_6        Main_3              Sub_7  \
# 0          Swim Speed Up  Ink Resistance Up  Stealth Jump   Quick Super Jump
# 1          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# 2          Special Saver   Quick Super Jump  Stealth Jump  Ink Resistance Up
# 3          Swim Speed Up      Swim Speed Up  Stealth Jump      Special Saver
# 4          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# ...                  ...                ...           ...                ...
# 30300  Ink Resistance Up  Sub Resistance Up  Stealth Jump   Quick Super Jump
# 30301      Swim Speed Up       Sub Power Up  Stealth Jump      Quick Respawn
# 30302  Special Charge Up  Special Charge Up  Stealth Jump      Quick Respawn
# 30303      Swim Speed Up  Special Charge Up  Stealth Jump      Quick Respawn
# 30304      Quick Respawn      Swim Speed Up  Stealth Jump      Special Saver
#
#                    Sub_8              Sub_9  \
# 0       Quick Super Jump  Sub Resistance Up
# 1      Ink Resistance Up   Intensify Action
# 2      Sub Resistance Up   Intensify Action
# 3       Quick Super Jump  Ink Resistance Up
# 4      Ink Resistance Up  Sub Resistance Up
# ...                  ...                ...
# 30300   Quick Super Jump   Quick Super Jump
# 30301      Quick Respawn       Sub Power Up
# 30302   Quick Super Jump       Sub Power Up
# 30303      Quick Respawn      Special Saver
# 30304   Quick Super Jump  Sub Resistance Up
#
#                                               game_modes
# 0      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4      [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                                                  ...
# 30300  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30301  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30302  [Turf War, Splat Zones, Tower Control, Clam Bl...
# 30303  [Turf War, Splat Zones, Tower Control, Rainmaker]
# 30304  [Splat Zones, Tower Control, Rainmaker, Clam B...
#
# [30305 rows x 14 columns]

# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"

DF_COLUMNS = ['Weapon_name',
'Main_1', 'Sub_1', 'Sub_2', 'Sub_3',
'Main_2', 'Sub_4', 'Sub_5', 'Sub_6',
'Main_3', 'Sub_7', 'Sub_8', 'Sub_9',
'game_modes']


# function that returns the data extracted from sendou as a data frame
def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    print(path_list)
    print(weapon_list)
    # call function returns the dataframe
    df_builds = create_weapon_build_df(path_list, weapon_list)
    display(df_builds)
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        path, weapon_name = search_for_build_path(link)
        paths = add_to_list(paths, path)
        weapon_names = add_to_list(weapon_names, weapon_name)
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    # define dataframe columns

    
    # Create and empty data frame from the columns
    df_all_weapon_builds = pd.DataFrame(columns = DF_COLUMNS) 
    
    count = 0 # counter for what weapon builds page we are currently on
    # repeat for each weapon path
    for path in path_list:
         
        # pause for each path
        time.sleep(1) 
        
        if count  > 10:
               break
         
        path_soup = BeautifulSoup(make_request(path + '?limit=500').text, "html.parser")

        df_weapon_builds = scrape_all_builds(path_soup, weapon_list, count)
        
        df_all_weapon_builds = pd.concat([df_all_weapon_builds, df_weapon_builds], ignore_index=True)
        count += 1
    return df_all_weapon_builds

# function to scrape all builds for a single weapon:
def scrape_all_builds(path_soup, weapon_list, count):
    df_weapon_builds = pd.DataFrame(columns = DF_COLUMNS)
    # message to show what weapon we are currently obtaining info from
    print("Scraping builds for: " + weapon_list[count])
    
    build_entries = path_soup.find_all('div',  class_='build')

    for build in build_entries:
        
        ability_list, mode_list = scrape_a_build(build)
        
        df_weapon_builds.loc[len(df_weapon_builds)] = [weapon_list[count]] + ability_list + [mode_list]    
    return df_weapon_builds


# function to look at a single build and returns its info
def scrape_a_build(build):
    
    ability_list = extract_abilities(build)
    mode_list = extract_modes(build)   


    return ability_list, mode_list
    

# function to extract game mode info from a build
def extract_modes(build):
    
    mode_list = []
    modes = build.find('div', class_='build__modes')

    if modes is None:
        mode_list = ['NO MODES LISTED']

    elif modes is not None:
            
        img_tags = modes.find_all('img')

        for i in img_tags:
            alt_text = i['alt']
            mode_list.append(alt_text)
    
    return mode_list

# function to extract ability info from a build
def extract_abilities(build):
    abilities = build.find_all('div', class_="build__ability readonly")
    ability_list = []
    
    for a in abilities:
        img_tag = a.find('img')
        alt_text = img_tag['alt']          

        ability_list.append((alt_text))
    return ability_list

# %%
extract_sendou_data()
# Out:
# ['https://sendou.ink/builds/52-gal', 'https://sendou.ink/builds/52-gal-deco', 'https://sendou.ink/builds/96-gal', 'https://sendou.ink/builds/96-gal-deco', 'https://sendou.ink/builds/aerospray-mg', 'https://sendou.ink/builds/aerospray-rg', 'https://sendou.ink/builds/annaki-splattershot-nova', 'https://sendou.ink/builds/custom-jet-squelcher', 'https://sendou.ink/builds/custom-splattershot-jr', 'https://sendou.ink/builds/foil-squeezer', 'https://sendou.ink/builds/forge-splattershot-pro', 'https://sendou.ink/builds/h-3-nozzlenose', 'https://sendou.ink/builds/h-3-nozzlenose-d', 'https://sendou.ink/builds/jet-squelcher', 'https://sendou.ink/builds/l-3-nozzlenose', 'https://sendou.ink/builds/l-3-nozzlenose-d', 'https://sendou.ink/builds/n-zap-85', 'https://sendou.ink/builds/n-zap-89', 'https://sendou.ink/builds/neo-splash-o-matic', 'https://sendou.ink/builds/neo-sploosh-o-matic', 'https://sendou.ink/builds/splash-o-matic', 'https://sendou.ink/builds/splattershot', 'https://sendou.ink/builds/splattershot-jr', 'https://sendou.ink/builds/splattershot-nova', 'https://sendou.ink/builds/splattershot-pro', 'https://sendou.ink/builds/sploosh-o-matic', 'https://sendou.ink/builds/squeezer', 'https://sendou.ink/builds/tentatek-splattershot', 'https://sendou.ink/builds/blaster', 'https://sendou.ink/builds/clash-blaster', 'https://sendou.ink/builds/clash-blaster-neo', 'https://sendou.ink/builds/custom-blaster', 'https://sendou.ink/builds/custom-range-blaster', 'https://sendou.ink/builds/luna-blaster', 'https://sendou.ink/builds/luna-blaster-neo', 'https://sendou.ink/builds/range-blaster', 'https://sendou.ink/builds/rapid-blaster', 'https://sendou.ink/builds/rapid-blaster-deco', 'https://sendou.ink/builds/rapid-blaster-pro', 'https://sendou.ink/builds/rapid-blaster-pro-deco', 'https://sendou.ink/builds/s-blast-91', 'https://sendou.ink/builds/s-blast-92', 'https://sendou.ink/builds/big-swig-roller', 'https://sendou.ink/builds/big-swig-roller-express', 'https://sendou.ink/builds/carbon-roller', 'https://sendou.ink/builds/carbon-roller-deco', 'https://sendou.ink/builds/dynamo-roller', 'https://sendou.ink/builds/flingza-roller', 'https://sendou.ink/builds/foil-flingza-roller', 'https://sendou.ink/builds/gold-dynamo-roller', 'https://sendou.ink/builds/krak-on-splat-roller', 'https://sendou.ink/builds/splat-roller', 'https://sendou.ink/builds/inkbrush', 'https://sendou.ink/builds/inkbrush-nouveau', 'https://sendou.ink/builds/octobrush', 'https://sendou.ink/builds/octobrush-nouveau', 'https://sendou.ink/builds/painbrush', 'https://sendou.ink/builds/painbrush-nouveau', 'https://sendou.ink/builds/bamboozler-14-mk-i', 'https://sendou.ink/builds/bamboozler-14-mk-ii', 'https://sendou.ink/builds/classic-squiffer', 'https://sendou.ink/builds/custom-e-liter-4k', 'https://sendou.ink/builds/custom-e-liter-4k-scope', 'https://sendou.ink/builds/custom-goo-tuber', 'https://sendou.ink/builds/e-liter-4k', 'https://sendou.ink/builds/e-liter-4k-scope', 'https://sendou.ink/builds/goo-tuber', 'https://sendou.ink/builds/new-squiffer', 'https://sendou.ink/builds/snipewriter-5b', 'https://sendou.ink/builds/snipewriter-5h', 'https://sendou.ink/builds/splat-charger', 'https://sendou.ink/builds/splatterscope', 'https://sendou.ink/builds/zf-splat-charger', 'https://sendou.ink/builds/zf-splatterscope', 'https://sendou.ink/builds/bloblobber', 'https://sendou.ink/builds/bloblobber-deco', 'https://sendou.ink/builds/custom-explosher', 'https://sendou.ink/builds/dread-wringer', 'https://sendou.ink/builds/dread-wringer-d', 'https://sendou.ink/builds/explosher', 'https://sendou.ink/builds/slosher', 'https://sendou.ink/builds/slosher-deco', 'https://sendou.ink/builds/sloshing-machine', 'https://sendou.ink/builds/sloshing-machine-neo', 'https://sendou.ink/builds/tri-slosher', 'https://sendou.ink/builds/tri-slosher-nouveau', 'https://sendou.ink/builds/ballpoint-splatling', 'https://sendou.ink/builds/ballpoint-splatling-nouveau', 'https://sendou.ink/builds/custom-hydra-splatling', 'https://s ...
# ['.52 Gal', '.52 Gal Deco', '.96 Gal', '.96 Gal Deco', 'Aerospray MG', 'Aerospray RG', 'Annaki Splattershot Nova', 'Custom Jet Squelcher', 'Custom Splattershot Jr.', 'Foil Squeezer', 'Forge Splattershot Pro', 'H-3 Nozzlenose', 'H-3 Nozzlenose D', 'Jet Squelcher', 'L-3 Nozzlenose', 'L-3 Nozzlenose D', "N-ZAP '85", "N-ZAP '89", 'Neo Splash-o-matic', 'Neo Sploosh-o-matic', 'Splash-o-matic', 'Splattershot', 'Splattershot Jr.', 'Splattershot Nova', 'Splattershot Pro', 'Sploosh-o-matic', 'Squeezer', 'Tentatek Splattershot', 'Blaster', 'Clash Blaster', 'Clash Blaster Neo', 'Custom Blaster', 'Custom Range Blaster', 'Luna Blaster', 'Luna Blaster Neo', 'Range Blaster', 'Rapid Blaster', 'Rapid Blaster Deco', 'Rapid Blaster Pro', 'Rapid Blaster Pro Deco', "S-BLAST '91", "S-BLAST '92", 'Big Swig Roller', 'Big Swig Roller Express', 'Carbon Roller', 'Carbon Roller Deco', 'Dynamo Roller', 'Flingza Roller', 'Foil Flingza Roller', 'Gold Dynamo Roller', 'Krak-On Splat Roller', 'Splat Roller', 'Inkbrush', 'Inkbrush Nouveau', 'Octobrush', 'Octobrush Nouveau', 'Painbrush', 'Painbrush Nouveau', 'Bamboozler 14 Mk I', 'Bamboozler 14 Mk II', 'Classic Squiffer', 'Custom E-liter 4K', 'Custom E-liter 4K Scope', 'Custom Goo Tuber', 'E-liter 4K', 'E-liter 4K Scope', 'Goo Tuber', 'New Squiffer', 'Snipewriter 5B', 'Snipewriter 5H', 'Splat Charger', 'Splatterscope', 'Z+F Splat Charger', 'Z+F Splatterscope', 'Bloblobber', 'Bloblobber Deco', 'Custom Explosher', 'Dread Wringer', 'Dread Wringer D', 'Explosher', 'Slosher', 'Slosher Deco', 'Sloshing Machine', 'Sloshing Machine Neo', 'Tri-Slosher', 'Tri-Slosher Nouveau', 'Ballpoint Splatling', 'Ballpoint Splatling Nouveau', 'Custom Hydra Splatling', 'Heavy Edit Splatling', 'Heavy Edit Splatling Nouveau', 'Heavy Splatling', 'Heavy Splatling Deco', 'Hydra Splatling', 'Mini Splatling', 'Nautilus 47', 'Nautilus 79', 'Zink Mini Splatling', 'Custom Douser Dualies FF', 'Custom Dualie Squelchers', 'Dapple Dualies', 'Dapple Dualies Nouveau', 'Dark Tetra Dualies', 'Douser Dualies FF', 'Dualie Squelchers', 'Enperry Splat Dualies', 'Glooga Dualies', 'Glooga Dualies Deco', 'Light Tetra Dualies', 'Splat Dualies', 'Recycled Brella 24 Mk I', 'Recycled Brella 24 Mk II', 'Sorella Brella', 'Splat Brella', 'Tenta Brella', 'Tenta Sorella Brella', 'Undercover Brella', 'Undercover Sorella Brella', 'Custom Wellstring V', 'Inkline Tri-Stringer', 'REEF-LUX 450', 'REEF-LUX 450 Deco', 'Tri-Stringer', 'Wellstring V', 'Charcoal Decavitator', 'Mint Decavitator', 'Splatana Stamper', 'Splatana Stamper Nouveau', 'Splatana Wiper', 'Splatana Wiper Deco']
# Scraping builds for: .52 Gal
# Scraping builds for: .52 Gal Deco
# Scraping builds for: .96 Gal
# Scraping builds for: .96 Gal Deco
# Scraping builds for: Aerospray MG
# Scraping builds for: Aerospray RG
# Scraping builds for: Annaki Splattershot Nova
# Scraping builds for: Custom Jet Squelcher
# Scraping builds for: Custom Splattershot Jr.
# Scraping builds for: Foil Squeezer
# Scraping builds for: Forge Splattershot Pro
#                  Weapon_name             Main_1              Sub_1  \
# 0                    .52 Gal     Opening Gambit   Intensify Action
# 1                    .52 Gal           Comeback   Intensify Action
# 2                    .52 Gal      Swim Speed Up   Intensify Action
# 3                    .52 Gal           Comeback   Intensify Action
# 4                    .52 Gal     Opening Gambit   Intensify Action
# ...                      ...                ...                ...
# 2635  Forge Splattershot Pro       Run Speed Up   Ink Saver (Main)
# 2636  Forge Splattershot Pro  Last-Ditch Effort      Swim Speed Up
# 2637  Forge Splattershot Pro    Ink Recovery Up  Sub Resistance Up
# 2638  Forge Splattershot Pro  Last-Ditch Effort      Special Saver
# 2639  Forge Splattershot Pro           Comeback      Swim Speed Up
#
#                   Sub_2              Sub_3             Main_2  \
# 0      Intensify Action   Intensify Action      Swim Speed Up
# 1      Intensify Action   Intensify Action      Swim Speed Up
# 2      Intensify Action   Intensify Action      Swim Speed Up
# 3      Intensify Action   Intensify Action      Swim Speed Up
# 4      Intensify Action   Intensify Action      Swim Speed Up
# ...                 ...                ...                ...
# 2635   Ink Saver (Main)   Ink Saver (Main)    Ink Recovery Up
# 2636      Swim Speed Up      Swim Speed Up  Special Charge Up
# 2637  Sub Resistance Up  Special Charge Up    Ink Recovery Up
# 2638       Sub Power Up   Intensify Action        Thermal Ink
# 2639      Swim Speed Up    Ink Recovery Up   Ink Saver (Main)
#
#                   Sub_4              Sub_5              Sub_6  \
# 0         Swim Speed Up      Swim Speed Up  Ink Resistance Up
# 1         Swim Speed Up      Swim Speed Up      Special Saver
# 2       Ink Recovery Up      Special Saver   Quick Super Jump
# 3         Swim Speed Up      Swim Speed Up      Swim Speed Up
# 4         Swim Speed Up      Swim Speed Up      Special Saver
# ...                 ...                ...                ...
# 2635    Ink Recovery Up    Ink Recovery Up    Ink Recovery Up
# 2636   Ink Saver (Main)   Ink Saver (Main)   Quick Super Jump
# 2637   Special Power Up   Special Power Up   Special Power Up
# 2638    Ink Saver (Sub)    Ink Recovery Up      Swim Speed Up
# 2639  Special Charge Up  Special Charge Up   Quick Super Jump
#
#                  Main_3              Sub_7              Sub_8  \
# 0          Stealth Jump   Quick Super Jump   Quick Super Jump
# 1          Stealth Jump   Quick Super Jump  Ink Resistance Up
# 2          Stealth Jump  Ink Resistance Up  Sub Resistance Up
# 3          Stealth Jump      Special Saver   Quick Super Jump
# 4          Stealth Jump   Quick Super Jump  Ink Resistance Up
# ...                 ...                ...                ...
# 2635   Ink Saver (Main)       Run Speed Up       Run Speed Up
# 2636       Stealth Jump   Intensify Action   Intensify Action
# 2637   Ink Saver (Main)   Ink Saver (Main)   Ink Saver (Main)
# 2638  Special Charge Up  Special Charge Up  Special Charge Up
# 2639       Stealth Jump   Intensify Action   Intensify Action
#
#                   Sub_9                                         game_modes
# 0     Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1      Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2      Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3     Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4     Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                 ...                                                ...
# 2635       Run Speed Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2636  Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2637   Ink Saver (Main)  [Turf War, Splat Zones, Tower Control, Rainmak...
# 2638   Ink Saver (Main)  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2639  Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
#
# [2640 rows x 14 columns]

# %%
extract_sendou_data()
# Out:
# ['https://sendou.ink/builds/52-gal', 'https://sendou.ink/builds/52-gal-deco', 'https://sendou.ink/builds/96-gal', 'https://sendou.ink/builds/96-gal-deco', 'https://sendou.ink/builds/aerospray-mg', 'https://sendou.ink/builds/aerospray-rg', 'https://sendou.ink/builds/annaki-splattershot-nova', 'https://sendou.ink/builds/custom-jet-squelcher', 'https://sendou.ink/builds/custom-splattershot-jr', 'https://sendou.ink/builds/foil-squeezer', 'https://sendou.ink/builds/forge-splattershot-pro', 'https://sendou.ink/builds/h-3-nozzlenose', 'https://sendou.ink/builds/h-3-nozzlenose-d', 'https://sendou.ink/builds/jet-squelcher', 'https://sendou.ink/builds/l-3-nozzlenose', 'https://sendou.ink/builds/l-3-nozzlenose-d', 'https://sendou.ink/builds/n-zap-85', 'https://sendou.ink/builds/n-zap-89', 'https://sendou.ink/builds/neo-splash-o-matic', 'https://sendou.ink/builds/neo-sploosh-o-matic', 'https://sendou.ink/builds/splash-o-matic', 'https://sendou.ink/builds/splattershot', 'https://sendou.ink/builds/splattershot-jr', 'https://sendou.ink/builds/splattershot-nova', 'https://sendou.ink/builds/splattershot-pro', 'https://sendou.ink/builds/sploosh-o-matic', 'https://sendou.ink/builds/squeezer', 'https://sendou.ink/builds/tentatek-splattershot', 'https://sendou.ink/builds/blaster', 'https://sendou.ink/builds/clash-blaster', 'https://sendou.ink/builds/clash-blaster-neo', 'https://sendou.ink/builds/custom-blaster', 'https://sendou.ink/builds/custom-range-blaster', 'https://sendou.ink/builds/luna-blaster', 'https://sendou.ink/builds/luna-blaster-neo', 'https://sendou.ink/builds/range-blaster', 'https://sendou.ink/builds/rapid-blaster', 'https://sendou.ink/builds/rapid-blaster-deco', 'https://sendou.ink/builds/rapid-blaster-pro', 'https://sendou.ink/builds/rapid-blaster-pro-deco', 'https://sendou.ink/builds/s-blast-91', 'https://sendou.ink/builds/s-blast-92', 'https://sendou.ink/builds/big-swig-roller', 'https://sendou.ink/builds/big-swig-roller-express', 'https://sendou.ink/builds/carbon-roller', 'https://sendou.ink/builds/carbon-roller-deco', 'https://sendou.ink/builds/dynamo-roller', 'https://sendou.ink/builds/flingza-roller', 'https://sendou.ink/builds/foil-flingza-roller', 'https://sendou.ink/builds/gold-dynamo-roller', 'https://sendou.ink/builds/krak-on-splat-roller', 'https://sendou.ink/builds/splat-roller', 'https://sendou.ink/builds/inkbrush', 'https://sendou.ink/builds/inkbrush-nouveau', 'https://sendou.ink/builds/octobrush', 'https://sendou.ink/builds/octobrush-nouveau', 'https://sendou.ink/builds/painbrush', 'https://sendou.ink/builds/painbrush-nouveau', 'https://sendou.ink/builds/bamboozler-14-mk-i', 'https://sendou.ink/builds/bamboozler-14-mk-ii', 'https://sendou.ink/builds/classic-squiffer', 'https://sendou.ink/builds/custom-e-liter-4k', 'https://sendou.ink/builds/custom-e-liter-4k-scope', 'https://sendou.ink/builds/custom-goo-tuber', 'https://sendou.ink/builds/e-liter-4k', 'https://sendou.ink/builds/e-liter-4k-scope', 'https://sendou.ink/builds/goo-tuber', 'https://sendou.ink/builds/new-squiffer', 'https://sendou.ink/builds/snipewriter-5b', 'https://sendou.ink/builds/snipewriter-5h', 'https://sendou.ink/builds/splat-charger', 'https://sendou.ink/builds/splatterscope', 'https://sendou.ink/builds/zf-splat-charger', 'https://sendou.ink/builds/zf-splatterscope', 'https://sendou.ink/builds/bloblobber', 'https://sendou.ink/builds/bloblobber-deco', 'https://sendou.ink/builds/custom-explosher', 'https://sendou.ink/builds/dread-wringer', 'https://sendou.ink/builds/dread-wringer-d', 'https://sendou.ink/builds/explosher', 'https://sendou.ink/builds/slosher', 'https://sendou.ink/builds/slosher-deco', 'https://sendou.ink/builds/sloshing-machine', 'https://sendou.ink/builds/sloshing-machine-neo', 'https://sendou.ink/builds/tri-slosher', 'https://sendou.ink/builds/tri-slosher-nouveau', 'https://sendou.ink/builds/ballpoint-splatling', 'https://sendou.ink/builds/ballpoint-splatling-nouveau', 'https://sendou.ink/builds/custom-hydra-splatling', 'https://s ...
# ['.52 Gal', '.52 Gal Deco', '.96 Gal', '.96 Gal Deco', 'Aerospray MG', 'Aerospray RG', 'Annaki Splattershot Nova', 'Custom Jet Squelcher', 'Custom Splattershot Jr.', 'Foil Squeezer', 'Forge Splattershot Pro', 'H-3 Nozzlenose', 'H-3 Nozzlenose D', 'Jet Squelcher', 'L-3 Nozzlenose', 'L-3 Nozzlenose D', "N-ZAP '85", "N-ZAP '89", 'Neo Splash-o-matic', 'Neo Sploosh-o-matic', 'Splash-o-matic', 'Splattershot', 'Splattershot Jr.', 'Splattershot Nova', 'Splattershot Pro', 'Sploosh-o-matic', 'Squeezer', 'Tentatek Splattershot', 'Blaster', 'Clash Blaster', 'Clash Blaster Neo', 'Custom Blaster', 'Custom Range Blaster', 'Luna Blaster', 'Luna Blaster Neo', 'Range Blaster', 'Rapid Blaster', 'Rapid Blaster Deco', 'Rapid Blaster Pro', 'Rapid Blaster Pro Deco', "S-BLAST '91", "S-BLAST '92", 'Big Swig Roller', 'Big Swig Roller Express', 'Carbon Roller', 'Carbon Roller Deco', 'Dynamo Roller', 'Flingza Roller', 'Foil Flingza Roller', 'Gold Dynamo Roller', 'Krak-On Splat Roller', 'Splat Roller', 'Inkbrush', 'Inkbrush Nouveau', 'Octobrush', 'Octobrush Nouveau', 'Painbrush', 'Painbrush Nouveau', 'Bamboozler 14 Mk I', 'Bamboozler 14 Mk II', 'Classic Squiffer', 'Custom E-liter 4K', 'Custom E-liter 4K Scope', 'Custom Goo Tuber', 'E-liter 4K', 'E-liter 4K Scope', 'Goo Tuber', 'New Squiffer', 'Snipewriter 5B', 'Snipewriter 5H', 'Splat Charger', 'Splatterscope', 'Z+F Splat Charger', 'Z+F Splatterscope', 'Bloblobber', 'Bloblobber Deco', 'Custom Explosher', 'Dread Wringer', 'Dread Wringer D', 'Explosher', 'Slosher', 'Slosher Deco', 'Sloshing Machine', 'Sloshing Machine Neo', 'Tri-Slosher', 'Tri-Slosher Nouveau', 'Ballpoint Splatling', 'Ballpoint Splatling Nouveau', 'Custom Hydra Splatling', 'Heavy Edit Splatling', 'Heavy Edit Splatling Nouveau', 'Heavy Splatling', 'Heavy Splatling Deco', 'Hydra Splatling', 'Mini Splatling', 'Nautilus 47', 'Nautilus 79', 'Zink Mini Splatling', 'Custom Douser Dualies FF', 'Custom Dualie Squelchers', 'Dapple Dualies', 'Dapple Dualies Nouveau', 'Dark Tetra Dualies', 'Douser Dualies FF', 'Dualie Squelchers', 'Enperry Splat Dualies', 'Glooga Dualies', 'Glooga Dualies Deco', 'Light Tetra Dualies', 'Splat Dualies', 'Recycled Brella 24 Mk I', 'Recycled Brella 24 Mk II', 'Sorella Brella', 'Splat Brella', 'Tenta Brella', 'Tenta Sorella Brella', 'Undercover Brella', 'Undercover Sorella Brella', 'Custom Wellstring V', 'Inkline Tri-Stringer', 'REEF-LUX 450', 'REEF-LUX 450 Deco', 'Tri-Stringer', 'Wellstring V', 'Charcoal Decavitator', 'Mint Decavitator', 'Splatana Stamper', 'Splatana Stamper Nouveau', 'Splatana Wiper', 'Splatana Wiper Deco']
# Scraping builds for: .52 Gal
# Scraping builds for: .52 Gal Deco
# Scraping builds for: .96 Gal
# Scraping builds for: .96 Gal Deco
# Scraping builds for: Aerospray MG
# Scraping builds for: Aerospray RG
# Scraping builds for: Annaki Splattershot Nova
# Scraping builds for: Custom Jet Squelcher
# Scraping builds for: Custom Splattershot Jr.
# Scraping builds for: Foil Squeezer
# Scraping builds for: Forge Splattershot Pro
#                  Weapon_name             Main_1              Sub_1  \
# 0                    .52 Gal     Opening Gambit   Intensify Action
# 1                    .52 Gal           Comeback   Intensify Action
# 2                    .52 Gal      Swim Speed Up   Intensify Action
# 3                    .52 Gal           Comeback   Intensify Action
# 4                    .52 Gal     Opening Gambit   Intensify Action
# ...                      ...                ...                ...
# 2635  Forge Splattershot Pro       Run Speed Up   Ink Saver (Main)
# 2636  Forge Splattershot Pro  Last-Ditch Effort      Swim Speed Up
# 2637  Forge Splattershot Pro    Ink Recovery Up  Sub Resistance Up
# 2638  Forge Splattershot Pro  Last-Ditch Effort      Special Saver
# 2639  Forge Splattershot Pro           Comeback      Swim Speed Up
#
#                   Sub_2              Sub_3             Main_2  \
# 0      Intensify Action   Intensify Action      Swim Speed Up
# 1      Intensify Action   Intensify Action      Swim Speed Up
# 2      Intensify Action   Intensify Action      Swim Speed Up
# 3      Intensify Action   Intensify Action      Swim Speed Up
# 4      Intensify Action   Intensify Action      Swim Speed Up
# ...                 ...                ...                ...
# 2635   Ink Saver (Main)   Ink Saver (Main)    Ink Recovery Up
# 2636      Swim Speed Up      Swim Speed Up  Special Charge Up
# 2637  Sub Resistance Up  Special Charge Up    Ink Recovery Up
# 2638       Sub Power Up   Intensify Action        Thermal Ink
# 2639      Swim Speed Up    Ink Recovery Up   Ink Saver (Main)
#
#                   Sub_4              Sub_5              Sub_6  \
# 0         Swim Speed Up      Swim Speed Up  Ink Resistance Up
# 1         Swim Speed Up      Swim Speed Up      Special Saver
# 2       Ink Recovery Up      Special Saver   Quick Super Jump
# 3         Swim Speed Up      Swim Speed Up      Swim Speed Up
# 4         Swim Speed Up      Swim Speed Up      Special Saver
# ...                 ...                ...                ...
# 2635    Ink Recovery Up    Ink Recovery Up    Ink Recovery Up
# 2636   Ink Saver (Main)   Ink Saver (Main)   Quick Super Jump
# 2637   Special Power Up   Special Power Up   Special Power Up
# 2638    Ink Saver (Sub)    Ink Recovery Up      Swim Speed Up
# 2639  Special Charge Up  Special Charge Up   Quick Super Jump
#
#                  Main_3              Sub_7              Sub_8  \
# 0          Stealth Jump   Quick Super Jump   Quick Super Jump
# 1          Stealth Jump   Quick Super Jump  Ink Resistance Up
# 2          Stealth Jump  Ink Resistance Up  Sub Resistance Up
# 3          Stealth Jump      Special Saver   Quick Super Jump
# 4          Stealth Jump   Quick Super Jump  Ink Resistance Up
# ...                 ...                ...                ...
# 2635   Ink Saver (Main)       Run Speed Up       Run Speed Up
# 2636       Stealth Jump   Intensify Action   Intensify Action
# 2637   Ink Saver (Main)   Ink Saver (Main)   Ink Saver (Main)
# 2638  Special Charge Up  Special Charge Up  Special Charge Up
# 2639       Stealth Jump   Intensify Action   Intensify Action
#
#                   Sub_9                                         game_modes
# 0     Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1      Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2      Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3     Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4     Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                 ...                                                ...
# 2635       Run Speed Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2636  Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2637   Ink Saver (Main)  [Turf War, Splat Zones, Tower Control, Rainmak...
# 2638   Ink Saver (Main)  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2639  Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
#
# [2640 rows x 14 columns]

# %%
from bs4 import BeautifulSoup
# import requests
import time
import pandas as pd
from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"

DF_COLUMNS = [
    'Weapon_name',
    'Main_1', 'Sub_1', 'Sub_2', 'Sub_3',
    'Main_2', 'Sub_4', 'Sub_5', 'Sub_6',
    'Main_3', 'Sub_7', 'Sub_8', 'Sub_9',
    'game_modes'
]


# function that returns the data extracted from sendou as a data frame
def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    print(path_list)
    print(weapon_list)
    # call function returns the dataframe for all builds
    df_builds = create_weapon_build_df(path_list, weapon_list)
    return df_builds


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        # call function that if the link is for a build
        # return the path and name
        path, weapon_name = search_for_build_path(link)
        # add this path to the list
        paths = add_to_list(paths, path)
        # add this weapon name to the list
        weapon_names = add_to_list(weapon_names, weapon_name)
    # check to see if both lists are of same size
    # so that each weapon has a path
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


# function to add an element to a list
# only if its not none
def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    # Create and empty data frame from the columns already defined
    # this will store all the builds listed on the website
    df_all_weapon_builds = pd.DataFrame(columns=DF_COLUMNS)
    count = 0  # counter for what weapon builds page we are currently on
    # repeat for each weapon path
    for path in path_list:
        # pause for each path
        time.sleep(1)
        if count > 0:
             break
        # make request to the path
        path_soup = BeautifulSoup(make_request(path + '?limit=500').text,
                                  "html.parser")
        # calls a function that returns all the builds of a single weapon
        # as a dataframe
        df_weapon_builds = scrape_all_builds(path_soup, weapon_list, count)
        # append to the dataframe of all weapon builds
        df_all_weapon_builds = pd.concat([df_all_weapon_builds,
                                          df_weapon_builds], ignore_index=True)
        count += 1
    return df_all_weapon_builds


# function to scrape all builds for a single weapon:
def scrape_all_builds(path_soup, weapon_list, count):
    # data frame for all builds for a weapon
    df_weapon_builds = pd.DataFrame(columns=DF_COLUMNS)
    # message to show what weapon we are currently obtaining info from
    print("Scraping builds for: " + weapon_list[count])
    # finds all the builds on the page
    build_entries = path_soup.find_all('div',  class_='build')
    # loops through these
    for build in build_entries:
        # scrape each build
        ability_list, mode_list = scrape_a_build(build)
        # use the lists created to add a new row to the dataframe
        df_weapon_builds.loc[len(df_weapon_builds)] = (
            [weapon_list[count]] + ability_list + [mode_list]
        )
    # return all builds for that weapon
    return df_weapon_builds


# function to look at a single build and returns its info
def scrape_a_build(build):
    # create a list of the abilities of a build
    ability_list = extract_abilities(build)
    # create a list of the modes of a build
    mode_list = extract_modes(build)
    # return both
    return ability_list, mode_list


# function to extract game mode info from a build
def extract_modes(build):
    mode_list = []  # create empty list to store modes
    # find all the modes
    modes = build.find('div', class_='build__modes')
    #  check if there are any modes listed
    if modes is None:
        # if none, add this message instead
        # placeholder for now
        mode_list = ['NO MODES LISTED']
    elif modes is not None:
        # if there is modes listed
        # find the image tags for modes
        # as each mode is represented by an image
        img_tags = modes.find_all('img')
        # loop through the found image tags
        for i in img_tags:
            # the alt text is the name of the mode
            alt_text = i['alt']
            # add to the list of modes
            mode_list.append(alt_text)
    # return this list
    return mode_list


# function to extract ability info from a build
def extract_abilities(build):
    # find all abilities
    abilities = build.find_all('div', class_="build__ability readonly")
    ability_list = []  # create empty list to store abilities
    # loop through the found abilities
    for a in abilities:
        # find the image of the ability
        img_tag = a.find('img')
        # find the alt text which has the name
        alt_text = img_tag['alt']
        # add to the list of abilities
        ability_list.append((alt_text))
    # return this list
    return ability_list

# %% [markdown]
# <div class="build__ability readonly"><img alt="Opening Gambit" src="/static-assets/img/abilities/OG.png"/></div>

# %%
<div class="build__modes"><img alt="Splat Zones" src="/static-assets/img/modes/SZ.png"/><img alt="Tower Control" src="/static-assets/img/modes/TC.png"/><img alt="Rainmaker" src="/static-assets/img/modes/RM.png"/><img alt="Clam Blitz" src="/static-assets/img/modes/CB.png"/></div>

# %%
extract_sendou_data()
# Out:
# ['https://sendou.ink/builds/52-gal', 'https://sendou.ink/builds/52-gal-deco', 'https://sendou.ink/builds/96-gal', 'https://sendou.ink/builds/96-gal-deco', 'https://sendou.ink/builds/aerospray-mg', 'https://sendou.ink/builds/aerospray-rg', 'https://sendou.ink/builds/annaki-splattershot-nova', 'https://sendou.ink/builds/custom-jet-squelcher', 'https://sendou.ink/builds/custom-splattershot-jr', 'https://sendou.ink/builds/foil-squeezer', 'https://sendou.ink/builds/forge-splattershot-pro', 'https://sendou.ink/builds/h-3-nozzlenose', 'https://sendou.ink/builds/h-3-nozzlenose-d', 'https://sendou.ink/builds/jet-squelcher', 'https://sendou.ink/builds/l-3-nozzlenose', 'https://sendou.ink/builds/l-3-nozzlenose-d', 'https://sendou.ink/builds/n-zap-85', 'https://sendou.ink/builds/n-zap-89', 'https://sendou.ink/builds/neo-splash-o-matic', 'https://sendou.ink/builds/neo-sploosh-o-matic', 'https://sendou.ink/builds/splash-o-matic', 'https://sendou.ink/builds/splattershot', 'https://sendou.ink/builds/splattershot-jr', 'https://sendou.ink/builds/splattershot-nova', 'https://sendou.ink/builds/splattershot-pro', 'https://sendou.ink/builds/sploosh-o-matic', 'https://sendou.ink/builds/squeezer', 'https://sendou.ink/builds/tentatek-splattershot', 'https://sendou.ink/builds/blaster', 'https://sendou.ink/builds/clash-blaster', 'https://sendou.ink/builds/clash-blaster-neo', 'https://sendou.ink/builds/custom-blaster', 'https://sendou.ink/builds/custom-range-blaster', 'https://sendou.ink/builds/luna-blaster', 'https://sendou.ink/builds/luna-blaster-neo', 'https://sendou.ink/builds/range-blaster', 'https://sendou.ink/builds/rapid-blaster', 'https://sendou.ink/builds/rapid-blaster-deco', 'https://sendou.ink/builds/rapid-blaster-pro', 'https://sendou.ink/builds/rapid-blaster-pro-deco', 'https://sendou.ink/builds/s-blast-91', 'https://sendou.ink/builds/s-blast-92', 'https://sendou.ink/builds/big-swig-roller', 'https://sendou.ink/builds/big-swig-roller-express', 'https://sendou.ink/builds/carbon-roller', 'https://sendou.ink/builds/carbon-roller-deco', 'https://sendou.ink/builds/dynamo-roller', 'https://sendou.ink/builds/flingza-roller', 'https://sendou.ink/builds/foil-flingza-roller', 'https://sendou.ink/builds/gold-dynamo-roller', 'https://sendou.ink/builds/krak-on-splat-roller', 'https://sendou.ink/builds/splat-roller', 'https://sendou.ink/builds/inkbrush', 'https://sendou.ink/builds/inkbrush-nouveau', 'https://sendou.ink/builds/octobrush', 'https://sendou.ink/builds/octobrush-nouveau', 'https://sendou.ink/builds/painbrush', 'https://sendou.ink/builds/painbrush-nouveau', 'https://sendou.ink/builds/bamboozler-14-mk-i', 'https://sendou.ink/builds/bamboozler-14-mk-ii', 'https://sendou.ink/builds/classic-squiffer', 'https://sendou.ink/builds/custom-e-liter-4k', 'https://sendou.ink/builds/custom-e-liter-4k-scope', 'https://sendou.ink/builds/custom-goo-tuber', 'https://sendou.ink/builds/e-liter-4k', 'https://sendou.ink/builds/e-liter-4k-scope', 'https://sendou.ink/builds/goo-tuber', 'https://sendou.ink/builds/new-squiffer', 'https://sendou.ink/builds/snipewriter-5b', 'https://sendou.ink/builds/snipewriter-5h', 'https://sendou.ink/builds/splat-charger', 'https://sendou.ink/builds/splatterscope', 'https://sendou.ink/builds/zf-splat-charger', 'https://sendou.ink/builds/zf-splatterscope', 'https://sendou.ink/builds/bloblobber', 'https://sendou.ink/builds/bloblobber-deco', 'https://sendou.ink/builds/custom-explosher', 'https://sendou.ink/builds/dread-wringer', 'https://sendou.ink/builds/dread-wringer-d', 'https://sendou.ink/builds/explosher', 'https://sendou.ink/builds/slosher', 'https://sendou.ink/builds/slosher-deco', 'https://sendou.ink/builds/sloshing-machine', 'https://sendou.ink/builds/sloshing-machine-neo', 'https://sendou.ink/builds/tri-slosher', 'https://sendou.ink/builds/tri-slosher-nouveau', 'https://sendou.ink/builds/ballpoint-splatling', 'https://sendou.ink/builds/ballpoint-splatling-nouveau', 'https://sendou.ink/builds/custom-hydra-splatling', 'https://s ...
# ['.52 Gal', '.52 Gal Deco', '.96 Gal', '.96 Gal Deco', 'Aerospray MG', 'Aerospray RG', 'Annaki Splattershot Nova', 'Custom Jet Squelcher', 'Custom Splattershot Jr.', 'Foil Squeezer', 'Forge Splattershot Pro', 'H-3 Nozzlenose', 'H-3 Nozzlenose D', 'Jet Squelcher', 'L-3 Nozzlenose', 'L-3 Nozzlenose D', "N-ZAP '85", "N-ZAP '89", 'Neo Splash-o-matic', 'Neo Sploosh-o-matic', 'Splash-o-matic', 'Splattershot', 'Splattershot Jr.', 'Splattershot Nova', 'Splattershot Pro', 'Sploosh-o-matic', 'Squeezer', 'Tentatek Splattershot', 'Blaster', 'Clash Blaster', 'Clash Blaster Neo', 'Custom Blaster', 'Custom Range Blaster', 'Luna Blaster', 'Luna Blaster Neo', 'Range Blaster', 'Rapid Blaster', 'Rapid Blaster Deco', 'Rapid Blaster Pro', 'Rapid Blaster Pro Deco', "S-BLAST '91", "S-BLAST '92", 'Big Swig Roller', 'Big Swig Roller Express', 'Carbon Roller', 'Carbon Roller Deco', 'Dynamo Roller', 'Flingza Roller', 'Foil Flingza Roller', 'Gold Dynamo Roller', 'Krak-On Splat Roller', 'Splat Roller', 'Inkbrush', 'Inkbrush Nouveau', 'Octobrush', 'Octobrush Nouveau', 'Painbrush', 'Painbrush Nouveau', 'Bamboozler 14 Mk I', 'Bamboozler 14 Mk II', 'Classic Squiffer', 'Custom E-liter 4K', 'Custom E-liter 4K Scope', 'Custom Goo Tuber', 'E-liter 4K', 'E-liter 4K Scope', 'Goo Tuber', 'New Squiffer', 'Snipewriter 5B', 'Snipewriter 5H', 'Splat Charger', 'Splatterscope', 'Z+F Splat Charger', 'Z+F Splatterscope', 'Bloblobber', 'Bloblobber Deco', 'Custom Explosher', 'Dread Wringer', 'Dread Wringer D', 'Explosher', 'Slosher', 'Slosher Deco', 'Sloshing Machine', 'Sloshing Machine Neo', 'Tri-Slosher', 'Tri-Slosher Nouveau', 'Ballpoint Splatling', 'Ballpoint Splatling Nouveau', 'Custom Hydra Splatling', 'Heavy Edit Splatling', 'Heavy Edit Splatling Nouveau', 'Heavy Splatling', 'Heavy Splatling Deco', 'Hydra Splatling', 'Mini Splatling', 'Nautilus 47', 'Nautilus 79', 'Zink Mini Splatling', 'Custom Douser Dualies FF', 'Custom Dualie Squelchers', 'Dapple Dualies', 'Dapple Dualies Nouveau', 'Dark Tetra Dualies', 'Douser Dualies FF', 'Dualie Squelchers', 'Enperry Splat Dualies', 'Glooga Dualies', 'Glooga Dualies Deco', 'Light Tetra Dualies', 'Splat Dualies', 'Recycled Brella 24 Mk I', 'Recycled Brella 24 Mk II', 'Sorella Brella', 'Splat Brella', 'Tenta Brella', 'Tenta Sorella Brella', 'Undercover Brella', 'Undercover Sorella Brella', 'Custom Wellstring V', 'Inkline Tri-Stringer', 'REEF-LUX 450', 'REEF-LUX 450 Deco', 'Tri-Stringer', 'Wellstring V', 'Charcoal Decavitator', 'Mint Decavitator', 'Splatana Stamper', 'Splatana Stamper Nouveau', 'Splatana Wiper', 'Splatana Wiper Deco']
# Scraping builds for: .52 Gal
#     Weapon_name          Main_1              Sub_1              Sub_2  \
# 0       .52 Gal  Opening Gambit   Intensify Action   Intensify Action
# 1       .52 Gal        Comeback   Intensify Action   Intensify Action
# 2       .52 Gal   Swim Speed Up   Intensify Action   Intensify Action
# 3       .52 Gal        Comeback   Intensify Action   Intensify Action
# 4       .52 Gal  Opening Gambit   Intensify Action   Intensify Action
# ..          ...             ...                ...                ...
# 235     .52 Gal   Swim Speed Up   Intensify Action   Intensify Action
# 236     .52 Gal        Comeback  Special Charge Up  Special Charge Up
# 237     .52 Gal  Opening Gambit   Intensify Action   Intensify Action
# 238     .52 Gal        Comeback   Intensify Action   Intensify Action
# 239     .52 Gal  Opening Gambit   Intensify Action   Intensify Action
#
#                  Sub_3             Main_2            Sub_4          Sub_5  \
# 0     Intensify Action      Swim Speed Up    Swim Speed Up  Swim Speed Up
# 1     Intensify Action      Swim Speed Up    Swim Speed Up  Swim Speed Up
# 2     Intensify Action      Swim Speed Up  Ink Recovery Up  Special Saver
# 3     Intensify Action      Swim Speed Up    Swim Speed Up  Swim Speed Up
# 4     Intensify Action      Swim Speed Up    Swim Speed Up  Swim Speed Up
# ..                 ...                ...              ...            ...
# 235   Intensify Action      Swim Speed Up  Ink Recovery Up  Special Saver
# 236  Ink Resistance Up      Swim Speed Up    Swim Speed Up  Swim Speed Up
# 237   Intensify Action      Swim Speed Up    Swim Speed Up  Swim Speed Up
# 238   Intensify Action      Swim Speed Up    Swim Speed Up  Swim Speed Up
# 239    Ink Saver (Sub)  Special Charge Up  Ink Recovery Up  Special Saver
#
#                  Sub_6        Main_3              Sub_7              Sub_8  \
# 0    Ink Resistance Up  Stealth Jump   Quick Super Jump   Quick Super Jump
# 1        Special Saver  Stealth Jump   Quick Super Jump  Ink Resistance Up
# 2     Quick Super Jump  Stealth Jump  Ink Resistance Up  Sub Resistance Up
# 3        Swim Speed Up  Stealth Jump      Special Saver   Quick Super Jump
# 4        Special Saver  Stealth Jump   Quick Super Jump  Ink Resistance Up
# ..                 ...           ...                ...                ...
# 235   Quick Super Jump  Stealth Jump  Ink Resistance Up  Sub Resistance Up
# 236   Quick Super Jump  Stealth Jump   Intensify Action   Intensify Action
# 237      Special Saver  Stealth Jump   Quick Super Jump  Ink Resistance Up
# 238      Special Saver  Stealth Jump   Quick Super Jump  Ink Resistance Up
# 239   Special Power Up  Stealth Jump   Quick Super Jump  Ink Resistance Up
#
#                  Sub_9                                         game_modes
# 0    Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1     Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2     Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3    Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4    Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# ..                 ...                                                ...
# 235   Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 236  Sub Resistance Up  [Turf War, Splat Zones, Tower Control, Rainmak...
# 237  Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 238  Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 239  Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
#
# [240 rows x 14 columns]

# %%
# FINAL CODE (as  of 09/05/2025)

# %%
from bs4 import BeautifulSoup
# import requests
import time
import pandas as pd
from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"

DF_COLUMNS = [
    'Weapon_name',
    'Main_1', 'Sub_1', 'Sub_2', 'Sub_3',
    'Main_2', 'Sub_4', 'Sub_5', 'Sub_6',
    'Main_3', 'Sub_7', 'Sub_8', 'Sub_9',
    'game_modes'
]


# function that returns the data extracted from sendou as a data frame
def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    # call function returns the dataframe for all builds
    df_builds = create_weapon_build_df(path_list, weapon_list)
    return df_builds


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        # call function that if the link is for a build
        # return the path and name
        path, weapon_name = search_for_build_path(link)
        # add this path to the list
        paths = add_to_list(paths, path)
        # add this weapon name to the list
        weapon_names = add_to_list(weapon_names, weapon_name)
    # check to see if both lists are of same size
    # so that each weapon has a path
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


# function to add an element to a list
# only if its not none
def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    # Create and empty data frame from the columns already defined
    # this will store all the builds listed on the website
    df_all_weapon_builds = pd.DataFrame(columns=DF_COLUMNS)
    count = 0  # counter for what weapon builds page we are currently on
    # repeat for each weapon path
    for path in path_list:
        # pause for each path
        time.sleep(1)
        # if count > 10:
        #      break
        # make request to the path
        path_soup = BeautifulSoup(make_request(path + '?limit=500').text,
                                  "html.parser")
        # calls a function that returns all the builds of a single weapon
        # as a dataframe
        df_weapon_builds = scrape_all_builds(path_soup, weapon_list, count)
        # append to the dataframe of all weapon builds
        df_all_weapon_builds = pd.concat([df_all_weapon_builds,
                                          df_weapon_builds], ignore_index=True)
        count += 1
    return df_all_weapon_builds


# function to scrape all builds for a single weapon:
def scrape_all_builds(path_soup, weapon_list, count):
    # data frame for all builds for a weapon
    df_weapon_builds = pd.DataFrame(columns=DF_COLUMNS)
    # message to show what weapon we are currently obtaining info from
    print("Scraping builds for: " + weapon_list[count])
    # finds all the builds on the page
    build_entries = path_soup.find_all('div',  class_='build')
    # loops through these
    for build in build_entries:
        # scrape each build
        ability_list, mode_list = scrape_a_build(build)
        # use the lists created to add a new row to the dataframe
        df_weapon_builds.loc[len(df_weapon_builds)] = (
            [weapon_list[count]] + ability_list + [mode_list]
        )
    # return all builds for that weapon
    return df_weapon_builds


# function to look at a single build and returns its info
def scrape_a_build(build):
    # create a list of the abilities of a build
    ability_list = extract_abilities(build)
    # create a list of the modes of a build
    mode_list = extract_modes(build)
    # return both
    return ability_list, mode_list


# function to extract game mode info from a build
def extract_modes(build):
    mode_list = []  # create empty list to store modes
    # find all the modes
    modes = build.find('div', class_='build__modes')
    #  check if there are any modes listed
    if modes is None:
        # if none, add this message instead
        # placeholder for now
        mode_list = ['NO MODES LISTED']
    elif modes is not None:
        # if there is modes listed
        # find the image tags for modes
        # as each mode is represented by an image
        img_tags = modes.find_all('img')
        # loop through the found image tags
        for i in img_tags:
            # the alt text is the name of the mode
            alt_text = i['alt']
            # add to the list of modes
            mode_list.append(alt_text)
    # return this list
    return mode_list


# function to extract ability info from a build
def extract_abilities(build):
    # find all abilities
    abilities = build.find_all('div', class_="build__ability readonly")
    ability_list = []  # create empty list to store abilities
    # loop through the found abilities
    for a in abilities:
        # find the image of the ability
        img_tag = a.find('img')
        # find the alt text which has the name
        alt_text = img_tag['alt']
        # add to the list of abilities
        ability_list.append((alt_text))
    # return this list
    return ability_list

# %%
extract_sendou_data()
# Out:
# Scraping builds for: .52 Gal
# Scraping builds for: .52 Gal Deco
# Scraping builds for: .96 Gal
# Scraping builds for: .96 Gal Deco
# Scraping builds for: Aerospray MG
# Scraping builds for: Aerospray RG
# Scraping builds for: Annaki Splattershot Nova
# Scraping builds for: Custom Jet Squelcher
# Scraping builds for: Custom Splattershot Jr.
# Scraping builds for: Foil Squeezer
# Scraping builds for: Forge Splattershot Pro
# Scraping builds for: H-3 Nozzlenose
# Scraping builds for: H-3 Nozzlenose D
# Scraping builds for: Jet Squelcher
# Scraping builds for: L-3 Nozzlenose
# Scraping builds for: L-3 Nozzlenose D
# Scraping builds for: N-ZAP '85
# Scraping builds for: N-ZAP '89
# Scraping builds for: Neo Splash-o-matic
# Scraping builds for: Neo Sploosh-o-matic
# Scraping builds for: Splash-o-matic
# Scraping builds for: Splattershot
# Scraping builds for: Splattershot Jr.
# Scraping builds for: Splattershot Nova
# Scraping builds for: Splattershot Pro
# Scraping builds for: Sploosh-o-matic
# Scraping builds for: Squeezer
# Scraping builds for: Tentatek Splattershot
# Scraping builds for: Blaster
# Scraping builds for: Clash Blaster
# Scraping builds for: Clash Blaster Neo
# Scraping builds for: Custom Blaster
# Scraping builds for: Custom Range Blaster
# Scraping builds for: Luna Blaster
# Scraping builds for: Luna Blaster Neo
# Scraping builds for: Range Blaster
# Scraping builds for: Rapid Blaster
# Scraping builds for: Rapid Blaster Deco
# Scraping builds for: Rapid Blaster Pro
# Scraping builds for: Rapid Blaster Pro Deco
# Scraping builds for: S-BLAST '91
# Scraping builds for: S-BLAST '92
# Scraping builds for: Big Swig Roller
# Scraping builds for: Big Swig Roller Express
# Scraping builds for: Carbon Roller
# Scraping builds for: Carbon Roller Deco
# Scraping builds for: Dynamo Roller
# Scraping builds for: Flingza Roller
# Scraping builds for: Foil Flingza Roller
# Scraping builds for: Gold Dynamo Roller
# Scraping builds for: Krak-On Splat Roller
# Scraping builds for: Splat Roller
# Scraping builds for: Inkbrush
# Scraping builds for: Inkbrush Nouveau
# Scraping builds for: Octobrush
# Scraping builds for: Octobrush Nouveau
# Scraping builds for: Painbrush
# Scraping builds for: Painbrush Nouveau
# Scraping builds for: Bamboozler 14 Mk I
# Scraping builds for: Bamboozler 14 Mk II
# Scraping builds for: Classic Squiffer
# Scraping builds for: Custom E-liter 4K
# Scraping builds for: Custom E-liter 4K Scope
# Scraping builds for: Custom Goo Tuber
# Scraping builds for: E-liter 4K
# Scraping builds for: E-liter 4K Scope
# Scraping builds for: Goo Tuber
# Scraping builds for: New Squiffer
# Scraping builds for: Snipewriter 5B
# Scraping builds for: Snipewriter 5H
# Scraping builds for: Splat Charger
# Scraping builds for: Splatterscope
# Scraping builds for: Z+F Splat Charger
# Scraping builds for: Z+F Splatterscope
# Scraping builds for: Bloblobber
# Scraping builds for: Bloblobber Deco
# Scraping builds for: Custom Explosher
# Scraping builds for: Dread Wringer
# Scraping builds for: Dread Wringer D
# Scraping builds for: Explosher
# Scraping builds for: Slosher
# Scraping builds for: Slosher Deco
# Scraping builds for: Sloshing Machine
# Scraping builds for: Sloshing Machine Neo
# Scraping builds for: Tri-Slosher
# Scraping builds for: Tri-Slosher Nouveau
# Scraping builds for: Ballpoint Splatling
# Scraping builds for: Ballpoint Splatling Nouveau
# Scraping builds for: Custom Hydra Splatling
# Scraping builds for: Heavy Edit Splatling
# Scraping builds for: Heavy Edit Splatling Nouveau
# Scraping builds for: Heavy Splatling
# Scraping builds for: Heavy Splatling Deco
# Scraping builds for: Hydra Splatling
# Scraping builds for: Mini Splatling
# Scraping builds for: Nautilus 47
# Scraping builds for: Nautilus 79
# Scraping builds for: Zink Mini Splatling
# Scraping builds for: Custom Douser Dualies FF
# Scraping builds for: Custom Dualie Squelchers
# Scraping builds for: Dapple Dualies
# Scraping builds for: Dapple Dualies Nouveau
# Scraping builds for: Dark Tetra Dualies
# Scraping builds for: Douser Dualies FF
# Scraping builds for: Dualie Squelchers
# Scraping builds for: Enperry Splat Dualies
# Scraping builds for: Glooga Dualies
# Scraping builds for: Glooga Dualies Deco
# Scraping builds for: Light Tetra Dualies
# Scraping builds for: Splat Dualies
# Scraping builds for: Recycled Brella 24 Mk I
# Scraping builds for: Recycled Brella 24 Mk II
# Scraping builds for: Sorella Brella
# Scraping builds for: Splat Brella
# Scraping builds for: Tenta Brella
# Scraping builds for: Tenta Sorella Brella
# Scraping builds for: Undercover Brella
# Scraping builds for: Undercover Sorella Brella
# Scraping builds for: Custom Wellstring V
# Scraping builds for: Inkline Tri-Stringer
# Scraping builds for: REEF-LUX 450
# Scraping builds for: REEF-LUX 450 Deco
# Scraping builds for: Tri-Stringer
# Scraping builds for: Wellstring V
# Scraping builds for: Charcoal Decavitator
# Scraping builds for: Mint Decavitator
# Scraping builds for: Splatana Stamper
# Scraping builds for: Splatana Stamper Nouveau
# Scraping builds for: Splatana Wiper
# Scraping builds for: Splatana Wiper Deco
#                Weapon_name          Main_1             Sub_1  \
# 0                  .52 Gal  Opening Gambit  Intensify Action
# 1                  .52 Gal        Comeback  Intensify Action
# 2                  .52 Gal   Swim Speed Up  Intensify Action
# 3                  .52 Gal        Comeback  Intensify Action
# 4                  .52 Gal  Opening Gambit  Intensify Action
# ...                    ...             ...               ...
# 30295  Splatana Wiper Deco        Comeback     Swim Speed Up
# 30296  Splatana Wiper Deco    Sub Power Up   Ink Saver (Sub)
# 30297  Splatana Wiper Deco        Comeback     Quick Respawn
# 30298  Splatana Wiper Deco        Comeback     Quick Respawn
# 30299  Splatana Wiper Deco    Sub Power Up      Sub Power Up
#
#                   Sub_2             Sub_3         Main_2              Sub_4  \
# 0      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 1      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 2      Intensify Action  Intensify Action  Swim Speed Up    Ink Recovery Up
# 3      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 4      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# ...                 ...               ...            ...                ...
# 30295     Swim Speed Up     Special Saver   Sub Power Up       Sub Power Up
# 30296   Ink Saver (Sub)   Ink Saver (Sub)  Swim Speed Up      Swim Speed Up
# 30297     Quick Respawn     Quick Respawn          Haunt      Swim Speed Up
# 30298     Quick Respawn     Quick Respawn   Sub Power Up  Special Charge Up
# 30299      Sub Power Up  Quick Super Jump  Swim Speed Up      Swim Speed Up
#
#                    Sub_5              Sub_6        Main_3              Sub_7  \
# 0          Swim Speed Up  Ink Resistance Up  Stealth Jump   Quick Super Jump
# 1          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# 2          Special Saver   Quick Super Jump  Stealth Jump  Ink Resistance Up
# 3          Swim Speed Up      Swim Speed Up  Stealth Jump      Special Saver
# 4          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# ...                  ...                ...           ...                ...
# 30295       Sub Power Up       Sub Power Up  Sub Power Up   Special Power Up
# 30296  Ink Resistance Up  Sub Resistance Up  Stealth Jump   Quick Super Jump
# 30297      Swim Speed Up       Sub Power Up  Stealth Jump      Quick Respawn
# 30298  Special Charge Up  Special Charge Up  Stealth Jump      Quick Respawn
# 30299      Swim Speed Up  Special Charge Up  Stealth Jump      Quick Respawn
#
#                    Sub_8              Sub_9  \
# 0       Quick Super Jump  Sub Resistance Up
# 1      Ink Resistance Up   Intensify Action
# 2      Sub Resistance Up   Intensify Action
# 3       Quick Super Jump  Ink Resistance Up
# 4      Ink Resistance Up  Sub Resistance Up
# ...                  ...                ...
# 30295   Quick Super Jump       Sub Power Up
# 30296   Quick Super Jump   Quick Super Jump
# 30297      Quick Respawn       Sub Power Up
# 30298   Quick Super Jump       Sub Power Up
# 30299      Quick Respawn      Special Saver
#
#                                               game_modes
# 0      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4      [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                                                  ...
# 30295  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30296  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30297  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30298  [Turf War, Splat Zones, Tower Control, Clam Bl...
# 30299  [Turf War, Splat Zones, Tower Control, Rainmaker]
#
# [30300 rows x 14 columns]

# %%
from bs4 import BeautifulSoup
# import requests
import time
import pandas as pd
from etl.extract.url_request import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"

DF_COLUMNS = [
    'Weapon_name',
    'Main_1', 'Sub_1', 'Sub_2', 'Sub_3',
    'Main_2', 'Sub_4', 'Sub_5', 'Sub_6',
    'Main_3', 'Sub_7', 'Sub_8', 'Sub_9',
    'game_modes'
]

TESTING_MODE = False


# function that returns the data extracted from sendou as a data frame
def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    # call function returns the dataframe for all builds
    df_builds = create_weapon_build_df(path_list, weapon_list)
    return df_builds


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page
    # --------- for testing -----------
    if TESTING_MODE is True:
        all_links = all_links[:10]
    # ---------------------------------
    # loop through all the links
    for link in all_links:
        # call function that if the link is for a build
        # return the path and name
        path, weapon_name = search_for_build_path(link)
        # add this path to the list
        paths = add_to_list(paths, path)
        # add this weapon name to the list
        weapon_names = add_to_list(weapon_names, weapon_name)
    # check to see if both lists are of same size
    # so that each weapon has a path
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


# function to add an element to a list
# only if its not none
def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    # Create and empty data frame from the columns already defined
    # this will store all the builds listed on the website
    df_all_weapon_builds = pd.DataFrame(columns=DF_COLUMNS)
    count = 0  # counter for what weapon builds page we are currently on
    # repeat for each weapon path
    for path in path_list:
        # pause for each path
        time.sleep(1)
        # if count > 10:
        #      break
        # make request to the path
        path_soup = BeautifulSoup(make_request(path + '?limit=500').text,
                                  "html.parser")
        # calls a function that returns all the builds of a single weapon
        # as a dataframe
        df_weapon_builds = scrape_all_builds(path_soup, weapon_list, count)
        # append to the dataframe of all weapon builds
        df_all_weapon_builds = pd.concat([df_all_weapon_builds,
                                          df_weapon_builds], ignore_index=True)
        count += 1
    return df_all_weapon_builds


# function to scrape all builds for a single weapon:
def scrape_all_builds(path_soup, weapon_list, count):
    # data frame for all builds for a weapon
    df_weapon_builds = pd.DataFrame(columns=DF_COLUMNS)
    # message to show what weapon we are currently obtaining info from
    print("Scraping builds for: " + weapon_list[count])
    # finds all the builds on the page
    build_entries = path_soup.find_all('div',  class_='build')
    # loops through these
    for build in build_entries:
        # scrape each build
        ability_list, mode_list = scrape_a_build(build)
        # use the lists created to add a new row to the dataframe
        df_weapon_builds.loc[len(df_weapon_builds)] = (
            [weapon_list[count]] + ability_list + [mode_list]
        )
    # return all builds for that weapon
    return df_weapon_builds


# function to look at a single build and returns its info
def scrape_a_build(build):
    # create a list of the abilities of a build
    ability_list = extract_abilities(build)
    # create a list of the modes of a build
    mode_list = extract_modes(build)
    # return both
    return ability_list, mode_list


# function to extract game mode info from a build
def extract_modes(build):
    mode_list = []  # create empty list to store modes
    # find all the modes
    modes = build.find('div', class_='build__modes')
    #  check if there are any modes listed
    if modes is None:
        # if none, add this message instead
        # placeholder for now
        mode_list = ['NO MODES LISTED']
    elif modes is not None:
        # if there is modes listed
        # find the image tags for modes
        # as each mode is represented by an image
        img_tags = modes.find_all('img')
        # loop through the found image tags
        for i in img_tags:
            # the alt text is the name of the mode
            alt_text = i['alt']
            # add to the list of modes
            mode_list.append(alt_text)
    # return this list
    return mode_list


# function to extract ability info from a build
def extract_abilities(build):
    # find all abilities
    abilities = build.find_all('div', class_="build__ability readonly")
    ability_list = []  # create empty list to store abilities
    # loop through the found abilities
    for a in abilities:
        # find the image of the ability
        img_tag = a.find('img')
        # find the alt text which has the name
        alt_text = img_tag['alt']
        # add to the list of abilities
        ability_list.append((alt_text))
    # return this list
    return ability_list

# %%
display(extract_sendou_data())
# Out:
# Scraping builds for: .52 Gal
# Scraping builds for: .52 Gal Deco
# Scraping builds for: .96 Gal
# Scraping builds for: .96 Gal Deco
# Scraping builds for: Aerospray MG
# Scraping builds for: Aerospray RG
# Scraping builds for: Annaki Splattershot Nova
# Scraping builds for: Custom Jet Squelcher
# Scraping builds for: Custom Splattershot Jr.
# Scraping builds for: Foil Squeezer
# Scraping builds for: Forge Splattershot Pro
# Scraping builds for: H-3 Nozzlenose
# Scraping builds for: H-3 Nozzlenose D
# Scraping builds for: Jet Squelcher
# Scraping builds for: L-3 Nozzlenose
# Scraping builds for: L-3 Nozzlenose D
# Scraping builds for: N-ZAP '85
# Scraping builds for: N-ZAP '89
# Scraping builds for: Neo Splash-o-matic
# Scraping builds for: Neo Sploosh-o-matic
# Scraping builds for: Splash-o-matic
# Scraping builds for: Splattershot
# Scraping builds for: Splattershot Jr.
# Scraping builds for: Splattershot Nova
# Scraping builds for: Splattershot Pro
# Scraping builds for: Sploosh-o-matic
# Scraping builds for: Squeezer
# Scraping builds for: Tentatek Splattershot
# Scraping builds for: Blaster
# Scraping builds for: Clash Blaster
# Scraping builds for: Clash Blaster Neo
# Scraping builds for: Custom Blaster
# Scraping builds for: Custom Range Blaster
# Scraping builds for: Luna Blaster
# Scraping builds for: Luna Blaster Neo
# Scraping builds for: Range Blaster
# Scraping builds for: Rapid Blaster
# Scraping builds for: Rapid Blaster Deco
# Scraping builds for: Rapid Blaster Pro
# Scraping builds for: Rapid Blaster Pro Deco
# Scraping builds for: S-BLAST '91
# Scraping builds for: S-BLAST '92
# Scraping builds for: Big Swig Roller
# Scraping builds for: Big Swig Roller Express
# Scraping builds for: Carbon Roller
# Scraping builds for: Carbon Roller Deco
# Scraping builds for: Dynamo Roller
# Scraping builds for: Flingza Roller
# Scraping builds for: Foil Flingza Roller
# Scraping builds for: Gold Dynamo Roller
# Scraping builds for: Krak-On Splat Roller
# Scraping builds for: Splat Roller
# Scraping builds for: Inkbrush
# Scraping builds for: Inkbrush Nouveau
# Scraping builds for: Octobrush
# Scraping builds for: Octobrush Nouveau
# Scraping builds for: Painbrush
# Scraping builds for: Painbrush Nouveau
# Scraping builds for: Bamboozler 14 Mk I
# Scraping builds for: Bamboozler 14 Mk II
# Scraping builds for: Classic Squiffer
# Scraping builds for: Custom E-liter 4K
# Scraping builds for: Custom E-liter 4K Scope
# Scraping builds for: Custom Goo Tuber
# Scraping builds for: E-liter 4K
# Scraping builds for: E-liter 4K Scope
# Scraping builds for: Goo Tuber
# Scraping builds for: New Squiffer
# Scraping builds for: Snipewriter 5B
# Scraping builds for: Snipewriter 5H
# Scraping builds for: Splat Charger
# Scraping builds for: Splatterscope
# Scraping builds for: Z+F Splat Charger
# Scraping builds for: Z+F Splatterscope
# Scraping builds for: Bloblobber
# Scraping builds for: Bloblobber Deco
# Scraping builds for: Custom Explosher
# Scraping builds for: Dread Wringer
# Scraping builds for: Dread Wringer D
# Scraping builds for: Explosher
# Scraping builds for: Slosher
# Scraping builds for: Slosher Deco
# Scraping builds for: Sloshing Machine
# Scraping builds for: Sloshing Machine Neo
# Scraping builds for: Tri-Slosher
# Scraping builds for: Tri-Slosher Nouveau
# Scraping builds for: Ballpoint Splatling
# Scraping builds for: Ballpoint Splatling Nouveau
# Scraping builds for: Custom Hydra Splatling
# Scraping builds for: Heavy Edit Splatling
# Scraping builds for: Heavy Edit Splatling Nouveau
# Scraping builds for: Heavy Splatling
# Scraping builds for: Heavy Splatling Deco
# Scraping builds for: Hydra Splatling
# Scraping builds for: Mini Splatling
# Scraping builds for: Nautilus 47
# Scraping builds for: Nautilus 79
# Scraping builds for: Zink Mini Splatling
# Scraping builds for: Custom Douser Dualies FF
# Scraping builds for: Custom Dualie Squelchers
# Scraping builds for: Dapple Dualies
# Scraping builds for: Dapple Dualies Nouveau
# Scraping builds for: Dark Tetra Dualies
# Scraping builds for: Douser Dualies FF
# Scraping builds for: Dualie Squelchers
# Scraping builds for: Enperry Splat Dualies
# Scraping builds for: Glooga Dualies
# Scraping builds for: Glooga Dualies Deco
# Scraping builds for: Light Tetra Dualies
# Scraping builds for: Splat Dualies
# Scraping builds for: Recycled Brella 24 Mk I
# Scraping builds for: Recycled Brella 24 Mk II
# Scraping builds for: Sorella Brella
# Scraping builds for: Splat Brella
# Scraping builds for: Tenta Brella
# Scraping builds for: Tenta Sorella Brella
# Scraping builds for: Undercover Brella
# Scraping builds for: Undercover Sorella Brella
# Scraping builds for: Custom Wellstring V
# Scraping builds for: Inkline Tri-Stringer
# Scraping builds for: REEF-LUX 450
# Scraping builds for: REEF-LUX 450 Deco
# Scraping builds for: Tri-Stringer
# Scraping builds for: Wellstring V
# Scraping builds for: Charcoal Decavitator
# Scraping builds for: Mint Decavitator
# Scraping builds for: Splatana Stamper
# Scraping builds for: Splatana Stamper Nouveau
# Scraping builds for: Splatana Wiper
# Scraping builds for: Splatana Wiper Deco
#                Weapon_name          Main_1             Sub_1  \
# 0                  .52 Gal  Opening Gambit  Intensify Action
# 1                  .52 Gal        Comeback  Intensify Action
# 2                  .52 Gal   Swim Speed Up  Intensify Action
# 3                  .52 Gal        Comeback  Intensify Action
# 4                  .52 Gal  Opening Gambit  Intensify Action
# ...                    ...             ...               ...
# 30292  Splatana Wiper Deco        Comeback     Swim Speed Up
# 30293  Splatana Wiper Deco    Sub Power Up   Ink Saver (Sub)
# 30294  Splatana Wiper Deco        Comeback     Quick Respawn
# 30295  Splatana Wiper Deco        Comeback     Quick Respawn
# 30296  Splatana Wiper Deco    Sub Power Up      Sub Power Up
#
#                   Sub_2             Sub_3         Main_2              Sub_4  \
# 0      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 1      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 2      Intensify Action  Intensify Action  Swim Speed Up    Ink Recovery Up
# 3      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 4      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# ...                 ...               ...            ...                ...
# 30292     Swim Speed Up     Special Saver   Sub Power Up       Sub Power Up
# 30293   Ink Saver (Sub)   Ink Saver (Sub)  Swim Speed Up      Swim Speed Up
# 30294     Quick Respawn     Quick Respawn          Haunt      Swim Speed Up
# 30295     Quick Respawn     Quick Respawn   Sub Power Up  Special Charge Up
# 30296      Sub Power Up  Quick Super Jump  Swim Speed Up      Swim Speed Up
#
#                    Sub_5              Sub_6        Main_3              Sub_7  \
# 0          Swim Speed Up  Ink Resistance Up  Stealth Jump   Quick Super Jump
# 1          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# 2          Special Saver   Quick Super Jump  Stealth Jump  Ink Resistance Up
# 3          Swim Speed Up      Swim Speed Up  Stealth Jump      Special Saver
# 4          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# ...                  ...                ...           ...                ...
# 30292       Sub Power Up       Sub Power Up  Sub Power Up   Special Power Up
# 30293  Ink Resistance Up  Sub Resistance Up  Stealth Jump   Quick Super Jump
# 30294      Swim Speed Up       Sub Power Up  Stealth Jump      Quick Respawn
# 30295  Special Charge Up  Special Charge Up  Stealth Jump      Quick Respawn
# 30296      Swim Speed Up  Special Charge Up  Stealth Jump      Quick Respawn
#
#                    Sub_8              Sub_9  \
# 0       Quick Super Jump  Sub Resistance Up
# 1      Ink Resistance Up   Intensify Action
# 2      Sub Resistance Up   Intensify Action
# 3       Quick Super Jump  Ink Resistance Up
# 4      Ink Resistance Up  Sub Resistance Up
# ...                  ...                ...
# 30292   Quick Super Jump       Sub Power Up
# 30293   Quick Super Jump   Quick Super Jump
# 30294      Quick Respawn       Sub Power Up
# 30295   Quick Super Jump       Sub Power Up
# 30296      Quick Respawn      Special Saver
#
#                                               game_modes
# 0      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4      [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                                                  ...
# 30292  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30293  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30294  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30295  [Turf War, Splat Zones, Tower Control, Clam Bl...
# 30296  [Turf War, Splat Zones, Tower Control, Rainmaker]
#
# [30297 rows x 14 columns]

# %%
from bs4 import BeautifulSoup
# import requests
import time
import pandas as pd
from etl.extract.url_request import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"

DF_COLUMNS = [
    'Weapon_name',
    'Main_1', 'Sub_1', 'Sub_2', 'Sub_3',
    'Main_2', 'Sub_4', 'Sub_5', 'Sub_6',
    'Main_3', 'Sub_7', 'Sub_8', 'Sub_9',
    'game_modes'
]

TESTING_MODE = True


# function that returns the data extracted from sendou as a data frame
def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    # call function returns the dataframe for all builds
    df_builds = create_weapon_build_df(path_list, weapon_list)
    return df_builds


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page
    # --------- for testing -----------
    if TESTING_MODE is True:
        all_links = all_links[:10]
    # ---------------------------------
    # loop through all the links
    for link in all_links:
        # call function that if the link is for a build
        # return the path and name
        path, weapon_name = search_for_build_path(link)
        # add this path to the list
        paths = add_to_list(paths, path)
        # add this weapon name to the list
        weapon_names = add_to_list(weapon_names, weapon_name)
    # check to see if both lists are of same size
    # so that each weapon has a path
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


# function to add an element to a list
# only if its not none
def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    # Create and empty data frame from the columns already defined
    # this will store all the builds listed on the website
    df_all_weapon_builds = pd.DataFrame(columns=DF_COLUMNS)
    count = 0  # counter for what weapon builds page we are currently on
    # repeat for each weapon path
    for path in path_list:
        # pause for each path
        time.sleep(1)
        # if count > 10:
        #      break
        # make request to the path
        path_soup = BeautifulSoup(make_request(path + '?limit=500').text,
                                  "html.parser")
        # calls a function that returns all the builds of a single weapon
        # as a dataframe
        df_weapon_builds = scrape_all_builds(path_soup, weapon_list, count)
        # append to the dataframe of all weapon builds
        df_all_weapon_builds = pd.concat([df_all_weapon_builds,
                                          df_weapon_builds], ignore_index=True)
        count += 1
    return df_all_weapon_builds


# function to scrape all builds for a single weapon:
def scrape_all_builds(path_soup, weapon_list, count):
    # data frame for all builds for a weapon
    df_weapon_builds = pd.DataFrame(columns=DF_COLUMNS)
    # message to show what weapon we are currently obtaining info from
    print("Scraping builds for: " + weapon_list[count])
    # finds all the builds on the page
    build_entries = path_soup.find_all('div',  class_='build')
    # loops through these
    for build in build_entries:
        # scrape each build
        ability_list, mode_list = scrape_a_build(build)
        # use the lists created to add a new row to the dataframe
        df_weapon_builds.loc[len(df_weapon_builds)] = (
            [weapon_list[count]] + ability_list + [mode_list]
        )
    # return all builds for that weapon
    return df_weapon_builds


# function to look at a single build and returns its info
def scrape_a_build(build):
    # create a list of the abilities of a build
    ability_list = extract_abilities(build)
    # create a list of the modes of a build
    mode_list = extract_modes(build)
    # return both
    return ability_list, mode_list


# function to extract game mode info from a build
def extract_modes(build):
    mode_list = []  # create empty list to store modes
    # find all the modes
    modes = build.find('div', class_='build__modes')
    #  check if there are any modes listed
    if modes is None:
        # if none, add this message instead
        # placeholder for now
        mode_list = ['NO MODES LISTED']
    elif modes is not None:
        # if there is modes listed
        # find the image tags for modes
        # as each mode is represented by an image
        img_tags = modes.find_all('img')
        # loop through the found image tags
        for i in img_tags:
            # the alt text is the name of the mode
            alt_text = i['alt']
            # add to the list of modes
            mode_list.append(alt_text)
    # return this list
    return mode_list


# function to extract ability info from a build
def extract_abilities(build):
    # find all abilities
    abilities = build.find_all('div', class_="build__ability readonly")
    ability_list = []  # create empty list to store abilities
    # loop through the found abilities
    for a in abilities:
        # find the image of the ability
        img_tag = a.find('img')
        # find the alt text which has the name
        alt_text = img_tag['alt']
        # add to the list of abilities
        ability_list.append((alt_text))
    # return this list
    return ability_list

# %%
display(extract_sendou_data())
# Out:
# Scraping builds for: .52 Gal
# Scraping builds for: .52 Gal Deco
# Scraping builds for: .96 Gal
# Scraping builds for: .96 Gal Deco
# Scraping builds for: Aerospray MG
# Scraping builds for: Aerospray RG
# Scraping builds for: Annaki Splattershot Nova
# Scraping builds for: Custom Jet Squelcher
#                Weapon_name             Main_1              Sub_1  \
# 0                  .52 Gal     Opening Gambit   Intensify Action
# 1                  .52 Gal           Comeback   Intensify Action
# 2                  .52 Gal      Swim Speed Up   Intensify Action
# 3                  .52 Gal           Comeback   Intensify Action
# 4                  .52 Gal     Opening Gambit   Intensify Action
# ...                    ...                ...                ...
# 1915  Custom Jet Squelcher      Swim Speed Up  Special Charge Up
# 1916  Custom Jet Squelcher  Special Charge Up      Swim Speed Up
# 1917  Custom Jet Squelcher  Special Charge Up   Ink Saver (Main)
# 1918  Custom Jet Squelcher  Last-Ditch Effort   Ink Saver (Main)
# 1919  Custom Jet Squelcher           Tenacity    Ink Recovery Up
#
#                   Sub_2             Sub_3             Main_2  \
# 0      Intensify Action  Intensify Action      Swim Speed Up
# 1      Intensify Action  Intensify Action      Swim Speed Up
# 2      Intensify Action  Intensify Action      Swim Speed Up
# 3      Intensify Action  Intensify Action      Swim Speed Up
# 4      Intensify Action  Intensify Action      Swim Speed Up
# ...                 ...               ...                ...
# 1915  Special Charge Up      Run Speed Up   Ink Saver (Main)
# 1916      Swim Speed Up     Special Saver   Ink Saver (Main)
# 1917   Ink Saver (Main)  Quick Super Jump        Thermal Ink
# 1918   Ink Saver (Main)  Ink Saver (Main)  Special Charge Up
# 1919    Ink Recovery Up      Run Speed Up   Special Power Up
#
#                  Sub_4             Sub_5              Sub_6  \
# 0        Swim Speed Up     Swim Speed Up  Ink Resistance Up
# 1        Swim Speed Up     Swim Speed Up      Special Saver
# 2      Ink Recovery Up     Special Saver   Quick Super Jump
# 3        Swim Speed Up     Swim Speed Up      Swim Speed Up
# 4        Swim Speed Up     Swim Speed Up      Special Saver
# ...                ...               ...                ...
# 1915  Intensify Action  Intensify Action      Special Saver
# 1916  Special Power Up  Special Power Up   Quick Super Jump
# 1917      Sub Power Up      Sub Power Up   Intensify Action
# 1918   Ink Recovery Up   Ink Recovery Up   Quick Super Jump
# 1919  Special Power Up  Quick Super Jump  Ink Resistance Up
#
#                  Main_3              Sub_7              Sub_8  \
# 0          Stealth Jump   Quick Super Jump   Quick Super Jump
# 1          Stealth Jump   Quick Super Jump  Ink Resistance Up
# 2          Stealth Jump  Ink Resistance Up  Sub Resistance Up
# 3          Stealth Jump      Special Saver   Quick Super Jump
# 4          Stealth Jump   Quick Super Jump  Ink Resistance Up
# ...                 ...                ...                ...
# 1915   Ink Saver (Main)   Quick Super Jump  Ink Resistance Up
# 1916       Stealth Jump   Intensify Action   Intensify Action
# 1917       Run Speed Up  Ink Resistance Up  Ink Resistance Up
# 1918  Special Charge Up       Run Speed Up       Run Speed Up
# 1919      Swim Speed Up  Special Charge Up  Special Charge Up
#
#                   Sub_9                                         game_modes
# 0     Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1      Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2      Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3     Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4     Sub Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                 ...                                                ...
# 1915  Sub Resistance Up  [Turf War, Splat Zones, Tower Control, Rainmak...
# 1916  Ink Resistance Up  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1917   Intensify Action  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1918   Intensify Action                                  [NO MODES LISTED]
# 1919      Special Saver  [Splat Zones, Tower Control, Rainmaker, Clam B...
#
# [1920 rows x 14 columns]
