# %%
from etl.extract.extract_inkipedia import extract_inkipedia
df_weapons = extract_inkipedia()
display(df_weapons)
# Out:
#     Extra_space                     Name    ID           Sub          Special  \
# 0                        Sploosh-o-matic     0  Curling Bomb      Ultra Stamp
# 1                    Neo Sploosh-o-matic     1  Squid Beakon  Killer Wail 5.1
# 2                       Splattershot Jr.    10    Splat Bomb      Big Bubbler
# 3                Custom Splattershot Jr.    11       Torpedo     Wave Breaker
# 4                         Splash-o-matic    20    Burst Bomb        Crab Tank
# ..          ...                      ...   ...           ...              ...
# 138               Order Splatana Replica  8005    Burst Bomb        Zipcaster
# 139                       Splatana Wiper  8010       Torpedo      Ultra Stamp
# 140                  Splatana Wiper Deco  8011  Squid Beakon   Tenta Missiles
# 141                     Mint Decavitator  8020  Suction Bomb      Big Bubbler
# 142                 Charcoal Decavitator  8021   Splash Wall           Inkjet
#
#     Special_Points Level Price     Class                         Introduced
# 0             180p     9     1   Shooter  Version1.0.0(Drizzle Season 2022)
# 1             170p    13     1   Shooter    Version3.0.0(Fresh Season 2023)
# 2             180p     1         Shooter  Version1.0.0(Drizzle Season 2022)
# 3             190p     6     1   Shooter    Version2.0.0(Chill Season 2022)
# 4             200p    16     1   Shooter  Version1.0.0(Drizzle Season 2022)
# ..             ...   ...   ...       ...                                ...
# 138           210p     1        Splatana           Version7.0.0(Side Order)
# 139           190p     5     1  Splatana  Version1.0.0(Drizzle Season 2022)
# 140           190p    10     1  Splatana   Version4.0.0(Sizzle Season 2023)
# 141           210p    21     1  Splatana   Version8.0.0(Sizzle Season 2024)
# 142           200p    25     1  Splatana   Version8.0.0(Sizzle Season 2024)
#
# [143 rows x 10 columns]

# %%
from bs4 import BeautifulSoup
import pandas as pd
from etl.extract.url_request import make_request
import time

CLASSES_GALLERY_PATH = (
    'https://splatoonwiki.org/wiki/Category:Splatoon_3_weapon_class_icons'
)


# function to extract all weapon classes images
# from inkipedia as a dataframe
def extract_classes_images(df_weapons):
    print("\nCreating a dataframe of w_class weapon images...")
    # first call a function that returns all possible weapon classes
    # as a dataframe
    weapon_classes_df = find_class_names(df_weapons)
    # find all image urls for class images
    image_urls = find_all_class_images()
    # add these to the original weapon classes dataframe
    weapon_classes_df = create_class_df(weapon_classes_df, image_urls)
    print(
        "\x1b[32mDone! " +
        str(weapon_classes_df.shape[0]) +
        "/11 \x1b[32mimages found\x1b[0m")
    # check the length
    if weapon_classes_df.shape[0] == 11:
        # return the completed classes dataframe
        return weapon_classes_df
    else:
        raise Exception(
            "Error: Weapon classes data frame only has " +
            str(weapon_classes_df.shape[0]) +
            " classes, some are missing"
        )


# function to find all possible weapon classes
def find_class_names(df_weapons):
    # obtain a series of distinct weapon classes
    weapon_classes = df_weapons['Class'].unique()
    # create a dataframe of distinct weapon classes
    weapon_classes_df = pd.DataFrame(weapon_classes, columns=['Weapon Class'])
    # return this dataframe of weapon classes
    return weapon_classes_df


# function to find all weapon class images
def find_all_class_images():
    # make request to the site
    soup = BeautifulSoup(
        make_request(CLASSES_GALLERY_PATH).text, "html.parser"
        )
    # obtain all images
    images = soup.find_all('img')
    image_urls = []  # to store urls
    # pause
    time.sleep(1)
    # loop through images on the page
    for img in images:
        # pause
        time.sleep(0.05)
        # call a function to add the image url to the list
        image_urls = find_w_class_image(img, image_urls)
    # return the complete list
    return image_urls


# function to check if the image is a weapon class
# if so add to the list or urls
def find_w_class_image(img, image_urls):
    src = img.get('src')
    print("\nhello\n")
    print(img)
    # Check if the 'src' attribute exists and contains 'S3_Icon'
    if src and 'S3_Icon' in src:
        image_urls.append('https:' + src)
    return image_urls


# function to use both the list of images
# and dataframe of weapon classes
# to create a complete dataframe of w_class images
def create_class_df(weapon_classes_df, image_urls):
    # first order the w_classs alphabetically
    weapon_classes_df = weapon_classes_df.sort_values(by='Weapon Class')
    # reset the index again
    weapon_classes_df.reset_index(drop=True, inplace=True)
    # --- Assistance from ChatGPT ---------------------------------------
    # order the specials
    image_urls = sorted(image_urls, key=lambda img: img.split('/')[-1])
    # -------------------------------------------------------------------
    # add a new column called Image URL
    # add the urls here
    weapon_classes_df['Image URL'] = image_urls
    # return the complete dataframe
    return weapon_classes_df

# %% [markdown]
# <img height="32" src="//cdn.wikimg.net/en/splatoonwiki/images/7/7f/Site-wordmark.svg" width="152"/>
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/0/0d/S3_Icon_Brella.png/120px-S3_Icon_Brella.png"

# %%
extract_classes_images(df_weapons)
# Out:
# Creating a dataframe of w_class weapon images...
#
# hello
#
# <img height="32" src="//cdn.wikimg.net/en/splatoonwiki/images/7/7f/Site-wordmark.svg" width="152"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/5/5b/S3_Icon_Blaster.png/120px-S3_Icon_Blaster.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/5/5b/S3_Icon_Blaster.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/0/0d/S3_Icon_Brella.png/120px-S3_Icon_Brella.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/0/0d/S3_Icon_Brella.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/7/77/S3_Icon_Brush.png/120px-S3_Icon_Brush.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/7/77/S3_Icon_Brush.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/a/a0/S3_Icon_Charger.png/120px-S3_Icon_Charger.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/a/a0/S3_Icon_Charger.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/b/b5/S3_Icon_Dualie.png/120px-S3_Icon_Dualie.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/b/b5/S3_Icon_Dualie.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/f/fb/S3_Icon_Roller.png/120px-S3_Icon_Roller.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/f/fb/S3_Icon_Roller.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/c/c8/S3_Icon_Shooter.png/120px-S3_Icon_Shooter.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/c/c8/S3_Icon_Shooter.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/2/2f/S3_Icon_Slosher.png/120px-S3_Icon_Slosher.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/2/2f/S3_Icon_Slosher.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/7/7c/S3_Icon_Splatana.png/120px-S3_Icon_Splatana.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/7/7c/S3_Icon_Splatana.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/a/af/S3_Icon_Splatling.png/120px-S3_Icon_Splatling.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/a/af/S3_Icon_Splatling.png 1.5x" width="120"/>
#
# hello
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/6/60/S3_Icon_Stringer.png/120px-S3_Icon_Stringer.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/6/60/S3_Icon_Stringer.png 1.5x" width="120"/>
#
# hello
#
# <img src="//cdn.wikimg.net/en/splatoonwiki/images/e/ea/Site-wiki.svg"/>
#
# hello
#
# <img alt="Creative Commons Attribution-ShareAlike 4.0" height="31" loading="lazy" src="/w/resources/assets/licenses/cc-by-sa.png" width="88"/>
#
# hello
#
# <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/w/resources/assets/poweredby_mediawiki_88x31.png" srcset="/w/resources/assets/poweredby_mediawiki_132x47.png 1.5x, /w/resources/assets/poweredby_mediawiki_176x62.png 2x" width="88"/>
#
# hello
#
# <img alt="Powered by StrategyWiki" height="31" loading="lazy" src="https://cdn.wikimg.net/en/strategywiki/images/e/e5/Powered_by_StrategyWiki_Button.png" srcset="https://cdn.wikimg.net/en/strategywiki/images/f/f0/Powered_by_StrategyWiki_Button2x.png 2x" width="88"/>
# Done! 11/11 images found
#    Weapon Class                                          Image URL
# 0       Blaster  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 1        Brella  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 2         Brush  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 3       Charger  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 4        Dualie  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 5        Roller  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 6       Shooter  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 7       Slosher  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 8      Splatana  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 9     Splatling  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 10     Stringer  https://cdn.wikimg.net/en/splatoonwiki/images/...
