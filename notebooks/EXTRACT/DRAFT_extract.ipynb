# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time


# defining constants:
SENDOU_BUILDS_URL = 'https://sendou.ink/builds'
SENDOU_BASE_URL = 'https://sendou.ink'




# function that returns the data extracted from sendou as a data frame

def extract_sendou_data():
    # call function that returns a list of paths to each weapon's page of builds
    # call function returns the dataframe
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, 'html.parser')
    
    paths = [] # empty list for storing paths
    weapon_names = [] # empty list for storing weapon names
    
    all_links = soup.find_all('a') # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links: 
        href = link.get('href') # the href of attribute of <a>
        # make sure that the <a> has href
        if href is not None: 
            # if href is not none then continue to check if the link is for a weapon build page
            if href.startswith('/builds/'):
                # if it is add the link to the list (add to the end of the base path first)
                path = SENDOU_BASE_URL + href
                paths.append(path)
                
                # also find the text of the link (with strip remove whitespaces)
                text = link.get_text(strip=True)
                # add this to the list of weapon names (if not none)
                if text is not None:
                    weapon_names.append(link.get_text(strip=True))
                # brief pause between each path retrieval (avoid overwhelming the website)
                time.sleep(0.1)
    print(len(paths))
    print(len(weapon_names))
    return paths, weapon_names




# function to create a dataframe from the the weapon build data
def create_weapon_build_df():
    return None


# function that takes in a site, makes a request then returns the response
def make_request(URL):
    try:
        # sending a get request to a URL, wait 10 seconds max for a response
        response = requests.get(URL, timeout=10) 
        if response.status_code != 200: # if the status code is not ok, return an error
            return {
                "status": "error",
                "error": "Request failed as status code is not 200"
            }
        # if succesful return response
        return response
    except Exception: 
        # return an error if something else goes wrong with the request
        return {
            "status": "error",
            "error": "An unknown error has occurred"
        }
        

weapon_build_paths()
# Out:
# 130
# 130
# (['https://sendou.ink/builds/52-gal',
#   'https://sendou.ink/builds/52-gal-deco',
#   'https://sendou.ink/builds/96-gal',
#   'https://sendou.ink/builds/96-gal-deco',
#   'https://sendou.ink/builds/aerospray-mg',
#   'https://sendou.ink/builds/aerospray-rg',
#   'https://sendou.ink/builds/annaki-splattershot-nova',
#   'https://sendou.ink/builds/custom-jet-squelcher',
#   'https://sendou.ink/builds/custom-splattershot-jr',
#   'https://sendou.ink/builds/foil-squeezer',
#   'https://sendou.ink/builds/forge-splattershot-pro',
#   'https://sendou.ink/builds/h-3-nozzlenose',
#   'https://sendou.ink/builds/h-3-nozzlenose-d',
#   'https://sendou.ink/builds/jet-squelcher',
#   'https://sendou.ink/builds/l-3-nozzlenose',
#   'https://sendou.ink/builds/l-3-nozzlenose-d',
#   'https://sendou.ink/builds/n-zap-85',
#   'https://sendou.ink/builds/n-zap-89',
#   'https://sendou.ink/builds/neo-splash-o-matic',
#   'https://sendou.ink/builds/neo-sploosh-o-matic',
#   'https://sendou.ink/builds/splash-o-matic',
#   'https://sendou.ink/builds/splattershot',
#   'https://sendou.ink/builds/splattershot-jr',
#   'https://sendou.ink/builds/splattershot-nova',
#   'https://sendou.ink/builds/splattershot-pro',
#   'https://sendou.ink/builds/sploosh-o-matic',
#   'https://sendou.ink/builds/squeezer',
#   'https://sendou.ink/builds/tentatek-splattershot',
#   'https://sendou.ink/builds/blaster',
#   'https://sendou.ink/builds/clash-blaster',
#   'https://sendou.ink/builds/clash-blaster-neo',
#   'https://sendou.ink/builds/custom-blaster',
#   'https://sendou.ink/builds/custom-range-blaster',
#   'https://sendou.ink/builds/luna-blaster',
#   'https://sendou.ink/builds/luna-blaster-neo',
#   'https://sendou.ink/builds/range-blaster',
#   'https://sendou.ink/builds/rapid-blaster',
#   'https://sendou.ink/builds/rapid-blaster-deco',
#   'https://sendou.ink/builds/rapid-blaster-pro',
#   'https://sendou.ink/builds/rapid-blaster-pro-deco',
#   'https://sendou.ink/builds/s-blast-91',
#   'https://sendou.ink/builds/s-blast-92',
#   'https://sendou.ink/builds/big-swig-roller',
#   'https://sendou.ink/builds/big-swig-roller-express',
#   'https://sendou.ink/builds/carbon-roller',
#   'https://sendou.ink/builds/carbon-roller-deco',
#   'https://sendou.ink/builds/dynamo-roller',
#   'https://sendou.ink/builds/flingza-roller',
#   'https://sendou.ink/builds/foil-flingza-roller',
#   'https://sendou.ink/builds/gold-dynamo-roller',
#   'https://sendou.ink/builds/krak-on-splat-roller',
#   'https://sendou.ink/builds/splat-roller',
#   'https://sendou.ink/builds/inkbrush',
#   'https://sendou.ink/builds/inkbrush-nouveau',
#   'https://sendou.ink/builds/octobrush',
#   'https://sendou.ink/builds/octobrush-nouveau',
#   'https://sendou.ink/builds/painbrush',
#   'https://sendou.ink/builds/painbrush-nouveau',
#   'https://sendou.ink/builds/bamboozler-14-mk-i',
#   'https://sendou.ink/builds/bamboozler-14-mk-ii',
#   'https://sendou.ink/builds/classic-squiffer',
#   'https://sendou.ink/builds/custom-e-liter-4k',
#   'https://sendou.ink/builds/custom-e-liter-4k-scope',
#   'https://sendou.ink/builds/custom-goo-tuber',
#   'https://sendou.ink/builds/e-liter-4k',
#   'https://sendou.ink/builds/e-liter-4k-scope',
#   'https://sendou.ink/builds/goo-tuber',
#   'https://sendou.ink/builds/new-squiffer',
#   'https://sendou.ink/builds/snipewriter-5b',
#   'https://sendou.ink/builds/snipewriter-5h',
#   'https://sendou.ink/builds/splat-charger',
#   'https://sendou.ink/builds/splatterscope',
#   'https://sendou.ink/builds/zf-splat-charger',
#   'https://sendou.ink/builds/zf-splatterscope',
#   'https://sendou.ink/builds/bloblobber',
#   'https://sendou.ink/builds/bloblobber-deco',
#   'https://sendou.ink/builds/custom-explosher',
#   'https://sendou.ink/builds/dread-wringer',
#   'https://sendou.ink/builds/dread-wringer-d',
#   'https://sendou.ink/builds/explosher',
#   'https://sendou.ink/builds/slosher',
#   'https://sendou.ink/builds/slosher-deco',
#   'https://sendou.ink/builds/sloshing-machine',
#   'https://sendou.ink/builds/sloshing-machine-neo',
#   'https://sendou.ink/builds/tri-slosher',
#   'https://sendou.ink/builds/tri-slosher-nouveau',
#   'https://sendou.ink/builds/ballpoint-splatling',
#   'https://sendou.ink/builds/ballpoint-splatling-nouveau',
#   'https://sendou.ink/builds/custom-hydra-splatling',
#   'https://sendou.ink/builds/heavy-edit-splatling',
#   'https://sendou.ink/builds/heavy-edit-splatling-nouveau',
#   'https://sendou.ink/builds/heavy-splatling',
#   'https://sendou.ink/builds/heavy-splatling-deco',
#   'https://sendou.ink/builds/hydra-splatling',
#   'https://sendou.ink/builds/mini-splatling',
#   'https://sendou.ink/builds/nautilus-47',
#   'https://sendou.ink/builds/nautilus-79',
#   'https://sendou.ink/builds/zink-mini-splatling',
#   'https://sendou.ink/builds/custom-douser-dualies-ff',
#   'https://sendou.ink/builds/custom-dualie-squelchers',
#   'https://sendou.ink/builds/dapple-dualies',
#   'https://sendou.ink/builds/dapple-dualies-nouveau',
#   'https://sendou.ink/builds/dark-tetra-dualies',
#   'https://sendou.ink/builds/douser-dualies-ff',
#   'https://sendou.ink/builds/dualie-squelchers',
#   'https://sendou.ink/builds/enperry-splat-dualies',
#   'https://sendou.ink/builds/glooga-dualies',
#   'https://sendou.ink/builds/glooga-dualies-deco',
#   'https://sendou.ink/builds/light-tetra-dualies',
#   'https://sendou.ink/builds/splat-dualies',
#   'https://sendou.ink/builds/recycled-brella-24-mk-i',
#   'https://sendou.ink/builds/recycled-brella-24-mk-ii',
#   'https://sendou.ink/builds/sorella-brella',
#   'https://sendou.ink/builds/splat-brella',
#   'https://sendou.ink/builds/tenta-brella',
#   'https://sendou.ink/builds/tenta-sorella-brella',
#   'https://sendou.ink/builds/undercover-brella',
#   'https://sendou.ink/builds/undercover-sorella-brella',
#   'https://sendou.ink/builds/custom-wellstring-v',
#   'https://sendou.ink/builds/inkline-tri-stringer',
#   'https://sendou.ink/builds/reef-lux-450',
#   'https://sendou.ink/builds/reef-lux-450-deco',
#   'https://sendou.ink/builds/tri-stringer',
#   'https://sendou.ink/builds/wellstring-v',
#   'https://sendou.ink/builds/charcoal-decavitator',
#   'https://sendou.ink/builds/mint-decavitator',
#   'https://sendou.ink/builds/splatana-stamper',
#   'https://sendou.ink/builds/splatana-stamper-nouveau',
#   'https://sendou.ink/builds/splatana-wiper',
#   'https://sendou.ink/builds/splatana-wiper-deco'],
#  ['.52 Gal',
#   '.52 Gal Deco',
#   '.96 Gal',
#   '.96 Gal Deco',
#   'Aerospray MG',
#   'Aerospray RG',
#   'Annaki Splattershot Nova',
#   'Custom Jet Squelcher',
#   'Custom Splattershot Jr.',
#   'Foil Squeezer',
#   'Forge Splattershot Pro',
#   'H-3 Nozzlenose',
#   'H-3 Nozzlenose D',
#   'Jet Squelcher',
#   'L-3 Nozzlenose',
#   'L-3 Nozzlenose D',
#   "N-ZAP '85",
#   "N-ZAP '89",
#   'Neo Splash-o-matic',
#   'Neo Sploosh-o-matic',
#   'Splash-o-matic',
#   'Splattershot',
#   'Splattershot Jr.',
#   'Splattershot Nova',
#   'Splattershot Pro',
#   'Sploosh-o-matic',
#   'Squeezer',
#   'Tentatek Splattershot',
#   'Blaster',
#   'Clash Blaster',
#   'Clash Blaster Neo',
#   'Custom Blaster',
#   'Custom Range Blaster',
#   'Luna Blaster',
#   'Luna Blaster Neo',
#   'Range Blaster',
#   'Rapid Blaster',
#   'Rapid Blaster Deco',
#   'Rapid Blaster Pro',
#   'Rapid Blaster Pro Deco',
#   "S-BLAST '91",
#   "S-BLAST '92",
#   'Big Swig Roller',
#   'Big Swig Roller Express',
#   'Carbon Roller',
#   'Carbon Roller Deco',
#   'Dynamo Roller',
#   'Flingza Roller',
#   'Foil Flingza Roller',
#   'Gold Dynamo Roller',
#   'Krak-On Splat Roller',
#   'Splat Roller',
#   'Inkbrush',
#   'Inkbrush Nouveau',
#   'Octobrush',
#   'Octobrush Nouveau',
#   'Painbrush',
#   'Painbrush Nouveau',
#   'Bamboozler 14 Mk I',
#   'Bamboozler 14 Mk II',
#   'Classic Squiffer',
#   'Custom E-liter 4K',
#   'Custom E-liter 4K Scope',
#   'Custom Goo Tuber',
#   'E-liter 4K',
#   'E-liter 4K Scope',
#   'Goo Tuber',
#   'New Squiffer',
#   'Snipewriter 5B',
#   'Snipewriter 5H',
#   'Splat Charger',
#   'Splatterscope',
#   'Z+F Splat Charger',
#   'Z+F Splatterscope',
#   'Bloblobber',
#   'Bloblobber Deco',
#   'Custom Explosher',
#   'Dread Wringer',
#   'Dread Wringer D',
#   'Explosher',
#   'Slosher',
#   'Slosher Deco',
#   'Sloshing Machine',
#   'Sloshing Machine Neo',
#   'Tri-Slosher',
#   'Tri-Slosher Nouveau',
#   'Ballpoint Splatling',
#   'Ballpoint Splatling Nouveau',
#   'Custom Hydra Splatling',
#   'Heavy Edit Splatling',
#   'Heavy Edit Splatling Nouveau',
#   'Heavy Splatling',
#   'Heavy Splatling Deco',
#   'Hydra Splatling',
#   'Mini Splatling',
#   'Nautilus 47',
#   'Nautilus 79',
#   'Zink Mini Splatling',
#   'Custom Douser Dualies FF',
#   'Custom Dualie Squelchers',
#   'Dapple Dualies',
#   'Dapple Dualies Nouveau',
#   'Dark Tetra Dualies',
#   'Douser Dualies FF',
#   'Dualie Squelchers',
#   'Enperry Splat Dualies',
#   'Glooga Dualies',
#   'Glooga Dualies Deco',
#   'Light Tetra Dualies',
#   'Splat Dualies',
#   'Recycled Brella 24 Mk I',
#   'Recycled Brella 24 Mk II',
#   'Sorella Brella',
#   'Splat Brella',
#   'Tenta Brella',
#   'Tenta Sorella Brella',
#   'Undercover Brella',
#   'Undercover Sorella Brella',
#   'Custom Wellstring V',
#   'Inkline Tri-Stringer',
#   'REEF-LUX 450',
#   'REEF-LUX 450 Deco',
#   'Tri-Stringer',
#   'Wellstring V',
#   'Charcoal Decavitator',
#   'Mint Decavitator',
#   'Splatana Stamper',
#   'Splatana Stamper Nouveau',
#   'Splatana Wiper',
#   'Splatana Wiper Deco'])

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time


# defining constants:
SENDOU_BUILDS_URL = 'https://sendou.ink/builds'
SENDOU_BASE_URL = 'https://sendou.ink'




# function that returns the data extracted from sendou as a data frame

def extract_sendou_data():
    # call function that returns a list of paths to each weapon's page of builds
    # call function returns the dataframe
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, 'html.parser')
    
    paths = [] # empty list for storing paths
    weapon_names = [] # empty list for storing weapon names
    
    all_links = soup.find_all('a') # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links: 
        path,weapon_name = search_for_build_path(link)
        paths = add_to_list(paths,path)
        weapon_names = add_to_list(weapon_names,weapon_name)
        
    print(len(paths))
    print(len(weapon_names))
    return paths, weapon_names

# function to find the build paths 
def search_for_build_path(link):
    href = link.get('href') # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None: 
        # if href is not none then continue to check if the link is for a weapon build page
        if href.startswith('/builds/'):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval (avoid overwhelming the website)
            time.sleep(0.1)
        # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None
    
def add_to_list(the_list,element):
    if element is not None:
        the_list.append(element)
    return the_list
    
    
    
    

# function to create a dataframe from the the weapon build data
def create_weapon_build_df():
    return None


# function that takes in a site, makes a request then returns the response
def make_request(URL):
    try:
        # sending a get request to a URL, wait 10 seconds max for a response
        response = requests.get(URL, timeout=10) 
        if response.status_code != 200: # if the status code is not ok, return an error
            return {
                "status": "error",
                "error": "Request failed as status code is not 200"
            }
        # if succesful return response
        return response
    except Exception: 
        # return an error if something else goes wrong with the request
        return {
            "status": "error",
            "error": "An unknown error has occurred"
        }
        

weapon_build_paths()
# Out:
# 130
# 130
# (['https://sendou.ink/builds/52-gal',
#   'https://sendou.ink/builds/52-gal-deco',
#   'https://sendou.ink/builds/96-gal',
#   'https://sendou.ink/builds/96-gal-deco',
#   'https://sendou.ink/builds/aerospray-mg',
#   'https://sendou.ink/builds/aerospray-rg',
#   'https://sendou.ink/builds/annaki-splattershot-nova',
#   'https://sendou.ink/builds/custom-jet-squelcher',
#   'https://sendou.ink/builds/custom-splattershot-jr',
#   'https://sendou.ink/builds/foil-squeezer',
#   'https://sendou.ink/builds/forge-splattershot-pro',
#   'https://sendou.ink/builds/h-3-nozzlenose',
#   'https://sendou.ink/builds/h-3-nozzlenose-d',
#   'https://sendou.ink/builds/jet-squelcher',
#   'https://sendou.ink/builds/l-3-nozzlenose',
#   'https://sendou.ink/builds/l-3-nozzlenose-d',
#   'https://sendou.ink/builds/n-zap-85',
#   'https://sendou.ink/builds/n-zap-89',
#   'https://sendou.ink/builds/neo-splash-o-matic',
#   'https://sendou.ink/builds/neo-sploosh-o-matic',
#   'https://sendou.ink/builds/splash-o-matic',
#   'https://sendou.ink/builds/splattershot',
#   'https://sendou.ink/builds/splattershot-jr',
#   'https://sendou.ink/builds/splattershot-nova',
#   'https://sendou.ink/builds/splattershot-pro',
#   'https://sendou.ink/builds/sploosh-o-matic',
#   'https://sendou.ink/builds/squeezer',
#   'https://sendou.ink/builds/tentatek-splattershot',
#   'https://sendou.ink/builds/blaster',
#   'https://sendou.ink/builds/clash-blaster',
#   'https://sendou.ink/builds/clash-blaster-neo',
#   'https://sendou.ink/builds/custom-blaster',
#   'https://sendou.ink/builds/custom-range-blaster',
#   'https://sendou.ink/builds/luna-blaster',
#   'https://sendou.ink/builds/luna-blaster-neo',
#   'https://sendou.ink/builds/range-blaster',
#   'https://sendou.ink/builds/rapid-blaster',
#   'https://sendou.ink/builds/rapid-blaster-deco',
#   'https://sendou.ink/builds/rapid-blaster-pro',
#   'https://sendou.ink/builds/rapid-blaster-pro-deco',
#   'https://sendou.ink/builds/s-blast-91',
#   'https://sendou.ink/builds/s-blast-92',
#   'https://sendou.ink/builds/big-swig-roller',
#   'https://sendou.ink/builds/big-swig-roller-express',
#   'https://sendou.ink/builds/carbon-roller',
#   'https://sendou.ink/builds/carbon-roller-deco',
#   'https://sendou.ink/builds/dynamo-roller',
#   'https://sendou.ink/builds/flingza-roller',
#   'https://sendou.ink/builds/foil-flingza-roller',
#   'https://sendou.ink/builds/gold-dynamo-roller',
#   'https://sendou.ink/builds/krak-on-splat-roller',
#   'https://sendou.ink/builds/splat-roller',
#   'https://sendou.ink/builds/inkbrush',
#   'https://sendou.ink/builds/inkbrush-nouveau',
#   'https://sendou.ink/builds/octobrush',
#   'https://sendou.ink/builds/octobrush-nouveau',
#   'https://sendou.ink/builds/painbrush',
#   'https://sendou.ink/builds/painbrush-nouveau',
#   'https://sendou.ink/builds/bamboozler-14-mk-i',
#   'https://sendou.ink/builds/bamboozler-14-mk-ii',
#   'https://sendou.ink/builds/classic-squiffer',
#   'https://sendou.ink/builds/custom-e-liter-4k',
#   'https://sendou.ink/builds/custom-e-liter-4k-scope',
#   'https://sendou.ink/builds/custom-goo-tuber',
#   'https://sendou.ink/builds/e-liter-4k',
#   'https://sendou.ink/builds/e-liter-4k-scope',
#   'https://sendou.ink/builds/goo-tuber',
#   'https://sendou.ink/builds/new-squiffer',
#   'https://sendou.ink/builds/snipewriter-5b',
#   'https://sendou.ink/builds/snipewriter-5h',
#   'https://sendou.ink/builds/splat-charger',
#   'https://sendou.ink/builds/splatterscope',
#   'https://sendou.ink/builds/zf-splat-charger',
#   'https://sendou.ink/builds/zf-splatterscope',
#   'https://sendou.ink/builds/bloblobber',
#   'https://sendou.ink/builds/bloblobber-deco',
#   'https://sendou.ink/builds/custom-explosher',
#   'https://sendou.ink/builds/dread-wringer',
#   'https://sendou.ink/builds/dread-wringer-d',
#   'https://sendou.ink/builds/explosher',
#   'https://sendou.ink/builds/slosher',
#   'https://sendou.ink/builds/slosher-deco',
#   'https://sendou.ink/builds/sloshing-machine',
#   'https://sendou.ink/builds/sloshing-machine-neo',
#   'https://sendou.ink/builds/tri-slosher',
#   'https://sendou.ink/builds/tri-slosher-nouveau',
#   'https://sendou.ink/builds/ballpoint-splatling',
#   'https://sendou.ink/builds/ballpoint-splatling-nouveau',
#   'https://sendou.ink/builds/custom-hydra-splatling',
#   'https://sendou.ink/builds/heavy-edit-splatling',
#   'https://sendou.ink/builds/heavy-edit-splatling-nouveau',
#   'https://sendou.ink/builds/heavy-splatling',
#   'https://sendou.ink/builds/heavy-splatling-deco',
#   'https://sendou.ink/builds/hydra-splatling',
#   'https://sendou.ink/builds/mini-splatling',
#   'https://sendou.ink/builds/nautilus-47',
#   'https://sendou.ink/builds/nautilus-79',
#   'https://sendou.ink/builds/zink-mini-splatling',
#   'https://sendou.ink/builds/custom-douser-dualies-ff',
#   'https://sendou.ink/builds/custom-dualie-squelchers',
#   'https://sendou.ink/builds/dapple-dualies',
#   'https://sendou.ink/builds/dapple-dualies-nouveau',
#   'https://sendou.ink/builds/dark-tetra-dualies',
#   'https://sendou.ink/builds/douser-dualies-ff',
#   'https://sendou.ink/builds/dualie-squelchers',
#   'https://sendou.ink/builds/enperry-splat-dualies',
#   'https://sendou.ink/builds/glooga-dualies',
#   'https://sendou.ink/builds/glooga-dualies-deco',
#   'https://sendou.ink/builds/light-tetra-dualies',
#   'https://sendou.ink/builds/splat-dualies',
#   'https://sendou.ink/builds/recycled-brella-24-mk-i',
#   'https://sendou.ink/builds/recycled-brella-24-mk-ii',
#   'https://sendou.ink/builds/sorella-brella',
#   'https://sendou.ink/builds/splat-brella',
#   'https://sendou.ink/builds/tenta-brella',
#   'https://sendou.ink/builds/tenta-sorella-brella',
#   'https://sendou.ink/builds/undercover-brella',
#   'https://sendou.ink/builds/undercover-sorella-brella',
#   'https://sendou.ink/builds/custom-wellstring-v',
#   'https://sendou.ink/builds/inkline-tri-stringer',
#   'https://sendou.ink/builds/reef-lux-450',
#   'https://sendou.ink/builds/reef-lux-450-deco',
#   'https://sendou.ink/builds/tri-stringer',
#   'https://sendou.ink/builds/wellstring-v',
#   'https://sendou.ink/builds/charcoal-decavitator',
#   'https://sendou.ink/builds/mint-decavitator',
#   'https://sendou.ink/builds/splatana-stamper',
#   'https://sendou.ink/builds/splatana-stamper-nouveau',
#   'https://sendou.ink/builds/splatana-wiper',
#   'https://sendou.ink/builds/splatana-wiper-deco'],
#  ['.52 Gal',
#   '.52 Gal Deco',
#   '.96 Gal',
#   '.96 Gal Deco',
#   'Aerospray MG',
#   'Aerospray RG',
#   'Annaki Splattershot Nova',
#   'Custom Jet Squelcher',
#   'Custom Splattershot Jr.',
#   'Foil Squeezer',
#   'Forge Splattershot Pro',
#   'H-3 Nozzlenose',
#   'H-3 Nozzlenose D',
#   'Jet Squelcher',
#   'L-3 Nozzlenose',
#   'L-3 Nozzlenose D',
#   "N-ZAP '85",
#   "N-ZAP '89",
#   'Neo Splash-o-matic',
#   'Neo Sploosh-o-matic',
#   'Splash-o-matic',
#   'Splattershot',
#   'Splattershot Jr.',
#   'Splattershot Nova',
#   'Splattershot Pro',
#   'Sploosh-o-matic',
#   'Squeezer',
#   'Tentatek Splattershot',
#   'Blaster',
#   'Clash Blaster',
#   'Clash Blaster Neo',
#   'Custom Blaster',
#   'Custom Range Blaster',
#   'Luna Blaster',
#   'Luna Blaster Neo',
#   'Range Blaster',
#   'Rapid Blaster',
#   'Rapid Blaster Deco',
#   'Rapid Blaster Pro',
#   'Rapid Blaster Pro Deco',
#   "S-BLAST '91",
#   "S-BLAST '92",
#   'Big Swig Roller',
#   'Big Swig Roller Express',
#   'Carbon Roller',
#   'Carbon Roller Deco',
#   'Dynamo Roller',
#   'Flingza Roller',
#   'Foil Flingza Roller',
#   'Gold Dynamo Roller',
#   'Krak-On Splat Roller',
#   'Splat Roller',
#   'Inkbrush',
#   'Inkbrush Nouveau',
#   'Octobrush',
#   'Octobrush Nouveau',
#   'Painbrush',
#   'Painbrush Nouveau',
#   'Bamboozler 14 Mk I',
#   'Bamboozler 14 Mk II',
#   'Classic Squiffer',
#   'Custom E-liter 4K',
#   'Custom E-liter 4K Scope',
#   'Custom Goo Tuber',
#   'E-liter 4K',
#   'E-liter 4K Scope',
#   'Goo Tuber',
#   'New Squiffer',
#   'Snipewriter 5B',
#   'Snipewriter 5H',
#   'Splat Charger',
#   'Splatterscope',
#   'Z+F Splat Charger',
#   'Z+F Splatterscope',
#   'Bloblobber',
#   'Bloblobber Deco',
#   'Custom Explosher',
#   'Dread Wringer',
#   'Dread Wringer D',
#   'Explosher',
#   'Slosher',
#   'Slosher Deco',
#   'Sloshing Machine',
#   'Sloshing Machine Neo',
#   'Tri-Slosher',
#   'Tri-Slosher Nouveau',
#   'Ballpoint Splatling',
#   'Ballpoint Splatling Nouveau',
#   'Custom Hydra Splatling',
#   'Heavy Edit Splatling',
#   'Heavy Edit Splatling Nouveau',
#   'Heavy Splatling',
#   'Heavy Splatling Deco',
#   'Hydra Splatling',
#   'Mini Splatling',
#   'Nautilus 47',
#   'Nautilus 79',
#   'Zink Mini Splatling',
#   'Custom Douser Dualies FF',
#   'Custom Dualie Squelchers',
#   'Dapple Dualies',
#   'Dapple Dualies Nouveau',
#   'Dark Tetra Dualies',
#   'Douser Dualies FF',
#   'Dualie Squelchers',
#   'Enperry Splat Dualies',
#   'Glooga Dualies',
#   'Glooga Dualies Deco',
#   'Light Tetra Dualies',
#   'Splat Dualies',
#   'Recycled Brella 24 Mk I',
#   'Recycled Brella 24 Mk II',
#   'Sorella Brella',
#   'Splat Brella',
#   'Tenta Brella',
#   'Tenta Sorella Brella',
#   'Undercover Brella',
#   'Undercover Sorella Brella',
#   'Custom Wellstring V',
#   'Inkline Tri-Stringer',
#   'REEF-LUX 450',
#   'REEF-LUX 450 Deco',
#   'Tri-Stringer',
#   'Wellstring V',
#   'Charcoal Decavitator',
#   'Mint Decavitator',
#   'Splatana Stamper',
#   'Splatana Stamper Nouveau',
#   'Splatana Wiper',
#   'Splatana Wiper Deco'])

# %%
from bs4 import BeautifulSoup
import requests
import time


# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"


# function that returns the data extracted from sendou as a data frame


def extract_sendou_data():
    # call function that returns a
    # list of paths to each weapon's page of builds
    # call function returns the dataframe
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        path, weapon_name = search_for_build_path(link)
        paths = add_to_list(paths, path)
        weapon_names = add_to_list(weapon_names, weapon_name)
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df():
    return None


# function that takes in a site, makes a request then returns the response
def make_request(URL):
    try:
        # sending a get request to a URL, wait 10 seconds max for a response
        response = requests.get(URL, timeout=10)
        # if the status code is not ok, return an error
        if response.status_code != 200:
            return {
                "status": "error",
                "error": "Request failed as status code is not 200",
            }
        # if succesful return response
        return response
    except Exception:
        # return an error if something else goes wrong with the request
        return {"status": "error", "error": "An unknown error has occurred"}

# %%
weapon_build_paths()
# Out:
# (['https://sendou.ink/builds/52-gal',
#   'https://sendou.ink/builds/52-gal-deco',
#   'https://sendou.ink/builds/96-gal',
#   'https://sendou.ink/builds/96-gal-deco',
#   'https://sendou.ink/builds/aerospray-mg',
#   'https://sendou.ink/builds/aerospray-rg',
#   'https://sendou.ink/builds/annaki-splattershot-nova',
#   'https://sendou.ink/builds/custom-jet-squelcher',
#   'https://sendou.ink/builds/custom-splattershot-jr',
#   'https://sendou.ink/builds/foil-squeezer',
#   'https://sendou.ink/builds/forge-splattershot-pro',
#   'https://sendou.ink/builds/h-3-nozzlenose',
#   'https://sendou.ink/builds/h-3-nozzlenose-d',
#   'https://sendou.ink/builds/jet-squelcher',
#   'https://sendou.ink/builds/l-3-nozzlenose',
#   'https://sendou.ink/builds/l-3-nozzlenose-d',
#   'https://sendou.ink/builds/n-zap-85',
#   'https://sendou.ink/builds/n-zap-89',
#   'https://sendou.ink/builds/neo-splash-o-matic',
#   'https://sendou.ink/builds/neo-sploosh-o-matic',
#   'https://sendou.ink/builds/splash-o-matic',
#   'https://sendou.ink/builds/splattershot',
#   'https://sendou.ink/builds/splattershot-jr',
#   'https://sendou.ink/builds/splattershot-nova',
#   'https://sendou.ink/builds/splattershot-pro',
#   'https://sendou.ink/builds/sploosh-o-matic',
#   'https://sendou.ink/builds/squeezer',
#   'https://sendou.ink/builds/tentatek-splattershot',
#   'https://sendou.ink/builds/blaster',
#   'https://sendou.ink/builds/clash-blaster',
#   'https://sendou.ink/builds/clash-blaster-neo',
#   'https://sendou.ink/builds/custom-blaster',
#   'https://sendou.ink/builds/custom-range-blaster',
#   'https://sendou.ink/builds/luna-blaster',
#   'https://sendou.ink/builds/luna-blaster-neo',
#   'https://sendou.ink/builds/range-blaster',
#   'https://sendou.ink/builds/rapid-blaster',
#   'https://sendou.ink/builds/rapid-blaster-deco',
#   'https://sendou.ink/builds/rapid-blaster-pro',
#   'https://sendou.ink/builds/rapid-blaster-pro-deco',
#   'https://sendou.ink/builds/s-blast-91',
#   'https://sendou.ink/builds/s-blast-92',
#   'https://sendou.ink/builds/big-swig-roller',
#   'https://sendou.ink/builds/big-swig-roller-express',
#   'https://sendou.ink/builds/carbon-roller',
#   'https://sendou.ink/builds/carbon-roller-deco',
#   'https://sendou.ink/builds/dynamo-roller',
#   'https://sendou.ink/builds/flingza-roller',
#   'https://sendou.ink/builds/foil-flingza-roller',
#   'https://sendou.ink/builds/gold-dynamo-roller',
#   'https://sendou.ink/builds/krak-on-splat-roller',
#   'https://sendou.ink/builds/splat-roller',
#   'https://sendou.ink/builds/inkbrush',
#   'https://sendou.ink/builds/inkbrush-nouveau',
#   'https://sendou.ink/builds/octobrush',
#   'https://sendou.ink/builds/octobrush-nouveau',
#   'https://sendou.ink/builds/painbrush',
#   'https://sendou.ink/builds/painbrush-nouveau',
#   'https://sendou.ink/builds/bamboozler-14-mk-i',
#   'https://sendou.ink/builds/bamboozler-14-mk-ii',
#   'https://sendou.ink/builds/classic-squiffer',
#   'https://sendou.ink/builds/custom-e-liter-4k',
#   'https://sendou.ink/builds/custom-e-liter-4k-scope',
#   'https://sendou.ink/builds/custom-goo-tuber',
#   'https://sendou.ink/builds/e-liter-4k',
#   'https://sendou.ink/builds/e-liter-4k-scope',
#   'https://sendou.ink/builds/goo-tuber',
#   'https://sendou.ink/builds/new-squiffer',
#   'https://sendou.ink/builds/snipewriter-5b',
#   'https://sendou.ink/builds/snipewriter-5h',
#   'https://sendou.ink/builds/splat-charger',
#   'https://sendou.ink/builds/splatterscope',
#   'https://sendou.ink/builds/zf-splat-charger',
#   'https://sendou.ink/builds/zf-splatterscope',
#   'https://sendou.ink/builds/bloblobber',
#   'https://sendou.ink/builds/bloblobber-deco',
#   'https://sendou.ink/builds/custom-explosher',
#   'https://sendou.ink/builds/dread-wringer',
#   'https://sendou.ink/builds/dread-wringer-d',
#   'https://sendou.ink/builds/explosher',
#   'https://sendou.ink/builds/slosher',
#   'https://sendou.ink/builds/slosher-deco',
#   'https://sendou.ink/builds/sloshing-machine',
#   'https://sendou.ink/builds/sloshing-machine-neo',
#   'https://sendou.ink/builds/tri-slosher',
#   'https://sendou.ink/builds/tri-slosher-nouveau',
#   'https://sendou.ink/builds/ballpoint-splatling',
#   'https://sendou.ink/builds/ballpoint-splatling-nouveau',
#   'https://sendou.ink/builds/custom-hydra-splatling',
#   'https://sendou.ink/builds/heavy-edit-splatling',
#   'https://sendou.ink/builds/heavy-edit-splatling-nouveau',
#   'https://sendou.ink/builds/heavy-splatling',
#   'https://sendou.ink/builds/heavy-splatling-deco',
#   'https://sendou.ink/builds/hydra-splatling',
#   'https://sendou.ink/builds/mini-splatling',
#   'https://sendou.ink/builds/nautilus-47',
#   'https://sendou.ink/builds/nautilus-79',
#   'https://sendou.ink/builds/zink-mini-splatling',
#   'https://sendou.ink/builds/custom-douser-dualies-ff',
#   'https://sendou.ink/builds/custom-dualie-squelchers',
#   'https://sendou.ink/builds/dapple-dualies',
#   'https://sendou.ink/builds/dapple-dualies-nouveau',
#   'https://sendou.ink/builds/dark-tetra-dualies',
#   'https://sendou.ink/builds/douser-dualies-ff',
#   'https://sendou.ink/builds/dualie-squelchers',
#   'https://sendou.ink/builds/enperry-splat-dualies',
#   'https://sendou.ink/builds/glooga-dualies',
#   'https://sendou.ink/builds/glooga-dualies-deco',
#   'https://sendou.ink/builds/light-tetra-dualies',
#   'https://sendou.ink/builds/splat-dualies',
#   'https://sendou.ink/builds/recycled-brella-24-mk-i',
#   'https://sendou.ink/builds/recycled-brella-24-mk-ii',
#   'https://sendou.ink/builds/sorella-brella',
#   'https://sendou.ink/builds/splat-brella',
#   'https://sendou.ink/builds/tenta-brella',
#   'https://sendou.ink/builds/tenta-sorella-brella',
#   'https://sendou.ink/builds/undercover-brella',
#   'https://sendou.ink/builds/undercover-sorella-brella',
#   'https://sendou.ink/builds/custom-wellstring-v',
#   'https://sendou.ink/builds/inkline-tri-stringer',
#   'https://sendou.ink/builds/reef-lux-450',
#   'https://sendou.ink/builds/reef-lux-450-deco',
#   'https://sendou.ink/builds/tri-stringer',
#   'https://sendou.ink/builds/wellstring-v',
#   'https://sendou.ink/builds/charcoal-decavitator',
#   'https://sendou.ink/builds/mint-decavitator',
#   'https://sendou.ink/builds/splatana-stamper',
#   'https://sendou.ink/builds/splatana-stamper-nouveau',
#   'https://sendou.ink/builds/splatana-wiper',
#   'https://sendou.ink/builds/splatana-wiper-deco'],
#  ['.52 Gal',
#   '.52 Gal Deco',
#   '.96 Gal',
#   '.96 Gal Deco',
#   'Aerospray MG',
#   'Aerospray RG',
#   'Annaki Splattershot Nova',
#   'Custom Jet Squelcher',
#   'Custom Splattershot Jr.',
#   'Foil Squeezer',
#   'Forge Splattershot Pro',
#   'H-3 Nozzlenose',
#   'H-3 Nozzlenose D',
#   'Jet Squelcher',
#   'L-3 Nozzlenose',
#   'L-3 Nozzlenose D',
#   "N-ZAP '85",
#   "N-ZAP '89",
#   'Neo Splash-o-matic',
#   'Neo Sploosh-o-matic',
#   'Splash-o-matic',
#   'Splattershot',
#   'Splattershot Jr.',
#   'Splattershot Nova',
#   'Splattershot Pro',
#   'Sploosh-o-matic',
#   'Squeezer',
#   'Tentatek Splattershot',
#   'Blaster',
#   'Clash Blaster',
#   'Clash Blaster Neo',
#   'Custom Blaster',
#   'Custom Range Blaster',
#   'Luna Blaster',
#   'Luna Blaster Neo',
#   'Range Blaster',
#   'Rapid Blaster',
#   'Rapid Blaster Deco',
#   'Rapid Blaster Pro',
#   'Rapid Blaster Pro Deco',
#   "S-BLAST '91",
#   "S-BLAST '92",
#   'Big Swig Roller',
#   'Big Swig Roller Express',
#   'Carbon Roller',
#   'Carbon Roller Deco',
#   'Dynamo Roller',
#   'Flingza Roller',
#   'Foil Flingza Roller',
#   'Gold Dynamo Roller',
#   'Krak-On Splat Roller',
#   'Splat Roller',
#   'Inkbrush',
#   'Inkbrush Nouveau',
#   'Octobrush',
#   'Octobrush Nouveau',
#   'Painbrush',
#   'Painbrush Nouveau',
#   'Bamboozler 14 Mk I',
#   'Bamboozler 14 Mk II',
#   'Classic Squiffer',
#   'Custom E-liter 4K',
#   'Custom E-liter 4K Scope',
#   'Custom Goo Tuber',
#   'E-liter 4K',
#   'E-liter 4K Scope',
#   'Goo Tuber',
#   'New Squiffer',
#   'Snipewriter 5B',
#   'Snipewriter 5H',
#   'Splat Charger',
#   'Splatterscope',
#   'Z+F Splat Charger',
#   'Z+F Splatterscope',
#   'Bloblobber',
#   'Bloblobber Deco',
#   'Custom Explosher',
#   'Dread Wringer',
#   'Dread Wringer D',
#   'Explosher',
#   'Slosher',
#   'Slosher Deco',
#   'Sloshing Machine',
#   'Sloshing Machine Neo',
#   'Tri-Slosher',
#   'Tri-Slosher Nouveau',
#   'Ballpoint Splatling',
#   'Ballpoint Splatling Nouveau',
#   'Custom Hydra Splatling',
#   'Heavy Edit Splatling',
#   'Heavy Edit Splatling Nouveau',
#   'Heavy Splatling',
#   'Heavy Splatling Deco',
#   'Hydra Splatling',
#   'Mini Splatling',
#   'Nautilus 47',
#   'Nautilus 79',
#   'Zink Mini Splatling',
#   'Custom Douser Dualies FF',
#   'Custom Dualie Squelchers',
#   'Dapple Dualies',
#   'Dapple Dualies Nouveau',
#   'Dark Tetra Dualies',
#   'Douser Dualies FF',
#   'Dualie Squelchers',
#   'Enperry Splat Dualies',
#   'Glooga Dualies',
#   'Glooga Dualies Deco',
#   'Light Tetra Dualies',
#   'Splat Dualies',
#   'Recycled Brella 24 Mk I',
#   'Recycled Brella 24 Mk II',
#   'Sorella Brella',
#   'Splat Brella',
#   'Tenta Brella',
#   'Tenta Sorella Brella',
#   'Undercover Brella',
#   'Undercover Sorella Brella',
#   'Custom Wellstring V',
#   'Inkline Tri-Stringer',
#   'REEF-LUX 450',
#   'REEF-LUX 450 Deco',
#   'Tri-Stringer',
#   'Wellstring V',
#   'Charcoal Decavitator',
#   'Mint Decavitator',
#   'Splatana Stamper',
#   'Splatana Stamper Nouveau',
#   'Splatana Wiper',
#   'Splatana Wiper Deco'])

# %%
from bs4 import BeautifulSoup
import requests
import time

from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"


# function that returns the data extracted from sendou as a data frame


def extract_sendou_data():
    # call function that returns a
    # list of paths to each weapon's page of builds
    # call function returns the dataframe
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        path, weapon_name = search_for_build_path(link)
        paths = add_to_list(paths, path)
        weapon_names = add_to_list(weapon_names, weapon_name)
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df():
    return None

# %%
weapon_build_paths()
# Out:
# (['https://sendou.ink/builds/52-gal',
#   'https://sendou.ink/builds/52-gal-deco',
#   'https://sendou.ink/builds/96-gal',
#   'https://sendou.ink/builds/96-gal-deco',
#   'https://sendou.ink/builds/aerospray-mg',
#   'https://sendou.ink/builds/aerospray-rg',
#   'https://sendou.ink/builds/annaki-splattershot-nova',
#   'https://sendou.ink/builds/custom-jet-squelcher',
#   'https://sendou.ink/builds/custom-splattershot-jr',
#   'https://sendou.ink/builds/foil-squeezer',
#   'https://sendou.ink/builds/forge-splattershot-pro',
#   'https://sendou.ink/builds/h-3-nozzlenose',
#   'https://sendou.ink/builds/h-3-nozzlenose-d',
#   'https://sendou.ink/builds/jet-squelcher',
#   'https://sendou.ink/builds/l-3-nozzlenose',
#   'https://sendou.ink/builds/l-3-nozzlenose-d',
#   'https://sendou.ink/builds/n-zap-85',
#   'https://sendou.ink/builds/n-zap-89',
#   'https://sendou.ink/builds/neo-splash-o-matic',
#   'https://sendou.ink/builds/neo-sploosh-o-matic',
#   'https://sendou.ink/builds/splash-o-matic',
#   'https://sendou.ink/builds/splattershot',
#   'https://sendou.ink/builds/splattershot-jr',
#   'https://sendou.ink/builds/splattershot-nova',
#   'https://sendou.ink/builds/splattershot-pro',
#   'https://sendou.ink/builds/sploosh-o-matic',
#   'https://sendou.ink/builds/squeezer',
#   'https://sendou.ink/builds/tentatek-splattershot',
#   'https://sendou.ink/builds/blaster',
#   'https://sendou.ink/builds/clash-blaster',
#   'https://sendou.ink/builds/clash-blaster-neo',
#   'https://sendou.ink/builds/custom-blaster',
#   'https://sendou.ink/builds/custom-range-blaster',
#   'https://sendou.ink/builds/luna-blaster',
#   'https://sendou.ink/builds/luna-blaster-neo',
#   'https://sendou.ink/builds/range-blaster',
#   'https://sendou.ink/builds/rapid-blaster',
#   'https://sendou.ink/builds/rapid-blaster-deco',
#   'https://sendou.ink/builds/rapid-blaster-pro',
#   'https://sendou.ink/builds/rapid-blaster-pro-deco',
#   'https://sendou.ink/builds/s-blast-91',
#   'https://sendou.ink/builds/s-blast-92',
#   'https://sendou.ink/builds/big-swig-roller',
#   'https://sendou.ink/builds/big-swig-roller-express',
#   'https://sendou.ink/builds/carbon-roller',
#   'https://sendou.ink/builds/carbon-roller-deco',
#   'https://sendou.ink/builds/dynamo-roller',
#   'https://sendou.ink/builds/flingza-roller',
#   'https://sendou.ink/builds/foil-flingza-roller',
#   'https://sendou.ink/builds/gold-dynamo-roller',
#   'https://sendou.ink/builds/krak-on-splat-roller',
#   'https://sendou.ink/builds/splat-roller',
#   'https://sendou.ink/builds/inkbrush',
#   'https://sendou.ink/builds/inkbrush-nouveau',
#   'https://sendou.ink/builds/octobrush',
#   'https://sendou.ink/builds/octobrush-nouveau',
#   'https://sendou.ink/builds/painbrush',
#   'https://sendou.ink/builds/painbrush-nouveau',
#   'https://sendou.ink/builds/bamboozler-14-mk-i',
#   'https://sendou.ink/builds/bamboozler-14-mk-ii',
#   'https://sendou.ink/builds/classic-squiffer',
#   'https://sendou.ink/builds/custom-e-liter-4k',
#   'https://sendou.ink/builds/custom-e-liter-4k-scope',
#   'https://sendou.ink/builds/custom-goo-tuber',
#   'https://sendou.ink/builds/e-liter-4k',
#   'https://sendou.ink/builds/e-liter-4k-scope',
#   'https://sendou.ink/builds/goo-tuber',
#   'https://sendou.ink/builds/new-squiffer',
#   'https://sendou.ink/builds/snipewriter-5b',
#   'https://sendou.ink/builds/snipewriter-5h',
#   'https://sendou.ink/builds/splat-charger',
#   'https://sendou.ink/builds/splatterscope',
#   'https://sendou.ink/builds/zf-splat-charger',
#   'https://sendou.ink/builds/zf-splatterscope',
#   'https://sendou.ink/builds/bloblobber',
#   'https://sendou.ink/builds/bloblobber-deco',
#   'https://sendou.ink/builds/custom-explosher',
#   'https://sendou.ink/builds/dread-wringer',
#   'https://sendou.ink/builds/dread-wringer-d',
#   'https://sendou.ink/builds/explosher',
#   'https://sendou.ink/builds/slosher',
#   'https://sendou.ink/builds/slosher-deco',
#   'https://sendou.ink/builds/sloshing-machine',
#   'https://sendou.ink/builds/sloshing-machine-neo',
#   'https://sendou.ink/builds/tri-slosher',
#   'https://sendou.ink/builds/tri-slosher-nouveau',
#   'https://sendou.ink/builds/ballpoint-splatling',
#   'https://sendou.ink/builds/ballpoint-splatling-nouveau',
#   'https://sendou.ink/builds/custom-hydra-splatling',
#   'https://sendou.ink/builds/heavy-edit-splatling',
#   'https://sendou.ink/builds/heavy-edit-splatling-nouveau',
#   'https://sendou.ink/builds/heavy-splatling',
#   'https://sendou.ink/builds/heavy-splatling-deco',
#   'https://sendou.ink/builds/hydra-splatling',
#   'https://sendou.ink/builds/mini-splatling',
#   'https://sendou.ink/builds/nautilus-47',
#   'https://sendou.ink/builds/nautilus-79',
#   'https://sendou.ink/builds/zink-mini-splatling',
#   'https://sendou.ink/builds/custom-douser-dualies-ff',
#   'https://sendou.ink/builds/custom-dualie-squelchers',
#   'https://sendou.ink/builds/dapple-dualies',
#   'https://sendou.ink/builds/dapple-dualies-nouveau',
#   'https://sendou.ink/builds/dark-tetra-dualies',
#   'https://sendou.ink/builds/douser-dualies-ff',
#   'https://sendou.ink/builds/dualie-squelchers',
#   'https://sendou.ink/builds/enperry-splat-dualies',
#   'https://sendou.ink/builds/glooga-dualies',
#   'https://sendou.ink/builds/glooga-dualies-deco',
#   'https://sendou.ink/builds/light-tetra-dualies',
#   'https://sendou.ink/builds/splat-dualies',
#   'https://sendou.ink/builds/recycled-brella-24-mk-i',
#   'https://sendou.ink/builds/recycled-brella-24-mk-ii',
#   'https://sendou.ink/builds/sorella-brella',
#   'https://sendou.ink/builds/splat-brella',
#   'https://sendou.ink/builds/tenta-brella',
#   'https://sendou.ink/builds/tenta-sorella-brella',
#   'https://sendou.ink/builds/undercover-brella',
#   'https://sendou.ink/builds/undercover-sorella-brella',
#   'https://sendou.ink/builds/custom-wellstring-v',
#   'https://sendou.ink/builds/inkline-tri-stringer',
#   'https://sendou.ink/builds/reef-lux-450',
#   'https://sendou.ink/builds/reef-lux-450-deco',
#   'https://sendou.ink/builds/tri-stringer',
#   'https://sendou.ink/builds/wellstring-v',
#   'https://sendou.ink/builds/charcoal-decavitator',
#   'https://sendou.ink/builds/mint-decavitator',
#   'https://sendou.ink/builds/splatana-stamper',
#   'https://sendou.ink/builds/splatana-stamper-nouveau',
#   'https://sendou.ink/builds/splatana-wiper',
#   'https://sendou.ink/builds/splatana-wiper-deco'],
#  ['.52 Gal',
#   '.52 Gal Deco',
#   '.96 Gal',
#   '.96 Gal Deco',
#   'Aerospray MG',
#   'Aerospray RG',
#   'Annaki Splattershot Nova',
#   'Custom Jet Squelcher',
#   'Custom Splattershot Jr.',
#   'Foil Squeezer',
#   'Forge Splattershot Pro',
#   'H-3 Nozzlenose',
#   'H-3 Nozzlenose D',
#   'Jet Squelcher',
#   'L-3 Nozzlenose',
#   'L-3 Nozzlenose D',
#   "N-ZAP '85",
#   "N-ZAP '89",
#   'Neo Splash-o-matic',
#   'Neo Sploosh-o-matic',
#   'Splash-o-matic',
#   'Splattershot',
#   'Splattershot Jr.',
#   'Splattershot Nova',
#   'Splattershot Pro',
#   'Sploosh-o-matic',
#   'Squeezer',
#   'Tentatek Splattershot',
#   'Blaster',
#   'Clash Blaster',
#   'Clash Blaster Neo',
#   'Custom Blaster',
#   'Custom Range Blaster',
#   'Luna Blaster',
#   'Luna Blaster Neo',
#   'Range Blaster',
#   'Rapid Blaster',
#   'Rapid Blaster Deco',
#   'Rapid Blaster Pro',
#   'Rapid Blaster Pro Deco',
#   "S-BLAST '91",
#   "S-BLAST '92",
#   'Big Swig Roller',
#   'Big Swig Roller Express',
#   'Carbon Roller',
#   'Carbon Roller Deco',
#   'Dynamo Roller',
#   'Flingza Roller',
#   'Foil Flingza Roller',
#   'Gold Dynamo Roller',
#   'Krak-On Splat Roller',
#   'Splat Roller',
#   'Inkbrush',
#   'Inkbrush Nouveau',
#   'Octobrush',
#   'Octobrush Nouveau',
#   'Painbrush',
#   'Painbrush Nouveau',
#   'Bamboozler 14 Mk I',
#   'Bamboozler 14 Mk II',
#   'Classic Squiffer',
#   'Custom E-liter 4K',
#   'Custom E-liter 4K Scope',
#   'Custom Goo Tuber',
#   'E-liter 4K',
#   'E-liter 4K Scope',
#   'Goo Tuber',
#   'New Squiffer',
#   'Snipewriter 5B',
#   'Snipewriter 5H',
#   'Splat Charger',
#   'Splatterscope',
#   'Z+F Splat Charger',
#   'Z+F Splatterscope',
#   'Bloblobber',
#   'Bloblobber Deco',
#   'Custom Explosher',
#   'Dread Wringer',
#   'Dread Wringer D',
#   'Explosher',
#   'Slosher',
#   'Slosher Deco',
#   'Sloshing Machine',
#   'Sloshing Machine Neo',
#   'Tri-Slosher',
#   'Tri-Slosher Nouveau',
#   'Ballpoint Splatling',
#   'Ballpoint Splatling Nouveau',
#   'Custom Hydra Splatling',
#   'Heavy Edit Splatling',
#   'Heavy Edit Splatling Nouveau',
#   'Heavy Splatling',
#   'Heavy Splatling Deco',
#   'Hydra Splatling',
#   'Mini Splatling',
#   'Nautilus 47',
#   'Nautilus 79',
#   'Zink Mini Splatling',
#   'Custom Douser Dualies FF',
#   'Custom Dualie Squelchers',
#   'Dapple Dualies',
#   'Dapple Dualies Nouveau',
#   'Dark Tetra Dualies',
#   'Douser Dualies FF',
#   'Dualie Squelchers',
#   'Enperry Splat Dualies',
#   'Glooga Dualies',
#   'Glooga Dualies Deco',
#   'Light Tetra Dualies',
#   'Splat Dualies',
#   'Recycled Brella 24 Mk I',
#   'Recycled Brella 24 Mk II',
#   'Sorella Brella',
#   'Splat Brella',
#   'Tenta Brella',
#   'Tenta Sorella Brella',
#   'Undercover Brella',
#   'Undercover Sorella Brella',
#   'Custom Wellstring V',
#   'Inkline Tri-Stringer',
#   'REEF-LUX 450',
#   'REEF-LUX 450 Deco',
#   'Tri-Stringer',
#   'Wellstring V',
#   'Charcoal Decavitator',
#   'Mint Decavitator',
#   'Splatana Stamper',
#   'Splatana Stamper Nouveau',
#   'Splatana Wiper',
#   'Splatana Wiper Deco'])

# %%
# NEXT STEP ADD STUFF
# Do code for ability only

# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd

from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"


# function that returns the data extracted from sendou as a data frame


def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    print(path_list)
    print(weapon_list)
    # call function returns the dataframe
    builds_df = create_weapon_build_df(path_list, weapon_list)
    #print(builds_df)
    display(builds_df)
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        path, weapon_name = search_for_build_path(link)
        paths = add_to_list(paths, path)
        weapon_names = add_to_list(weapon_names, weapon_name)
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    alL_abilities = ['Weapon_name','Main_1', 'Sub_1', 'Sub_2', 'Sub_3','Main_2', 'Sub_4', 'Sub_5', 'Sub_6', 'Main_3', 'Sub_7', 'Sub_8', 'Sub_9']

    df_weapon_builds = pd.DataFrame(columns = alL_abilities) 

    count = 0 
    for path in path_list:
        time.sleep(0.1)
        if count > 10:
            break

        path_soup = BeautifulSoup(make_request(path + '?limit=500').text, "html.parser")
        
        print(weapon_list[count])
        
        build_entries = path_soup.find_all('div', class_='build')
        build_ability_lists = []
        
        for build in build_entries:
        
            abilities = build.find_all('div', class_="build__ability readonly")
            ability_list = [] 
    
            for a in abilities:
                img_tag = a.find('img')
                alt_text = img_tag['alt']          
        
                ability_list.append((alt_text))
                
            df_weapon_builds.loc[len(df_weapon_builds)] = [weapon_list[count]] + ability_list
            build_ability_lists.append(ability_list) 
            
        count += 1
    return df_weapon_builds

# %%
extract_sendou_data()
# Out:
# ['https://sendou.ink/builds/52-gal', 'https://sendou.ink/builds/52-gal-deco', 'https://sendou.ink/builds/96-gal', 'https://sendou.ink/builds/96-gal-deco', 'https://sendou.ink/builds/aerospray-mg', 'https://sendou.ink/builds/aerospray-rg', 'https://sendou.ink/builds/annaki-splattershot-nova', 'https://sendou.ink/builds/custom-jet-squelcher', 'https://sendou.ink/builds/custom-splattershot-jr', 'https://sendou.ink/builds/foil-squeezer', 'https://sendou.ink/builds/forge-splattershot-pro', 'https://sendou.ink/builds/h-3-nozzlenose', 'https://sendou.ink/builds/h-3-nozzlenose-d', 'https://sendou.ink/builds/jet-squelcher', 'https://sendou.ink/builds/l-3-nozzlenose', 'https://sendou.ink/builds/l-3-nozzlenose-d', 'https://sendou.ink/builds/n-zap-85', 'https://sendou.ink/builds/n-zap-89', 'https://sendou.ink/builds/neo-splash-o-matic', 'https://sendou.ink/builds/neo-sploosh-o-matic', 'https://sendou.ink/builds/splash-o-matic', 'https://sendou.ink/builds/splattershot', 'https://sendou.ink/builds/splattershot-jr', 'https://sendou.ink/builds/splattershot-nova', 'https://sendou.ink/builds/splattershot-pro', 'https://sendou.ink/builds/sploosh-o-matic', 'https://sendou.ink/builds/squeezer', 'https://sendou.ink/builds/tentatek-splattershot', 'https://sendou.ink/builds/blaster', 'https://sendou.ink/builds/clash-blaster', 'https://sendou.ink/builds/clash-blaster-neo', 'https://sendou.ink/builds/custom-blaster', 'https://sendou.ink/builds/custom-range-blaster', 'https://sendou.ink/builds/luna-blaster', 'https://sendou.ink/builds/luna-blaster-neo', 'https://sendou.ink/builds/range-blaster', 'https://sendou.ink/builds/rapid-blaster', 'https://sendou.ink/builds/rapid-blaster-deco', 'https://sendou.ink/builds/rapid-blaster-pro', 'https://sendou.ink/builds/rapid-blaster-pro-deco', 'https://sendou.ink/builds/s-blast-91', 'https://sendou.ink/builds/s-blast-92', 'https://sendou.ink/builds/big-swig-roller', 'https://sendou.ink/builds/big-swig-roller-express', 'https://sendou.ink/builds/carbon-roller', 'https://sendou.ink/builds/carbon-roller-deco', 'https://sendou.ink/builds/dynamo-roller', 'https://sendou.ink/builds/flingza-roller', 'https://sendou.ink/builds/foil-flingza-roller', 'https://sendou.ink/builds/gold-dynamo-roller', 'https://sendou.ink/builds/krak-on-splat-roller', 'https://sendou.ink/builds/splat-roller', 'https://sendou.ink/builds/inkbrush', 'https://sendou.ink/builds/inkbrush-nouveau', 'https://sendou.ink/builds/octobrush', 'https://sendou.ink/builds/octobrush-nouveau', 'https://sendou.ink/builds/painbrush', 'https://sendou.ink/builds/painbrush-nouveau', 'https://sendou.ink/builds/bamboozler-14-mk-i', 'https://sendou.ink/builds/bamboozler-14-mk-ii', 'https://sendou.ink/builds/classic-squiffer', 'https://sendou.ink/builds/custom-e-liter-4k', 'https://sendou.ink/builds/custom-e-liter-4k-scope', 'https://sendou.ink/builds/custom-goo-tuber', 'https://sendou.ink/builds/e-liter-4k', 'https://sendou.ink/builds/e-liter-4k-scope', 'https://sendou.ink/builds/goo-tuber', 'https://sendou.ink/builds/new-squiffer', 'https://sendou.ink/builds/snipewriter-5b', 'https://sendou.ink/builds/snipewriter-5h', 'https://sendou.ink/builds/splat-charger', 'https://sendou.ink/builds/splatterscope', 'https://sendou.ink/builds/zf-splat-charger', 'https://sendou.ink/builds/zf-splatterscope', 'https://sendou.ink/builds/bloblobber', 'https://sendou.ink/builds/bloblobber-deco', 'https://sendou.ink/builds/custom-explosher', 'https://sendou.ink/builds/dread-wringer', 'https://sendou.ink/builds/dread-wringer-d', 'https://sendou.ink/builds/explosher', 'https://sendou.ink/builds/slosher', 'https://sendou.ink/builds/slosher-deco', 'https://sendou.ink/builds/sloshing-machine', 'https://sendou.ink/builds/sloshing-machine-neo', 'https://sendou.ink/builds/tri-slosher', 'https://sendou.ink/builds/tri-slosher-nouveau', 'https://sendou.ink/builds/ballpoint-splatling', 'https://sendou.ink/builds/ballpoint-splatling-nouveau', 'https://sendou.ink/builds/custom-hydra-splatling', 'https://s ...
# ['.52 Gal', '.52 Gal Deco', '.96 Gal', '.96 Gal Deco', 'Aerospray MG', 'Aerospray RG', 'Annaki Splattershot Nova', 'Custom Jet Squelcher', 'Custom Splattershot Jr.', 'Foil Squeezer', 'Forge Splattershot Pro', 'H-3 Nozzlenose', 'H-3 Nozzlenose D', 'Jet Squelcher', 'L-3 Nozzlenose', 'L-3 Nozzlenose D', "N-ZAP '85", "N-ZAP '89", 'Neo Splash-o-matic', 'Neo Sploosh-o-matic', 'Splash-o-matic', 'Splattershot', 'Splattershot Jr.', 'Splattershot Nova', 'Splattershot Pro', 'Sploosh-o-matic', 'Squeezer', 'Tentatek Splattershot', 'Blaster', 'Clash Blaster', 'Clash Blaster Neo', 'Custom Blaster', 'Custom Range Blaster', 'Luna Blaster', 'Luna Blaster Neo', 'Range Blaster', 'Rapid Blaster', 'Rapid Blaster Deco', 'Rapid Blaster Pro', 'Rapid Blaster Pro Deco', "S-BLAST '91", "S-BLAST '92", 'Big Swig Roller', 'Big Swig Roller Express', 'Carbon Roller', 'Carbon Roller Deco', 'Dynamo Roller', 'Flingza Roller', 'Foil Flingza Roller', 'Gold Dynamo Roller', 'Krak-On Splat Roller', 'Splat Roller', 'Inkbrush', 'Inkbrush Nouveau', 'Octobrush', 'Octobrush Nouveau', 'Painbrush', 'Painbrush Nouveau', 'Bamboozler 14 Mk I', 'Bamboozler 14 Mk II', 'Classic Squiffer', 'Custom E-liter 4K', 'Custom E-liter 4K Scope', 'Custom Goo Tuber', 'E-liter 4K', 'E-liter 4K Scope', 'Goo Tuber', 'New Squiffer', 'Snipewriter 5B', 'Snipewriter 5H', 'Splat Charger', 'Splatterscope', 'Z+F Splat Charger', 'Z+F Splatterscope', 'Bloblobber', 'Bloblobber Deco', 'Custom Explosher', 'Dread Wringer', 'Dread Wringer D', 'Explosher', 'Slosher', 'Slosher Deco', 'Sloshing Machine', 'Sloshing Machine Neo', 'Tri-Slosher', 'Tri-Slosher Nouveau', 'Ballpoint Splatling', 'Ballpoint Splatling Nouveau', 'Custom Hydra Splatling', 'Heavy Edit Splatling', 'Heavy Edit Splatling Nouveau', 'Heavy Splatling', 'Heavy Splatling Deco', 'Hydra Splatling', 'Mini Splatling', 'Nautilus 47', 'Nautilus 79', 'Zink Mini Splatling', 'Custom Douser Dualies FF', 'Custom Dualie Squelchers', 'Dapple Dualies', 'Dapple Dualies Nouveau', 'Dark Tetra Dualies', 'Douser Dualies FF', 'Dualie Squelchers', 'Enperry Splat Dualies', 'Glooga Dualies', 'Glooga Dualies Deco', 'Light Tetra Dualies', 'Splat Dualies', 'Recycled Brella 24 Mk I', 'Recycled Brella 24 Mk II', 'Sorella Brella', 'Splat Brella', 'Tenta Brella', 'Tenta Sorella Brella', 'Undercover Brella', 'Undercover Sorella Brella', 'Custom Wellstring V', 'Inkline Tri-Stringer', 'REEF-LUX 450', 'REEF-LUX 450 Deco', 'Tri-Stringer', 'Wellstring V', 'Charcoal Decavitator', 'Mint Decavitator', 'Splatana Stamper', 'Splatana Stamper Nouveau', 'Splatana Wiper', 'Splatana Wiper Deco']
# .52 Gal
# .52 Gal Deco
# .96 Gal
# .96 Gal Deco
# Aerospray MG
# Aerospray RG
# Annaki Splattershot Nova
# Custom Jet Squelcher
# Custom Splattershot Jr.
# Foil Squeezer
# Forge Splattershot Pro
#                  Weapon_name             Main_1             Sub_1  \
# 0                    .52 Gal     Opening Gambit  Intensify Action
# 1                    .52 Gal           Comeback  Intensify Action
# 2                    .52 Gal      Swim Speed Up  Intensify Action
# 3                    .52 Gal           Comeback  Intensify Action
# 4                    .52 Gal     Opening Gambit  Intensify Action
# ...                      ...                ...               ...
# 2635  Forge Splattershot Pro  Last-Ditch Effort     Special Saver
# 2636  Forge Splattershot Pro           Comeback     Swim Speed Up
# 2637  Forge Splattershot Pro           Comeback  Ink Saver (Main)
# 2638  Forge Splattershot Pro   Intensify Action     Swim Speed Up
# 2639  Forge Splattershot Pro  Last-Ditch Effort  Quick Super Jump
#
#                  Sub_2              Sub_3            Main_2  \
# 0     Intensify Action   Intensify Action     Swim Speed Up
# 1     Intensify Action   Intensify Action     Swim Speed Up
# 2     Intensify Action   Intensify Action     Swim Speed Up
# 3     Intensify Action   Intensify Action     Swim Speed Up
# 4     Intensify Action   Intensify Action     Swim Speed Up
# ...                ...                ...               ...
# 2635      Sub Power Up   Intensify Action       Thermal Ink
# 2636     Swim Speed Up    Ink Recovery Up  Ink Saver (Main)
# 2637  Ink Saver (Main)  Special Charge Up     Swim Speed Up
# 2638     Swim Speed Up      Swim Speed Up  Ink Saver (Main)
# 2639      Sub Power Up   Intensify Action   Ink Recovery Up
#
#                   Sub_4              Sub_5              Sub_6  \
# 0         Swim Speed Up      Swim Speed Up  Ink Resistance Up
# 1         Swim Speed Up      Swim Speed Up      Special Saver
# 2       Ink Recovery Up      Special Saver   Quick Super Jump
# 3         Swim Speed Up      Swim Speed Up      Swim Speed Up
# 4         Swim Speed Up      Swim Speed Up      Special Saver
# ...                 ...                ...                ...
# 2635    Ink Saver (Sub)    Ink Recovery Up      Swim Speed Up
# 2636  Special Charge Up  Special Charge Up   Quick Super Jump
# 2637      Swim Speed Up      Swim Speed Up      Special Saver
# 2638   Ink Saver (Main)   Quick Super Jump  Ink Resistance Up
# 2639    Ink Recovery Up    Ink Recovery Up  Special Charge Up
#
#                  Main_3              Sub_7              Sub_8  \
# 0          Stealth Jump   Quick Super Jump   Quick Super Jump
# 1          Stealth Jump   Quick Super Jump  Ink Resistance Up
# 2          Stealth Jump  Ink Resistance Up  Sub Resistance Up
# 3          Stealth Jump      Special Saver   Quick Super Jump
# 4          Stealth Jump   Quick Super Jump  Ink Resistance Up
# ...                 ...                ...                ...
# 2635  Special Charge Up  Special Charge Up  Special Charge Up
# 2636       Stealth Jump   Intensify Action   Intensify Action
# 2637       Stealth Jump   Intensify Action   Intensify Action
# 2638       Stealth Jump  Special Charge Up  Special Charge Up
# 2639   Ink Saver (Main)   Ink Saver (Main)   Ink Saver (Main)
#
#                   Sub_9
# 0     Sub Resistance Up
# 1      Intensify Action
# 2      Intensify Action
# 3     Ink Resistance Up
# 4     Sub Resistance Up
# ...                 ...
# 2635   Ink Saver (Main)
# 2636  Ink Resistance Up
# 2637   Quick Super Jump
# 2638  Special Charge Up
# 2639    Ink Saver (Sub)
#
# [2640 rows x 13 columns]

# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd

from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"


# function that returns the data extracted from sendou as a data frame


def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    print(path_list)
    print(weapon_list)
    # call function returns the dataframe
    builds_df = create_weapon_build_df(path_list, weapon_list)
    #print(builds_df)
    display(builds_df)
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        path, weapon_name = search_for_build_path(link)
        paths = add_to_list(paths, path)
        weapon_names = add_to_list(weapon_names, weapon_name)
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    alL_abilities = ['Weapon_name','Main_1', 'Sub_1', 'Sub_2', 'Sub_3','Main_2', 'Sub_4', 'Sub_5', 'Sub_6', 'Main_3', 'Sub_7', 'Sub_8', 'Sub_9']

    df_weapon_builds = pd.DataFrame(columns = alL_abilities) 

    count = 0 
    for path in path_list:
        time.sleep(0.1)
        # if count > 10:
        #     break

        path_soup = BeautifulSoup(make_request(path + '?limit=500').text, "html.parser")
        
        print(weapon_list[count])
        
        build_entries = path_soup.find_all('div', class_='build')
        build_ability_lists = []
        
        for build in build_entries:
        
            abilities = build.find_all('div', class_="build__ability readonly")
            ability_list = [] 
    
            for a in abilities:
                img_tag = a.find('img')
                alt_text = img_tag['alt']          
        
                ability_list.append((alt_text))
                
            df_weapon_builds.loc[len(df_weapon_builds)] = [weapon_list[count]] + ability_list
            build_ability_lists.append(ability_list) 
            
        count += 1
    return df_weapon_builds

# %%
extract_sendou_data()
# Out:
# ['https://sendou.ink/builds/52-gal', 'https://sendou.ink/builds/52-gal-deco', 'https://sendou.ink/builds/96-gal', 'https://sendou.ink/builds/96-gal-deco', 'https://sendou.ink/builds/aerospray-mg', 'https://sendou.ink/builds/aerospray-rg', 'https://sendou.ink/builds/annaki-splattershot-nova', 'https://sendou.ink/builds/custom-jet-squelcher', 'https://sendou.ink/builds/custom-splattershot-jr', 'https://sendou.ink/builds/foil-squeezer', 'https://sendou.ink/builds/forge-splattershot-pro', 'https://sendou.ink/builds/h-3-nozzlenose', 'https://sendou.ink/builds/h-3-nozzlenose-d', 'https://sendou.ink/builds/jet-squelcher', 'https://sendou.ink/builds/l-3-nozzlenose', 'https://sendou.ink/builds/l-3-nozzlenose-d', 'https://sendou.ink/builds/n-zap-85', 'https://sendou.ink/builds/n-zap-89', 'https://sendou.ink/builds/neo-splash-o-matic', 'https://sendou.ink/builds/neo-sploosh-o-matic', 'https://sendou.ink/builds/splash-o-matic', 'https://sendou.ink/builds/splattershot', 'https://sendou.ink/builds/splattershot-jr', 'https://sendou.ink/builds/splattershot-nova', 'https://sendou.ink/builds/splattershot-pro', 'https://sendou.ink/builds/sploosh-o-matic', 'https://sendou.ink/builds/squeezer', 'https://sendou.ink/builds/tentatek-splattershot', 'https://sendou.ink/builds/blaster', 'https://sendou.ink/builds/clash-blaster', 'https://sendou.ink/builds/clash-blaster-neo', 'https://sendou.ink/builds/custom-blaster', 'https://sendou.ink/builds/custom-range-blaster', 'https://sendou.ink/builds/luna-blaster', 'https://sendou.ink/builds/luna-blaster-neo', 'https://sendou.ink/builds/range-blaster', 'https://sendou.ink/builds/rapid-blaster', 'https://sendou.ink/builds/rapid-blaster-deco', 'https://sendou.ink/builds/rapid-blaster-pro', 'https://sendou.ink/builds/rapid-blaster-pro-deco', 'https://sendou.ink/builds/s-blast-91', 'https://sendou.ink/builds/s-blast-92', 'https://sendou.ink/builds/big-swig-roller', 'https://sendou.ink/builds/big-swig-roller-express', 'https://sendou.ink/builds/carbon-roller', 'https://sendou.ink/builds/carbon-roller-deco', 'https://sendou.ink/builds/dynamo-roller', 'https://sendou.ink/builds/flingza-roller', 'https://sendou.ink/builds/foil-flingza-roller', 'https://sendou.ink/builds/gold-dynamo-roller', 'https://sendou.ink/builds/krak-on-splat-roller', 'https://sendou.ink/builds/splat-roller', 'https://sendou.ink/builds/inkbrush', 'https://sendou.ink/builds/inkbrush-nouveau', 'https://sendou.ink/builds/octobrush', 'https://sendou.ink/builds/octobrush-nouveau', 'https://sendou.ink/builds/painbrush', 'https://sendou.ink/builds/painbrush-nouveau', 'https://sendou.ink/builds/bamboozler-14-mk-i', 'https://sendou.ink/builds/bamboozler-14-mk-ii', 'https://sendou.ink/builds/classic-squiffer', 'https://sendou.ink/builds/custom-e-liter-4k', 'https://sendou.ink/builds/custom-e-liter-4k-scope', 'https://sendou.ink/builds/custom-goo-tuber', 'https://sendou.ink/builds/e-liter-4k', 'https://sendou.ink/builds/e-liter-4k-scope', 'https://sendou.ink/builds/goo-tuber', 'https://sendou.ink/builds/new-squiffer', 'https://sendou.ink/builds/snipewriter-5b', 'https://sendou.ink/builds/snipewriter-5h', 'https://sendou.ink/builds/splat-charger', 'https://sendou.ink/builds/splatterscope', 'https://sendou.ink/builds/zf-splat-charger', 'https://sendou.ink/builds/zf-splatterscope', 'https://sendou.ink/builds/bloblobber', 'https://sendou.ink/builds/bloblobber-deco', 'https://sendou.ink/builds/custom-explosher', 'https://sendou.ink/builds/dread-wringer', 'https://sendou.ink/builds/dread-wringer-d', 'https://sendou.ink/builds/explosher', 'https://sendou.ink/builds/slosher', 'https://sendou.ink/builds/slosher-deco', 'https://sendou.ink/builds/sloshing-machine', 'https://sendou.ink/builds/sloshing-machine-neo', 'https://sendou.ink/builds/tri-slosher', 'https://sendou.ink/builds/tri-slosher-nouveau', 'https://sendou.ink/builds/ballpoint-splatling', 'https://sendou.ink/builds/ballpoint-splatling-nouveau', 'https://sendou.ink/builds/custom-hydra-splatling', 'https://s ...
# ['.52 Gal', '.52 Gal Deco', '.96 Gal', '.96 Gal Deco', 'Aerospray MG', 'Aerospray RG', 'Annaki Splattershot Nova', 'Custom Jet Squelcher', 'Custom Splattershot Jr.', 'Foil Squeezer', 'Forge Splattershot Pro', 'H-3 Nozzlenose', 'H-3 Nozzlenose D', 'Jet Squelcher', 'L-3 Nozzlenose', 'L-3 Nozzlenose D', "N-ZAP '85", "N-ZAP '89", 'Neo Splash-o-matic', 'Neo Sploosh-o-matic', 'Splash-o-matic', 'Splattershot', 'Splattershot Jr.', 'Splattershot Nova', 'Splattershot Pro', 'Sploosh-o-matic', 'Squeezer', 'Tentatek Splattershot', 'Blaster', 'Clash Blaster', 'Clash Blaster Neo', 'Custom Blaster', 'Custom Range Blaster', 'Luna Blaster', 'Luna Blaster Neo', 'Range Blaster', 'Rapid Blaster', 'Rapid Blaster Deco', 'Rapid Blaster Pro', 'Rapid Blaster Pro Deco', "S-BLAST '91", "S-BLAST '92", 'Big Swig Roller', 'Big Swig Roller Express', 'Carbon Roller', 'Carbon Roller Deco', 'Dynamo Roller', 'Flingza Roller', 'Foil Flingza Roller', 'Gold Dynamo Roller', 'Krak-On Splat Roller', 'Splat Roller', 'Inkbrush', 'Inkbrush Nouveau', 'Octobrush', 'Octobrush Nouveau', 'Painbrush', 'Painbrush Nouveau', 'Bamboozler 14 Mk I', 'Bamboozler 14 Mk II', 'Classic Squiffer', 'Custom E-liter 4K', 'Custom E-liter 4K Scope', 'Custom Goo Tuber', 'E-liter 4K', 'E-liter 4K Scope', 'Goo Tuber', 'New Squiffer', 'Snipewriter 5B', 'Snipewriter 5H', 'Splat Charger', 'Splatterscope', 'Z+F Splat Charger', 'Z+F Splatterscope', 'Bloblobber', 'Bloblobber Deco', 'Custom Explosher', 'Dread Wringer', 'Dread Wringer D', 'Explosher', 'Slosher', 'Slosher Deco', 'Sloshing Machine', 'Sloshing Machine Neo', 'Tri-Slosher', 'Tri-Slosher Nouveau', 'Ballpoint Splatling', 'Ballpoint Splatling Nouveau', 'Custom Hydra Splatling', 'Heavy Edit Splatling', 'Heavy Edit Splatling Nouveau', 'Heavy Splatling', 'Heavy Splatling Deco', 'Hydra Splatling', 'Mini Splatling', 'Nautilus 47', 'Nautilus 79', 'Zink Mini Splatling', 'Custom Douser Dualies FF', 'Custom Dualie Squelchers', 'Dapple Dualies', 'Dapple Dualies Nouveau', 'Dark Tetra Dualies', 'Douser Dualies FF', 'Dualie Squelchers', 'Enperry Splat Dualies', 'Glooga Dualies', 'Glooga Dualies Deco', 'Light Tetra Dualies', 'Splat Dualies', 'Recycled Brella 24 Mk I', 'Recycled Brella 24 Mk II', 'Sorella Brella', 'Splat Brella', 'Tenta Brella', 'Tenta Sorella Brella', 'Undercover Brella', 'Undercover Sorella Brella', 'Custom Wellstring V', 'Inkline Tri-Stringer', 'REEF-LUX 450', 'REEF-LUX 450 Deco', 'Tri-Stringer', 'Wellstring V', 'Charcoal Decavitator', 'Mint Decavitator', 'Splatana Stamper', 'Splatana Stamper Nouveau', 'Splatana Wiper', 'Splatana Wiper Deco']
# .52 Gal
# .52 Gal Deco
# .96 Gal
# .96 Gal Deco
# Aerospray MG
# Aerospray RG
# Annaki Splattershot Nova
# Custom Jet Squelcher
# Custom Splattershot Jr.
# Foil Squeezer
# Forge Splattershot Pro
# H-3 Nozzlenose
# H-3 Nozzlenose D
# Jet Squelcher
# L-3 Nozzlenose
# L-3 Nozzlenose D
# N-ZAP '85
# N-ZAP '89
# Neo Splash-o-matic
# Neo Sploosh-o-matic
# Splash-o-matic
# Splattershot
# Splattershot Jr.
# Splattershot Nova
# Splattershot Pro
# Sploosh-o-matic
# Squeezer
# Tentatek Splattershot
# Blaster
# Clash Blaster
# Clash Blaster Neo
# Custom Blaster
# Custom Range Blaster
# Luna Blaster
# Luna Blaster Neo
# Range Blaster
# Rapid Blaster
# Rapid Blaster Deco
# Rapid Blaster Pro
# Rapid Blaster Pro Deco
# S-BLAST '91
# S-BLAST '92
# Big Swig Roller
# Big Swig Roller Express
# Carbon Roller
# Carbon Roller Deco
# Dynamo Roller
# Flingza Roller
# Foil Flingza Roller
# Gold Dynamo Roller
# Krak-On Splat Roller
# Splat Roller
# Inkbrush
# Inkbrush Nouveau
# Octobrush
# Octobrush Nouveau
# Painbrush
# Painbrush Nouveau
# Bamboozler 14 Mk I
# Bamboozler 14 Mk II
# Classic Squiffer
# Custom E-liter 4K
# Custom E-liter 4K Scope
# Custom Goo Tuber
# E-liter 4K
# E-liter 4K Scope
# Goo Tuber
# New Squiffer
# Snipewriter 5B
# Snipewriter 5H
# Splat Charger
# Splatterscope
# Z+F Splat Charger
# Z+F Splatterscope
# Bloblobber
# Bloblobber Deco
# Custom Explosher
# Dread Wringer
# Dread Wringer D
# Explosher
# Slosher
# Slosher Deco
# Sloshing Machine
# Sloshing Machine Neo
# Tri-Slosher
# Tri-Slosher Nouveau
# Ballpoint Splatling
# Ballpoint Splatling Nouveau
# Custom Hydra Splatling
# Heavy Edit Splatling
# Heavy Edit Splatling Nouveau
# Heavy Splatling
# Heavy Splatling Deco
# Hydra Splatling
# Mini Splatling
# Nautilus 47
# Nautilus 79
# Zink Mini Splatling
# Custom Douser Dualies FF
# Custom Dualie Squelchers
# Dapple Dualies
# Dapple Dualies Nouveau
# Dark Tetra Dualies
# Douser Dualies FF
# Dualie Squelchers
# Enperry Splat Dualies
# Glooga Dualies
# Glooga Dualies Deco
# Light Tetra Dualies
# Splat Dualies
# Recycled Brella 24 Mk I
# Recycled Brella 24 Mk II
# Sorella Brella
# Splat Brella
# Tenta Brella
# Tenta Sorella Brella
# Undercover Brella
# Undercover Sorella Brella
# Custom Wellstring V
# Inkline Tri-Stringer
# REEF-LUX 450
# REEF-LUX 450 Deco
# Tri-Stringer
# Wellstring V
# Charcoal Decavitator
# Mint Decavitator
# Splatana Stamper
# Splatana Stamper Nouveau
# Splatana Wiper
# Splatana Wiper Deco
#                Weapon_name          Main_1              Sub_1  \
# 0                  .52 Gal  Opening Gambit   Intensify Action
# 1                  .52 Gal        Comeback   Intensify Action
# 2                  .52 Gal   Swim Speed Up   Intensify Action
# 3                  .52 Gal        Comeback   Intensify Action
# 4                  .52 Gal  Opening Gambit   Intensify Action
# ...                    ...             ...                ...
# 30300  Splatana Wiper Deco    Sub Power Up    Ink Saver (Sub)
# 30301  Splatana Wiper Deco        Comeback      Quick Respawn
# 30302  Splatana Wiper Deco        Comeback      Quick Respawn
# 30303  Splatana Wiper Deco    Sub Power Up       Sub Power Up
# 30304  Splatana Wiper Deco        Comeback  Special Charge Up
#
#                    Sub_2              Sub_3         Main_2              Sub_4  \
# 0       Intensify Action   Intensify Action  Swim Speed Up      Swim Speed Up
# 1       Intensify Action   Intensify Action  Swim Speed Up      Swim Speed Up
# 2       Intensify Action   Intensify Action  Swim Speed Up    Ink Recovery Up
# 3       Intensify Action   Intensify Action  Swim Speed Up      Swim Speed Up
# 4       Intensify Action   Intensify Action  Swim Speed Up      Swim Speed Up
# ...                  ...                ...            ...                ...
# 30300    Ink Saver (Sub)    Ink Saver (Sub)  Swim Speed Up      Swim Speed Up
# 30301      Quick Respawn      Quick Respawn          Haunt      Swim Speed Up
# 30302      Quick Respawn      Quick Respawn   Sub Power Up  Special Charge Up
# 30303       Sub Power Up   Quick Super Jump  Swim Speed Up      Swim Speed Up
# 30304  Special Charge Up  Special Charge Up    Ninja Squid      Quick Respawn
#
#                    Sub_5              Sub_6        Main_3              Sub_7  \
# 0          Swim Speed Up  Ink Resistance Up  Stealth Jump   Quick Super Jump
# 1          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# 2          Special Saver   Quick Super Jump  Stealth Jump  Ink Resistance Up
# 3          Swim Speed Up      Swim Speed Up  Stealth Jump      Special Saver
# 4          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# ...                  ...                ...           ...                ...
# 30300  Ink Resistance Up  Sub Resistance Up  Stealth Jump   Quick Super Jump
# 30301      Swim Speed Up       Sub Power Up  Stealth Jump      Quick Respawn
# 30302  Special Charge Up  Special Charge Up  Stealth Jump      Quick Respawn
# 30303      Swim Speed Up  Special Charge Up  Stealth Jump      Quick Respawn
# 30304      Quick Respawn      Swim Speed Up  Stealth Jump      Special Saver
#
#                    Sub_8              Sub_9
# 0       Quick Super Jump  Sub Resistance Up
# 1      Ink Resistance Up   Intensify Action
# 2      Sub Resistance Up   Intensify Action
# 3       Quick Super Jump  Ink Resistance Up
# 4      Ink Resistance Up  Sub Resistance Up
# ...                  ...                ...
# 30300   Quick Super Jump   Quick Super Jump
# 30301      Quick Respawn       Sub Power Up
# 30302   Quick Super Jump       Sub Power Up
# 30303      Quick Respawn      Special Saver
# 30304   Quick Super Jump  Sub Resistance Up
#
# [30305 rows x 13 columns]

# %%
# Do code for mode only

# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd

from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"


# function that returns the data extracted from sendou as a data frame


def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    print(path_list)
    print(weapon_list)
    # call function returns the dataframe
    builds_df = create_weapon_build_df(path_list, weapon_list)
    #print(builds_df)
    display(builds_df)
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        path, weapon_name = search_for_build_path(link)
        paths = add_to_list(paths, path)
        weapon_names = add_to_list(weapon_names, weapon_name)
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    all_modes = ['Weapon_name','game_modes']

    count = 0

    df_weapon_builds_2 = pd.DataFrame(columns = all_modes) 

    for path in path_list:
        
        if count  >10:
            break
        
        path_soup = BeautifulSoup(make_request(path + '?limit=500').text, "html.parser")
        
        print(weapon_list[count])
        

        # ------------------------------
        
        build_entries =  path_soup.find_all('div', class_='build')

        for build in build_entries:
            mode_list = []
            
            modes = build.find('div', class_='build__modes')
            
            
            if modes is None:
                mode_list = ['NO MODES LISTED']

            elif modes is not None:
                    

                img_tags = modes.find_all('img')

                for i in img_tags:
                    alt_text = i['alt']
                    mode_list.append(alt_text)
                
            #df_weapon_builds_2 = pd.concat([df_weapon_builds_2, pd.DataFrame([[weapon_list[count], mode_list]], columns=all_modes)], ignore_index=True)
            df_weapon_builds_2.loc[len(df_weapon_builds_2)] = [weapon_list[count],mode_list]
        
        count += 1
        
    return df_weapon_builds_2

# %%
extract_sendou_data()
# Out:
# ['https://sendou.ink/builds/52-gal', 'https://sendou.ink/builds/52-gal-deco', 'https://sendou.ink/builds/96-gal', 'https://sendou.ink/builds/96-gal-deco', 'https://sendou.ink/builds/aerospray-mg', 'https://sendou.ink/builds/aerospray-rg', 'https://sendou.ink/builds/annaki-splattershot-nova', 'https://sendou.ink/builds/custom-jet-squelcher', 'https://sendou.ink/builds/custom-splattershot-jr', 'https://sendou.ink/builds/foil-squeezer', 'https://sendou.ink/builds/forge-splattershot-pro', 'https://sendou.ink/builds/h-3-nozzlenose', 'https://sendou.ink/builds/h-3-nozzlenose-d', 'https://sendou.ink/builds/jet-squelcher', 'https://sendou.ink/builds/l-3-nozzlenose', 'https://sendou.ink/builds/l-3-nozzlenose-d', 'https://sendou.ink/builds/n-zap-85', 'https://sendou.ink/builds/n-zap-89', 'https://sendou.ink/builds/neo-splash-o-matic', 'https://sendou.ink/builds/neo-sploosh-o-matic', 'https://sendou.ink/builds/splash-o-matic', 'https://sendou.ink/builds/splattershot', 'https://sendou.ink/builds/splattershot-jr', 'https://sendou.ink/builds/splattershot-nova', 'https://sendou.ink/builds/splattershot-pro', 'https://sendou.ink/builds/sploosh-o-matic', 'https://sendou.ink/builds/squeezer', 'https://sendou.ink/builds/tentatek-splattershot', 'https://sendou.ink/builds/blaster', 'https://sendou.ink/builds/clash-blaster', 'https://sendou.ink/builds/clash-blaster-neo', 'https://sendou.ink/builds/custom-blaster', 'https://sendou.ink/builds/custom-range-blaster', 'https://sendou.ink/builds/luna-blaster', 'https://sendou.ink/builds/luna-blaster-neo', 'https://sendou.ink/builds/range-blaster', 'https://sendou.ink/builds/rapid-blaster', 'https://sendou.ink/builds/rapid-blaster-deco', 'https://sendou.ink/builds/rapid-blaster-pro', 'https://sendou.ink/builds/rapid-blaster-pro-deco', 'https://sendou.ink/builds/s-blast-91', 'https://sendou.ink/builds/s-blast-92', 'https://sendou.ink/builds/big-swig-roller', 'https://sendou.ink/builds/big-swig-roller-express', 'https://sendou.ink/builds/carbon-roller', 'https://sendou.ink/builds/carbon-roller-deco', 'https://sendou.ink/builds/dynamo-roller', 'https://sendou.ink/builds/flingza-roller', 'https://sendou.ink/builds/foil-flingza-roller', 'https://sendou.ink/builds/gold-dynamo-roller', 'https://sendou.ink/builds/krak-on-splat-roller', 'https://sendou.ink/builds/splat-roller', 'https://sendou.ink/builds/inkbrush', 'https://sendou.ink/builds/inkbrush-nouveau', 'https://sendou.ink/builds/octobrush', 'https://sendou.ink/builds/octobrush-nouveau', 'https://sendou.ink/builds/painbrush', 'https://sendou.ink/builds/painbrush-nouveau', 'https://sendou.ink/builds/bamboozler-14-mk-i', 'https://sendou.ink/builds/bamboozler-14-mk-ii', 'https://sendou.ink/builds/classic-squiffer', 'https://sendou.ink/builds/custom-e-liter-4k', 'https://sendou.ink/builds/custom-e-liter-4k-scope', 'https://sendou.ink/builds/custom-goo-tuber', 'https://sendou.ink/builds/e-liter-4k', 'https://sendou.ink/builds/e-liter-4k-scope', 'https://sendou.ink/builds/goo-tuber', 'https://sendou.ink/builds/new-squiffer', 'https://sendou.ink/builds/snipewriter-5b', 'https://sendou.ink/builds/snipewriter-5h', 'https://sendou.ink/builds/splat-charger', 'https://sendou.ink/builds/splatterscope', 'https://sendou.ink/builds/zf-splat-charger', 'https://sendou.ink/builds/zf-splatterscope', 'https://sendou.ink/builds/bloblobber', 'https://sendou.ink/builds/bloblobber-deco', 'https://sendou.ink/builds/custom-explosher', 'https://sendou.ink/builds/dread-wringer', 'https://sendou.ink/builds/dread-wringer-d', 'https://sendou.ink/builds/explosher', 'https://sendou.ink/builds/slosher', 'https://sendou.ink/builds/slosher-deco', 'https://sendou.ink/builds/sloshing-machine', 'https://sendou.ink/builds/sloshing-machine-neo', 'https://sendou.ink/builds/tri-slosher', 'https://sendou.ink/builds/tri-slosher-nouveau', 'https://sendou.ink/builds/ballpoint-splatling', 'https://sendou.ink/builds/ballpoint-splatling-nouveau', 'https://sendou.ink/builds/custom-hydra-splatling', 'https://s ...
# ['.52 Gal', '.52 Gal Deco', '.96 Gal', '.96 Gal Deco', 'Aerospray MG', 'Aerospray RG', 'Annaki Splattershot Nova', 'Custom Jet Squelcher', 'Custom Splattershot Jr.', 'Foil Squeezer', 'Forge Splattershot Pro', 'H-3 Nozzlenose', 'H-3 Nozzlenose D', 'Jet Squelcher', 'L-3 Nozzlenose', 'L-3 Nozzlenose D', "N-ZAP '85", "N-ZAP '89", 'Neo Splash-o-matic', 'Neo Sploosh-o-matic', 'Splash-o-matic', 'Splattershot', 'Splattershot Jr.', 'Splattershot Nova', 'Splattershot Pro', 'Sploosh-o-matic', 'Squeezer', 'Tentatek Splattershot', 'Blaster', 'Clash Blaster', 'Clash Blaster Neo', 'Custom Blaster', 'Custom Range Blaster', 'Luna Blaster', 'Luna Blaster Neo', 'Range Blaster', 'Rapid Blaster', 'Rapid Blaster Deco', 'Rapid Blaster Pro', 'Rapid Blaster Pro Deco', "S-BLAST '91", "S-BLAST '92", 'Big Swig Roller', 'Big Swig Roller Express', 'Carbon Roller', 'Carbon Roller Deco', 'Dynamo Roller', 'Flingza Roller', 'Foil Flingza Roller', 'Gold Dynamo Roller', 'Krak-On Splat Roller', 'Splat Roller', 'Inkbrush', 'Inkbrush Nouveau', 'Octobrush', 'Octobrush Nouveau', 'Painbrush', 'Painbrush Nouveau', 'Bamboozler 14 Mk I', 'Bamboozler 14 Mk II', 'Classic Squiffer', 'Custom E-liter 4K', 'Custom E-liter 4K Scope', 'Custom Goo Tuber', 'E-liter 4K', 'E-liter 4K Scope', 'Goo Tuber', 'New Squiffer', 'Snipewriter 5B', 'Snipewriter 5H', 'Splat Charger', 'Splatterscope', 'Z+F Splat Charger', 'Z+F Splatterscope', 'Bloblobber', 'Bloblobber Deco', 'Custom Explosher', 'Dread Wringer', 'Dread Wringer D', 'Explosher', 'Slosher', 'Slosher Deco', 'Sloshing Machine', 'Sloshing Machine Neo', 'Tri-Slosher', 'Tri-Slosher Nouveau', 'Ballpoint Splatling', 'Ballpoint Splatling Nouveau', 'Custom Hydra Splatling', 'Heavy Edit Splatling', 'Heavy Edit Splatling Nouveau', 'Heavy Splatling', 'Heavy Splatling Deco', 'Hydra Splatling', 'Mini Splatling', 'Nautilus 47', 'Nautilus 79', 'Zink Mini Splatling', 'Custom Douser Dualies FF', 'Custom Dualie Squelchers', 'Dapple Dualies', 'Dapple Dualies Nouveau', 'Dark Tetra Dualies', 'Douser Dualies FF', 'Dualie Squelchers', 'Enperry Splat Dualies', 'Glooga Dualies', 'Glooga Dualies Deco', 'Light Tetra Dualies', 'Splat Dualies', 'Recycled Brella 24 Mk I', 'Recycled Brella 24 Mk II', 'Sorella Brella', 'Splat Brella', 'Tenta Brella', 'Tenta Sorella Brella', 'Undercover Brella', 'Undercover Sorella Brella', 'Custom Wellstring V', 'Inkline Tri-Stringer', 'REEF-LUX 450', 'REEF-LUX 450 Deco', 'Tri-Stringer', 'Wellstring V', 'Charcoal Decavitator', 'Mint Decavitator', 'Splatana Stamper', 'Splatana Stamper Nouveau', 'Splatana Wiper', 'Splatana Wiper Deco']
# .52 Gal
# .52 Gal Deco
# .96 Gal
# .96 Gal Deco
# Aerospray MG
# Aerospray RG
# Annaki Splattershot Nova
# Custom Jet Squelcher
# Custom Splattershot Jr.
# Foil Squeezer
# Forge Splattershot Pro
#                  Weapon_name  \
# 0                    .52 Gal
# 1                    .52 Gal
# 2                    .52 Gal
# 3                    .52 Gal
# 4                    .52 Gal
# ...                      ...
# 2635  Forge Splattershot Pro
# 2636  Forge Splattershot Pro
# 2637  Forge Splattershot Pro
# 2638  Forge Splattershot Pro
# 2639  Forge Splattershot Pro
#
#                                              game_modes
# 0     [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1     [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2     [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3     [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4     [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                                                 ...
# 2635  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2636  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2637  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2638  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2639                            [Turf War, Splat Zones]
#
# [2640 rows x 2 columns]

# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd

from etl.extract.extract import make_request

# defining constants:
SENDOU_BUILDS_URL = "https://sendou.ink/builds"
SENDOU_BASE_URL = "https://sendou.ink"


# function that returns the data extracted from sendou as a data frame


def extract_sendou_data():
    # call function that returns a
    # lists of paths to each weapon's page of builds
    # and it's weapon name
    path_list, weapon_list = weapon_build_paths()
    print(path_list)
    print(weapon_list)
    # call function returns the dataframe
    builds_df = create_weapon_build_df(path_list, weapon_list)
    #print(builds_df)
    display(builds_df)
    return None


# function to find paths for weapon build pages
def weapon_build_paths():
    # making a request to 'https://sendou.ink/builds'
    soup = BeautifulSoup(make_request(SENDOU_BUILDS_URL).text, "html.parser")

    paths = []  # empty list for storing paths
    weapon_names = []  # empty list for storing weapon names

    all_links = soup.find_all("a")  # list of all hyperlinks on the page

    # loop through all the links
    for link in all_links:
        path, weapon_name = search_for_build_path(link)
        paths = add_to_list(paths, path)
        weapon_names = add_to_list(weapon_names, weapon_name)
    if len(paths) == len(weapon_names):
        return paths, weapon_names
    else:
        raise Exception("Error: number of paths and weapon names don't match")


# function to find the build paths
def search_for_build_path(link):
    href = link.get("href")  # the href of attribute of <a>
    # make sure that the <a> has href
    if href is not None:
        # if href is not none
        # then continue to check if the link is for a weapon build page
        if href.startswith("/builds/"):
            # if it is then add the base path to the end and return this value
            path = SENDOU_BASE_URL + href
            # also find the text of the link (with strip remove whitespaces)
            text = link.get_text(strip=True)
            # if text is not none assign it to weapon_name
            if text is not None:
                weapon_name = text
            else:
                return None, None
            # brief pause between each path retrieval
            # (avoid overwhelming the website)
            time.sleep(0.1)
            # return the path and weapon name associated with the link
            return path, weapon_name
    return None, None


def add_to_list(the_list, element):
    if element is not None:
        the_list.append(element)
    return the_list


# function to create a dataframe from the the weapon build data
def create_weapon_build_df(path_list, weapon_list):
    all_modes = ['Weapon_name','game_modes']

    count = 0

    df_weapon_builds_2 = pd.DataFrame(columns = all_modes) 

    for path in path_list:
        time.sleep(0.1)
        # if count  >10:
        #     break
        
        path_soup = BeautifulSoup(make_request(path + '?limit=500').text, "html.parser")
        
        print(weapon_list[count])
        

        # ------------------------------
        
        build_entries =  path_soup.find_all('div', class_='build')

        for build in build_entries:
            mode_list = []
            
            modes = build.find('div', class_='build__modes')
            
            
            if modes is None:
                mode_list = ['NO MODES LISTED']

            elif modes is not None:
                    

                img_tags = modes.find_all('img')

                for i in img_tags:
                    alt_text = i['alt']
                    mode_list.append(alt_text)
                
            #df_weapon_builds_2 = pd.concat([df_weapon_builds_2, pd.DataFrame([[weapon_list[count], mode_list]], columns=all_modes)], ignore_index=True)
            df_weapon_builds_2.loc[len(df_weapon_builds_2)] = [weapon_list[count],mode_list]
        
        count += 1
        
    return df_weapon_builds_2

# %%
extract_sendou_data()
# Out:
# ['https://sendou.ink/builds/52-gal', 'https://sendou.ink/builds/52-gal-deco', 'https://sendou.ink/builds/96-gal', 'https://sendou.ink/builds/96-gal-deco', 'https://sendou.ink/builds/aerospray-mg', 'https://sendou.ink/builds/aerospray-rg', 'https://sendou.ink/builds/annaki-splattershot-nova', 'https://sendou.ink/builds/custom-jet-squelcher', 'https://sendou.ink/builds/custom-splattershot-jr', 'https://sendou.ink/builds/foil-squeezer', 'https://sendou.ink/builds/forge-splattershot-pro', 'https://sendou.ink/builds/h-3-nozzlenose', 'https://sendou.ink/builds/h-3-nozzlenose-d', 'https://sendou.ink/builds/jet-squelcher', 'https://sendou.ink/builds/l-3-nozzlenose', 'https://sendou.ink/builds/l-3-nozzlenose-d', 'https://sendou.ink/builds/n-zap-85', 'https://sendou.ink/builds/n-zap-89', 'https://sendou.ink/builds/neo-splash-o-matic', 'https://sendou.ink/builds/neo-sploosh-o-matic', 'https://sendou.ink/builds/splash-o-matic', 'https://sendou.ink/builds/splattershot', 'https://sendou.ink/builds/splattershot-jr', 'https://sendou.ink/builds/splattershot-nova', 'https://sendou.ink/builds/splattershot-pro', 'https://sendou.ink/builds/sploosh-o-matic', 'https://sendou.ink/builds/squeezer', 'https://sendou.ink/builds/tentatek-splattershot', 'https://sendou.ink/builds/blaster', 'https://sendou.ink/builds/clash-blaster', 'https://sendou.ink/builds/clash-blaster-neo', 'https://sendou.ink/builds/custom-blaster', 'https://sendou.ink/builds/custom-range-blaster', 'https://sendou.ink/builds/luna-blaster', 'https://sendou.ink/builds/luna-blaster-neo', 'https://sendou.ink/builds/range-blaster', 'https://sendou.ink/builds/rapid-blaster', 'https://sendou.ink/builds/rapid-blaster-deco', 'https://sendou.ink/builds/rapid-blaster-pro', 'https://sendou.ink/builds/rapid-blaster-pro-deco', 'https://sendou.ink/builds/s-blast-91', 'https://sendou.ink/builds/s-blast-92', 'https://sendou.ink/builds/big-swig-roller', 'https://sendou.ink/builds/big-swig-roller-express', 'https://sendou.ink/builds/carbon-roller', 'https://sendou.ink/builds/carbon-roller-deco', 'https://sendou.ink/builds/dynamo-roller', 'https://sendou.ink/builds/flingza-roller', 'https://sendou.ink/builds/foil-flingza-roller', 'https://sendou.ink/builds/gold-dynamo-roller', 'https://sendou.ink/builds/krak-on-splat-roller', 'https://sendou.ink/builds/splat-roller', 'https://sendou.ink/builds/inkbrush', 'https://sendou.ink/builds/inkbrush-nouveau', 'https://sendou.ink/builds/octobrush', 'https://sendou.ink/builds/octobrush-nouveau', 'https://sendou.ink/builds/painbrush', 'https://sendou.ink/builds/painbrush-nouveau', 'https://sendou.ink/builds/bamboozler-14-mk-i', 'https://sendou.ink/builds/bamboozler-14-mk-ii', 'https://sendou.ink/builds/classic-squiffer', 'https://sendou.ink/builds/custom-e-liter-4k', 'https://sendou.ink/builds/custom-e-liter-4k-scope', 'https://sendou.ink/builds/custom-goo-tuber', 'https://sendou.ink/builds/e-liter-4k', 'https://sendou.ink/builds/e-liter-4k-scope', 'https://sendou.ink/builds/goo-tuber', 'https://sendou.ink/builds/new-squiffer', 'https://sendou.ink/builds/snipewriter-5b', 'https://sendou.ink/builds/snipewriter-5h', 'https://sendou.ink/builds/splat-charger', 'https://sendou.ink/builds/splatterscope', 'https://sendou.ink/builds/zf-splat-charger', 'https://sendou.ink/builds/zf-splatterscope', 'https://sendou.ink/builds/bloblobber', 'https://sendou.ink/builds/bloblobber-deco', 'https://sendou.ink/builds/custom-explosher', 'https://sendou.ink/builds/dread-wringer', 'https://sendou.ink/builds/dread-wringer-d', 'https://sendou.ink/builds/explosher', 'https://sendou.ink/builds/slosher', 'https://sendou.ink/builds/slosher-deco', 'https://sendou.ink/builds/sloshing-machine', 'https://sendou.ink/builds/sloshing-machine-neo', 'https://sendou.ink/builds/tri-slosher', 'https://sendou.ink/builds/tri-slosher-nouveau', 'https://sendou.ink/builds/ballpoint-splatling', 'https://sendou.ink/builds/ballpoint-splatling-nouveau', 'https://sendou.ink/builds/custom-hydra-splatling', 'https://s ...
# ['.52 Gal', '.52 Gal Deco', '.96 Gal', '.96 Gal Deco', 'Aerospray MG', 'Aerospray RG', 'Annaki Splattershot Nova', 'Custom Jet Squelcher', 'Custom Splattershot Jr.', 'Foil Squeezer', 'Forge Splattershot Pro', 'H-3 Nozzlenose', 'H-3 Nozzlenose D', 'Jet Squelcher', 'L-3 Nozzlenose', 'L-3 Nozzlenose D', "N-ZAP '85", "N-ZAP '89", 'Neo Splash-o-matic', 'Neo Sploosh-o-matic', 'Splash-o-matic', 'Splattershot', 'Splattershot Jr.', 'Splattershot Nova', 'Splattershot Pro', 'Sploosh-o-matic', 'Squeezer', 'Tentatek Splattershot', 'Blaster', 'Clash Blaster', 'Clash Blaster Neo', 'Custom Blaster', 'Custom Range Blaster', 'Luna Blaster', 'Luna Blaster Neo', 'Range Blaster', 'Rapid Blaster', 'Rapid Blaster Deco', 'Rapid Blaster Pro', 'Rapid Blaster Pro Deco', "S-BLAST '91", "S-BLAST '92", 'Big Swig Roller', 'Big Swig Roller Express', 'Carbon Roller', 'Carbon Roller Deco', 'Dynamo Roller', 'Flingza Roller', 'Foil Flingza Roller', 'Gold Dynamo Roller', 'Krak-On Splat Roller', 'Splat Roller', 'Inkbrush', 'Inkbrush Nouveau', 'Octobrush', 'Octobrush Nouveau', 'Painbrush', 'Painbrush Nouveau', 'Bamboozler 14 Mk I', 'Bamboozler 14 Mk II', 'Classic Squiffer', 'Custom E-liter 4K', 'Custom E-liter 4K Scope', 'Custom Goo Tuber', 'E-liter 4K', 'E-liter 4K Scope', 'Goo Tuber', 'New Squiffer', 'Snipewriter 5B', 'Snipewriter 5H', 'Splat Charger', 'Splatterscope', 'Z+F Splat Charger', 'Z+F Splatterscope', 'Bloblobber', 'Bloblobber Deco', 'Custom Explosher', 'Dread Wringer', 'Dread Wringer D', 'Explosher', 'Slosher', 'Slosher Deco', 'Sloshing Machine', 'Sloshing Machine Neo', 'Tri-Slosher', 'Tri-Slosher Nouveau', 'Ballpoint Splatling', 'Ballpoint Splatling Nouveau', 'Custom Hydra Splatling', 'Heavy Edit Splatling', 'Heavy Edit Splatling Nouveau', 'Heavy Splatling', 'Heavy Splatling Deco', 'Hydra Splatling', 'Mini Splatling', 'Nautilus 47', 'Nautilus 79', 'Zink Mini Splatling', 'Custom Douser Dualies FF', 'Custom Dualie Squelchers', 'Dapple Dualies', 'Dapple Dualies Nouveau', 'Dark Tetra Dualies', 'Douser Dualies FF', 'Dualie Squelchers', 'Enperry Splat Dualies', 'Glooga Dualies', 'Glooga Dualies Deco', 'Light Tetra Dualies', 'Splat Dualies', 'Recycled Brella 24 Mk I', 'Recycled Brella 24 Mk II', 'Sorella Brella', 'Splat Brella', 'Tenta Brella', 'Tenta Sorella Brella', 'Undercover Brella', 'Undercover Sorella Brella', 'Custom Wellstring V', 'Inkline Tri-Stringer', 'REEF-LUX 450', 'REEF-LUX 450 Deco', 'Tri-Stringer', 'Wellstring V', 'Charcoal Decavitator', 'Mint Decavitator', 'Splatana Stamper', 'Splatana Stamper Nouveau', 'Splatana Wiper', 'Splatana Wiper Deco']
# .52 Gal
# .52 Gal Deco
# .96 Gal
# .96 Gal Deco
# Aerospray MG
# Aerospray RG
# Annaki Splattershot Nova
# Custom Jet Squelcher
# Custom Splattershot Jr.
# Foil Squeezer
# Forge Splattershot Pro
# H-3 Nozzlenose
# H-3 Nozzlenose D
# Jet Squelcher
# L-3 Nozzlenose
# L-3 Nozzlenose D
# N-ZAP '85
# N-ZAP '89
# Neo Splash-o-matic
# Neo Sploosh-o-matic
# Splash-o-matic
# Splattershot
# Splattershot Jr.
# Splattershot Nova
# Splattershot Pro
# Sploosh-o-matic
# Squeezer
# Tentatek Splattershot
# Blaster
# Clash Blaster
# Clash Blaster Neo
# Custom Blaster
# Custom Range Blaster
# Luna Blaster
# Luna Blaster Neo
# Range Blaster
# Rapid Blaster
# Rapid Blaster Deco
# Rapid Blaster Pro
# Rapid Blaster Pro Deco
# S-BLAST '91
# S-BLAST '92
# Big Swig Roller
# Big Swig Roller Express
# Carbon Roller
# Carbon Roller Deco
# Dynamo Roller
# Flingza Roller
# Foil Flingza Roller
# Gold Dynamo Roller
# Krak-On Splat Roller
# Splat Roller
# Inkbrush
# Inkbrush Nouveau
# Octobrush
# Octobrush Nouveau
# Painbrush
# Painbrush Nouveau
# Bamboozler 14 Mk I
# Bamboozler 14 Mk II
# Classic Squiffer
# Custom E-liter 4K
# Custom E-liter 4K Scope
# Custom Goo Tuber
# E-liter 4K
# E-liter 4K Scope
# Goo Tuber
# New Squiffer
# Snipewriter 5B
# Snipewriter 5H
# Splat Charger
# Splatterscope
# Z+F Splat Charger
# Z+F Splatterscope
# Bloblobber
# Bloblobber Deco
# Custom Explosher
# Dread Wringer
# Dread Wringer D
# Explosher
# Slosher
# Slosher Deco
# Sloshing Machine
# Sloshing Machine Neo
# Tri-Slosher
# Tri-Slosher Nouveau
# Ballpoint Splatling
# Ballpoint Splatling Nouveau
# Custom Hydra Splatling
# Heavy Edit Splatling
# Heavy Edit Splatling Nouveau
# Heavy Splatling
# Heavy Splatling Deco
# Hydra Splatling
# Mini Splatling
# Nautilus 47
# Nautilus 79
# Zink Mini Splatling
# Custom Douser Dualies FF
# Custom Dualie Squelchers
# Dapple Dualies
# Dapple Dualies Nouveau
# Dark Tetra Dualies
# Douser Dualies FF
# Dualie Squelchers
# Enperry Splat Dualies
# Glooga Dualies
# Glooga Dualies Deco
# Light Tetra Dualies
# Splat Dualies
# Recycled Brella 24 Mk I
# Recycled Brella 24 Mk II
# Sorella Brella
# Splat Brella
# Tenta Brella
# Tenta Sorella Brella
# Undercover Brella
# Undercover Sorella Brella
# Custom Wellstring V
# Inkline Tri-Stringer
# REEF-LUX 450
# REEF-LUX 450 Deco
# Tri-Stringer
# Wellstring V
# Charcoal Decavitator
# Mint Decavitator
# Splatana Stamper
# Splatana Stamper Nouveau
# Splatana Wiper
# Splatana Wiper Deco
#                Weapon_name                                         game_modes
# 0                  .52 Gal  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1                  .52 Gal  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2                  .52 Gal  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3                  .52 Gal  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4                  .52 Gal  [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                    ...                                                ...
# 30300  Splatana Wiper Deco  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30301  Splatana Wiper Deco  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30302  Splatana Wiper Deco  [Turf War, Splat Zones, Tower Control, Clam Bl...
# 30303  Splatana Wiper Deco  [Turf War, Splat Zones, Tower Control, Rainmaker]
# 30304  Splatana Wiper Deco  [Splat Zones, Tower Control, Rainmaker, Clam B...
#
# [30305 rows x 2 columns]
