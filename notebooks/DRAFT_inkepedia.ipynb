# %%
from bs4 import BeautifulSoup  ## the BeautifulSoup library for scraping from the bs4 package
import pandas as pd ## Import the pandas library for data manipulation and analysis
from etl.extract.extract import make_request

site = 'https://splatoonwiki.org/wiki/List_of_main_weapons_in_Splatoon_3' ## The website we want to scrape

soup = BeautifulSoup(make_request(site).text, "html.parser")

power_elements = soup.find_all('tr')
new_list = []
# Iterate through the list and print each element's text
for element in power_elements:
    #print(element.get_text(strip=True))
    temp = element.find_all('td')
    #new_list.append(element.get_text(strip=True))
    for i in temp:
        new_list.append(i.get_text(strip=True))

print(new_list)

# obtain groups of 10 for each weapon:

elm_index = 0
array_2d = []
for elm in range(0,len(new_list),10):
    one_weapon = new_list[elm:elm+10]
    #print(one_weapon)
    array_2d.append(one_weapon)
print(array_2d)

df = pd.DataFrame(array_2d, columns=['Extra_space','Name', 'ID', 'Sub','Special','Special_Points', 'Level', 'Price', 'Class', 'Introduced']) 
df
# Out:
# ['', 'Sploosh-o-matic', '0', 'Curling Bomb', 'Ultra Stamp', '180p', '9', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', 'Neo Sploosh-o-matic', '1', 'Squid Beakon', 'Killer Wail 5.1', '170p', '13', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)', '', 'Splattershot Jr.', '10', 'Splat Bomb', 'Big Bubbler', '180p', '1', '', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', 'Custom Splattershot Jr.', '11', 'Torpedo', 'Wave Breaker', '190p', '6', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)', '', 'Splash-o-matic', '20', 'Burst Bomb', 'Crab Tank', '200p', '16', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', 'Neo Splash-o-matic', '21', 'Suction Bomb', 'Triple Inkstrike', '200p', '21', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)', '', 'Aerospray MG', '30', 'Fizzy Bomb', 'Reefslider', '180p', '5', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', 'Aerospray RG', '31', 'Sprinkler', 'Booyah Bomb', '190p', '18', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)', '', 'Splattershot', '40', 'Suction Bomb', 'Trizooka', '210p', '2', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', 'Tentatek Splattershot', '41', 'Splat Bomb', 'Triple Inkstrike', '190p', '10', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)', '', 'Hero Shot Replica', '45', 'Suction Bomb', 'Trizooka', '210p', '1', '', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', 'Octo Shot Replica', '46', 'Splat Bomb', 'Triple Inkstrike', '190p', '1', '', 'Shooter', 'Version7.0.0(Side Order)', '', 'Order Shot Replica', '47', 'Suction Bomb', 'Trizooka', '210p', '1', '', 'Shooter', 'Version7.0.0(Side Order)', '', '.52 Gal', '50', 'Splash Wall', 'Killer Wail 5.1', '200p', '11', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', '.52 Gal Deco', '51', 'Curling Bomb', 'Splattercolor Screen', '190p', '14', '1', 'Shooter', 'Version7.0.0(Fresh Season 2024)', '', "N-ZAP '85", '60', 'Suction Bomb', 'Tacticooler', '200p', '6', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', "N-ZAP '89", '61', 'Autobomb', 'Super Chump', '170p', '11', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)', '', 'Splattershot Pro', '70', 'Angle Shooter', 'Crab Tank', '180p', '9', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', 'Forge Splattershot Pro', '71', 'Suction Bomb', 'Booyah Bomb', '200p', '20', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)', '', '.96 Gal', '80', 'Sprinkler', 'Ink Vac', '190p', '17', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', '.96 Gal Deco', '81', 'Splash Wall', 'Kraken Royale', '210p', '23', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)', '', 'Jet Squelcher', '90', 'Angle Shooter', 'Ink Vac', '180p', '15', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)', '', 'Custom Jet Squelcher', '91', 'Toxic Mist', 'Ink Storm', '180p', '20', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)', '', 'Splattershot Nova', '100', 'Point Sensor', 'Killer Wail 5.1', '190p', '8', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)', '', 'Annaki Splattershot Nova', '101', 'Ink Mine', 'Inkjet', '210p', '12', '1', 'Shooter', 'Version4.0.0(Sizzle Season 2023)', '', 'Luna Blaster', '200', 'Splat Bomb', 'Zipcaster', '170p', '13', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)', '', 'Luna Blaster Neo', '201', 'Fizzy Bomb', 'Ultra Stamp', '180p', '24', '1', 'Blaster', 'Version2.0.0(Chill Season 2022)', '', 'Order Blaster Replica', '205', 'Splat Bomb', 'Zipcaster', '170p', '1', '', 'Blaster', 'Version7.0.0(Side Order)', '', 'Blaster', '210', 'Autobomb', 'Big Bubbler', '180p', '3', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)', '', 'Custom Blaster', '211', 'Point Sensor', 'Triple Splashdown', '180p', '8', '1', 'Blaster', 'Version6.0.0(Chill Season 2023)', '', 'Range Blaster', '220', 'Suction Bomb', 'Wave Breaker', '210p', '11', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)', '', 'Custom Range Blaster', '221', 'Splat Bomb', 'Kraken Royale', '210p', '15', '1', 'Blaster', 'Version8.0.0(Sizzle Season 2024)', '', 'Clash Blaster', '230 ...
# [['', 'Sploosh-o-matic', '0', 'Curling Bomb', 'Ultra Stamp', '180p', '9', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Neo Sploosh-o-matic', '1', 'Squid Beakon', 'Killer Wail 5.1', '170p', '13', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Splattershot Jr.', '10', 'Splat Bomb', 'Big Bubbler', '180p', '1', '', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Custom Splattershot Jr.', '11', 'Torpedo', 'Wave Breaker', '190p', '6', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', 'Splash-o-matic', '20', 'Burst Bomb', 'Crab Tank', '200p', '16', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Neo Splash-o-matic', '21', 'Suction Bomb', 'Triple Inkstrike', '200p', '21', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Aerospray MG', '30', 'Fizzy Bomb', 'Reefslider', '180p', '5', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Aerospray RG', '31', 'Sprinkler', 'Booyah Bomb', '190p', '18', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', 'Splattershot', '40', 'Suction Bomb', 'Trizooka', '210p', '2', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Tentatek Splattershot', '41', 'Splat Bomb', 'Triple Inkstrike', '190p', '10', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', 'Hero Shot Replica', '45', 'Suction Bomb', 'Trizooka', '210p', '1', '', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Octo Shot Replica', '46', 'Splat Bomb', 'Triple Inkstrike', '190p', '1', '', 'Shooter', 'Version7.0.0(Side Order)'], ['', 'Order Shot Replica', '47', 'Suction Bomb', 'Trizooka', '210p', '1', '', 'Shooter', 'Version7.0.0(Side Order)'], ['', '.52 Gal', '50', 'Splash Wall', 'Killer Wail 5.1', '200p', '11', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', '.52 Gal Deco', '51', 'Curling Bomb', 'Splattercolor Screen', '190p', '14', '1', 'Shooter', 'Version7.0.0(Fresh Season 2024)'], ['', "N-ZAP '85", '60', 'Suction Bomb', 'Tacticooler', '200p', '6', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', "N-ZAP '89", '61', 'Autobomb', 'Super Chump', '170p', '11', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Splattershot Pro', '70', 'Angle Shooter', 'Crab Tank', '180p', '9', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Forge Splattershot Pro', '71', 'Suction Bomb', 'Booyah Bomb', '200p', '20', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', '.96 Gal', '80', 'Sprinkler', 'Ink Vac', '190p', '17', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', '.96 Gal Deco', '81', 'Splash Wall', 'Kraken Royale', '210p', '23', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Jet Squelcher', '90', 'Angle Shooter', 'Ink Vac', '180p', '15', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Custom Jet Squelcher', '91', 'Toxic Mist', 'Ink Storm', '180p', '20', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Splattershot Nova', '100', 'Point Sensor', 'Killer Wail 5.1', '190p', '8', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', 'Annaki Splattershot Nova', '101', 'Ink Mine', 'Inkjet', '210p', '12', '1', 'Shooter', 'Version4.0.0(Sizzle Season 2023)'], ['', 'Luna Blaster', '200', 'Splat Bomb', 'Zipcaster', '170p', '13', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Luna Blaster Neo', '201', 'Fizzy Bomb', 'Ultra Stamp', '180p', '24', '1', 'Blaster', 'Version2.0.0(Chill Season 2022)'], ['', 'Order Blaster Replica', '205', 'Splat Bomb', 'Zipcaster', '170p', '1', '', 'Blaster', 'Version7.0.0(Side Order)'], ['', 'Blaster', '210', 'Autobomb', 'Big Bubbler', '180p', '3', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Custom Blaster', '211', 'Point Sensor', 'Triple Splashdown', '180p', '8', '1', 'Blaster', 'Version6.0.0(Chill Season 2023)'], ['', 'Range Blaster', '220', 'Suction Bomb', 'Wave Breaker', '210p', '11', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Custom Range Blaster', '221', 'Splat Bomb', 'Kraken Royale', '210p', '15', '1', 'Blaster' ...
#     Extra_space                     Name    ID           Sub          Special  \
# 0                        Sploosh-o-matic     0  Curling Bomb      Ultra Stamp
# 1                    Neo Sploosh-o-matic     1  Squid Beakon  Killer Wail 5.1
# 2                       Splattershot Jr.    10    Splat Bomb      Big Bubbler
# 3                Custom Splattershot Jr.    11       Torpedo     Wave Breaker
# 4                         Splash-o-matic    20    Burst Bomb        Crab Tank
# ..          ...                      ...   ...           ...              ...
# 138               Order Splatana Replica  8005    Burst Bomb        Zipcaster
# 139                       Splatana Wiper  8010       Torpedo      Ultra Stamp
# 140                  Splatana Wiper Deco  8011  Squid Beakon   Tenta Missiles
# 141                     Mint Decavitator  8020  Suction Bomb      Big Bubbler
# 142                 Charcoal Decavitator  8021   Splash Wall           Inkjet
#
#     Special_Points Level Price     Class                         Introduced
# 0             180p     9     1   Shooter  Version1.0.0(Drizzle Season 2022)
# 1             170p    13     1   Shooter    Version3.0.0(Fresh Season 2023)
# 2             180p     1         Shooter  Version1.0.0(Drizzle Season 2022)
# 3             190p     6     1   Shooter    Version2.0.0(Chill Season 2022)
# 4             200p    16     1   Shooter  Version1.0.0(Drizzle Season 2022)
# ..             ...   ...   ...       ...                                ...
# 138           210p     1        Splatana           Version7.0.0(Side Order)
# 139           190p     5     1  Splatana  Version1.0.0(Drizzle Season 2022)
# 140           190p    10     1  Splatana   Version4.0.0(Sizzle Season 2023)
# 141           210p    21     1  Splatana   Version8.0.0(Sizzle Season 2024)
# 142           200p    25     1  Splatana   Version8.0.0(Sizzle Season 2024)
#
# [143 rows x 10 columns]

# %%
from bs4 import BeautifulSoup
# import requests
import time
import pandas as pd
from etl.extract.extract import make_request

# defining constants

ALL_WEAPONS_SITE = (
    'https://splatoonwiki.org/wiki/List_of_main_weapons_in_Splatoon_3'
)


# function to extract all the needed data from inkepedia
def extract_inkepedia():
    return None


# function to specifically extract the information for each main weapon
# returns a dataframe
def extract_weapon_details():
    # make a request to the website
    soup = BeautifulSoup(make_request(ALL_WEAPONS_SITE).text, "html.parser")
    # find all the rows in the weapons table
    all_rows = soup.find_all('tr')
    weapon_info_list = []  # empty list to store these
    # loop through eah row
    for row in all_rows:
        time.sleep(0.05)
        # find all the elements in the row
        element = row.find_all('td')
        # loop through each
        for i in element:
            # add the text of the element to the list
            weapon_info_list.append(i.get_text(strip=True))
    complete_list = []  # 2d array to store detail lists for each weapon
    for elm in range(0, len(weapon_info_list), 10):
        one_weapon = weapon_info_list[elm:elm+10]
        complete_list.append(one_weapon)
    print(complete_list)
    weapons_df = pd.DataFrame(complete_list, columns=[
        'Extra_space', 'Name', 'ID', 'Sub', 'Special',
        'Special_Points', 'Level', 'Price', 'Class', 'Introduced'
    ])
    return weapons_df

# %%
display(extract_weapon_details())
# Out:
# [['', 'Sploosh-o-matic', '0', 'Curling Bomb', 'Ultra Stamp', '180p', '9', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Neo Sploosh-o-matic', '1', 'Squid Beakon', 'Killer Wail 5.1', '170p', '13', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Splattershot Jr.', '10', 'Splat Bomb', 'Big Bubbler', '180p', '1', '', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Custom Splattershot Jr.', '11', 'Torpedo', 'Wave Breaker', '190p', '6', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', 'Splash-o-matic', '20', 'Burst Bomb', 'Crab Tank', '200p', '16', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Neo Splash-o-matic', '21', 'Suction Bomb', 'Triple Inkstrike', '200p', '21', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Aerospray MG', '30', 'Fizzy Bomb', 'Reefslider', '180p', '5', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Aerospray RG', '31', 'Sprinkler', 'Booyah Bomb', '190p', '18', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', 'Splattershot', '40', 'Suction Bomb', 'Trizooka', '210p', '2', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Tentatek Splattershot', '41', 'Splat Bomb', 'Triple Inkstrike', '190p', '10', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', 'Hero Shot Replica', '45', 'Suction Bomb', 'Trizooka', '210p', '1', '', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Octo Shot Replica', '46', 'Splat Bomb', 'Triple Inkstrike', '190p', '1', '', 'Shooter', 'Version7.0.0(Side Order)'], ['', 'Order Shot Replica', '47', 'Suction Bomb', 'Trizooka', '210p', '1', '', 'Shooter', 'Version7.0.0(Side Order)'], ['', '.52 Gal', '50', 'Splash Wall', 'Killer Wail 5.1', '200p', '11', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', '.52 Gal Deco', '51', 'Curling Bomb', 'Splattercolor Screen', '190p', '14', '1', 'Shooter', 'Version7.0.0(Fresh Season 2024)'], ['', "N-ZAP '85", '60', 'Suction Bomb', 'Tacticooler', '200p', '6', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', "N-ZAP '89", '61', 'Autobomb', 'Super Chump', '170p', '11', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Splattershot Pro', '70', 'Angle Shooter', 'Crab Tank', '180p', '9', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Forge Splattershot Pro', '71', 'Suction Bomb', 'Booyah Bomb', '200p', '20', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', '.96 Gal', '80', 'Sprinkler', 'Ink Vac', '190p', '17', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', '.96 Gal Deco', '81', 'Splash Wall', 'Kraken Royale', '210p', '23', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Jet Squelcher', '90', 'Angle Shooter', 'Ink Vac', '180p', '15', '1', 'Shooter', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Custom Jet Squelcher', '91', 'Toxic Mist', 'Ink Storm', '180p', '20', '1', 'Shooter', 'Version3.0.0(Fresh Season 2023)'], ['', 'Splattershot Nova', '100', 'Point Sensor', 'Killer Wail 5.1', '190p', '8', '1', 'Shooter', 'Version2.0.0(Chill Season 2022)'], ['', 'Annaki Splattershot Nova', '101', 'Ink Mine', 'Inkjet', '210p', '12', '1', 'Shooter', 'Version4.0.0(Sizzle Season 2023)'], ['', 'Luna Blaster', '200', 'Splat Bomb', 'Zipcaster', '170p', '13', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Luna Blaster Neo', '201', 'Fizzy Bomb', 'Ultra Stamp', '180p', '24', '1', 'Blaster', 'Version2.0.0(Chill Season 2022)'], ['', 'Order Blaster Replica', '205', 'Splat Bomb', 'Zipcaster', '170p', '1', '', 'Blaster', 'Version7.0.0(Side Order)'], ['', 'Blaster', '210', 'Autobomb', 'Big Bubbler', '180p', '3', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Custom Blaster', '211', 'Point Sensor', 'Triple Splashdown', '180p', '8', '1', 'Blaster', 'Version6.0.0(Chill Season 2023)'], ['', 'Range Blaster', '220', 'Suction Bomb', 'Wave Breaker', '210p', '11', '1', 'Blaster', 'Version1.0.0(Drizzle Season 2022)'], ['', 'Custom Range Blaster', '221', 'Splat Bomb', 'Kraken Royale', '210p', '15', '1', 'Blaster' ...
#     Extra_space                     Name    ID           Sub          Special  \
# 0                        Sploosh-o-matic     0  Curling Bomb      Ultra Stamp
# 1                    Neo Sploosh-o-matic     1  Squid Beakon  Killer Wail 5.1
# 2                       Splattershot Jr.    10    Splat Bomb      Big Bubbler
# 3                Custom Splattershot Jr.    11       Torpedo     Wave Breaker
# 4                         Splash-o-matic    20    Burst Bomb        Crab Tank
# ..          ...                      ...   ...           ...              ...
# 138               Order Splatana Replica  8005    Burst Bomb        Zipcaster
# 139                       Splatana Wiper  8010       Torpedo      Ultra Stamp
# 140                  Splatana Wiper Deco  8011  Squid Beakon   Tenta Missiles
# 141                     Mint Decavitator  8020  Suction Bomb      Big Bubbler
# 142                 Charcoal Decavitator  8021   Splash Wall           Inkjet
#
#     Special_Points Level Price     Class                         Introduced
# 0             180p     9     1   Shooter  Version1.0.0(Drizzle Season 2022)
# 1             170p    13     1   Shooter    Version3.0.0(Fresh Season 2023)
# 2             180p     1         Shooter  Version1.0.0(Drizzle Season 2022)
# 3             190p     6     1   Shooter    Version2.0.0(Chill Season 2022)
# 4             200p    16     1   Shooter  Version1.0.0(Drizzle Season 2022)
# ..             ...   ...   ...       ...                                ...
# 138           210p     1        Splatana           Version7.0.0(Side Order)
# 139           190p     5     1  Splatana  Version1.0.0(Drizzle Season 2022)
# 140           190p    10     1  Splatana   Version4.0.0(Sizzle Season 2023)
# 141           210p    21     1  Splatana   Version8.0.0(Sizzle Season 2024)
# 142           200p    25     1  Splatana   Version8.0.0(Sizzle Season 2024)
#
# [143 rows x 10 columns]

# %%
# split into functions:

# %%
from bs4 import BeautifulSoup
# import requests
import time
import pandas as pd
from etl.extract.url_request import make_request

# defining constants

ALL_WEAPONS_SITE = (
    'https://splatoonwiki.org/wiki/List_of_main_weapons_in_Splatoon_3'
)


# function to extract all the needed data from inkepedia
def extract_inkepedia():
    weapon_details_df = extract_weapon_details()
    display(weapon_details_df)
    return None


# function to specifically extract the information for each main weapon
# returns a dataframe
def extract_weapon_details():
    # make a request to the website
    soup = BeautifulSoup(make_request(ALL_WEAPONS_SITE).text, "html.parser")
    # call function to return all the weapon details from the site
    weapon_info_list = scrape_weapon_details(soup)
    # call function to reshape this list to be a 2d array
    complete_list = reshaping_weapon_details(weapon_info_list)
    # use each element from this 2d array as a row in a dataframe
    # this way each weapon has a row describing it
    weapons_df = pd.DataFrame(complete_list, columns=[
        'Extra_space', 'Name', 'ID', 'Sub', 'Special',
        'Special_Points', 'Level', 'Price', 'Class', 'Introduced'
    ])
    # some of these columns are unnessary and we will drop them later
    # return the created dataframe
    return weapons_df


# function to find weapon details as a 1d array
def scrape_weapon_details(soup):
    # find all the rows in the weapons table
    all_rows = soup.find_all('tr')
    weapon_info_list = []  # empty list to store these
    # loop through eah row
    for row in all_rows:
        # function that adds elements from the row to the list 
        weapon_info_list = scrape_row(row, weapon_info_list)
    # return this list
    return weapon_info_list


# function to find and return elements from row
# and append to a list of elements
def scrape_row(row, element_list):
    # short pause to not overwhelm the site
    time.sleep(0.05)
    # find all the elements in the row
    element = row.find_all('td')
    # loop through each
    for i in element:
        # add the text of the element to the list
        element_list.append(i.get_text(strip=True))
    return element_list


# function that takes the weapon details list
# and creates a 2d array with from it
def reshaping_weapon_details(weapon_info_list):
    complete_list = []  # 2d array to store detail lists for each weapon
    # looping through the list but in steps of 10
    for elm in range(0, len(weapon_info_list), 10):
        # create a list for each weapon
        # includes elements like name to the version it was introduced
        one_weapon = weapon_info_list[elm:elm+10]
        # add to the 2d array
        complete_list.append(one_weapon)
    # return the completed list of weapons lists
    return complete_list

# %%
extract_inkepedia()
# Out:
#     Extra_space                     Name    ID           Sub          Special  \
# 0                        Sploosh-o-matic     0  Curling Bomb      Ultra Stamp
# 1                    Neo Sploosh-o-matic     1  Squid Beakon  Killer Wail 5.1
# 2                       Splattershot Jr.    10    Splat Bomb      Big Bubbler
# 3                Custom Splattershot Jr.    11       Torpedo     Wave Breaker
# 4                         Splash-o-matic    20    Burst Bomb        Crab Tank
# ..          ...                      ...   ...           ...              ...
# 138               Order Splatana Replica  8005    Burst Bomb        Zipcaster
# 139                       Splatana Wiper  8010       Torpedo      Ultra Stamp
# 140                  Splatana Wiper Deco  8011  Squid Beakon   Tenta Missiles
# 141                     Mint Decavitator  8020  Suction Bomb      Big Bubbler
# 142                 Charcoal Decavitator  8021   Splash Wall           Inkjet
#
#     Special_Points Level Price     Class                         Introduced
# 0             180p     9     1   Shooter  Version1.0.0(Drizzle Season 2022)
# 1             170p    13     1   Shooter    Version3.0.0(Fresh Season 2023)
# 2             180p     1         Shooter  Version1.0.0(Drizzle Season 2022)
# 3             190p     6     1   Shooter    Version2.0.0(Chill Season 2022)
# 4             200p    16     1   Shooter  Version1.0.0(Drizzle Season 2022)
# ..             ...   ...   ...       ...                                ...
# 138           210p     1        Splatana           Version7.0.0(Side Order)
# 139           190p     5     1  Splatana  Version1.0.0(Drizzle Season 2022)
# 140           190p    10     1  Splatana   Version4.0.0(Sizzle Season 2023)
# 141           210p    21     1  Splatana   Version8.0.0(Sizzle Season 2024)
# 142           200p    25     1  Splatana   Version8.0.0(Sizzle Season 2024)
#
# [143 rows x 10 columns]
