# %%
from etl.extract.extract_sendou_builds import extract_sendou_data

df_builds = extract_sendou_data()
display(df_builds)
# Out:
# Finding each weapon's page to scrape builds...
# Done! Found 130 pages!
# Now extracting the builds...
# Extracting builds for: .52 Gal
# 	240 builds found
# Extracting builds for: .52 Gal Deco
# 	240 builds found
# Extracting builds for: .96 Gal
# 	240 builds found
# Extracting builds for: .96 Gal Deco
# 	240 builds found
# Extracting builds for: Aerospray MG
# 	240 builds found
# Extracting builds for: Aerospray RG
# 	240 builds found
# Extracting builds for: Annaki Splattershot Nova
# 	240 builds found
# Extracting builds for: Custom Jet Squelcher
# 	240 builds found
# Extracting builds for: Custom Splattershot Jr.
# 	240 builds found
# Extracting builds for: Foil Squeezer
# 	240 builds found
# Extracting builds for: Forge Splattershot Pro
# 	240 builds found
# Extracting builds for: H-3 Nozzlenose
# 	240 builds found
# Extracting builds for: H-3 Nozzlenose D
# 	190 builds found
# Extracting builds for: Jet Squelcher
# 	240 builds found
# Extracting builds for: L-3 Nozzlenose
# 	186 builds found
# Extracting builds for: L-3 Nozzlenose D
# 	240 builds found
# Extracting builds for: N-ZAP '85
# 	240 builds found
# Extracting builds for: N-ZAP '89
# 	240 builds found
# Extracting builds for: Neo Splash-o-matic
# 	240 builds found
# Extracting builds for: Neo Sploosh-o-matic
# 	228 builds found
# Extracting builds for: Splash-o-matic
# 	240 builds found
# Extracting builds for: Splattershot
# 	240 builds found
# Extracting builds for: Splattershot Jr.
# 	240 builds found
# Extracting builds for: Splattershot Nova
# 	240 builds found
# Extracting builds for: Splattershot Pro
# 	240 builds found
# Extracting builds for: Sploosh-o-matic
# 	240 builds found
# Extracting builds for: Squeezer
# 	240 builds found
# Extracting builds for: Tentatek Splattershot
# 	240 builds found
# Extracting builds for: Blaster
# 	240 builds found
# Extracting builds for: Clash Blaster
# 	221 builds found
# Extracting builds for: Clash Blaster Neo
# 	107 builds found
# Extracting builds for: Custom Blaster
# 	240 builds found
# Extracting builds for: Custom Range Blaster
# 	240 builds found
# Extracting builds for: Luna Blaster
# 	240 builds found
# Extracting builds for: Luna Blaster Neo
# 	240 builds found
# Extracting builds for: Range Blaster
# 	240 builds found
# Extracting builds for: Rapid Blaster
# 	240 builds found
# Extracting builds for: Rapid Blaster Deco
# 	240 builds found
# Extracting builds for: Rapid Blaster Pro
# 	240 builds found
# Extracting builds for: Rapid Blaster Pro Deco
# 	240 builds found
# Extracting builds for: S-BLAST '91
# 	240 builds found
# Extracting builds for: S-BLAST '92
# 	240 builds found
# Extracting builds for: Big Swig Roller
# 	230 builds found
# Extracting builds for: Big Swig Roller Express
# 	240 builds found
# Extracting builds for: Carbon Roller
# 	240 builds found
# Extracting builds for: Carbon Roller Deco
# 	240 builds found
# Extracting builds for: Dynamo Roller
# 	240 builds found
# Extracting builds for: Flingza Roller
# 	240 builds found
# Extracting builds for: Foil Flingza Roller
# 	116 builds found
# Extracting builds for: Gold Dynamo Roller
# 	240 builds found
# Extracting builds for: Krak-On Splat Roller
# 	240 builds found
# Extracting builds for: Splat Roller
# 	240 builds found
# Extracting builds for: Inkbrush
# 	240 builds found
# Extracting builds for: Inkbrush Nouveau
# 	240 builds found
# Extracting builds for: Octobrush
# 	240 builds found
# Extracting builds for: Octobrush Nouveau
# 	240 builds found
# Extracting builds for: Painbrush
# 	240 builds found
# Extracting builds for: Painbrush Nouveau
# 	240 builds found
# Extracting builds for: Bamboozler 14 Mk I
# 	240 builds found
# Extracting builds for: Bamboozler 14 Mk II
# 	240 builds found
# Extracting builds for: Classic Squiffer
# 	240 builds found
# Extracting builds for: Custom E-liter 4K
# 	240 builds found
# Extracting builds for: Custom E-liter 4K Scope
# 	240 builds found
# Extracting builds for: Custom Goo Tuber
# 	117 builds found
# Extracting builds for: E-liter 4K
# 	240 builds found
# Extracting builds for: E-liter 4K Scope
# 	240 builds found
# Extracting builds for: Goo Tuber
# 	240 builds found
# Extracting builds for: New Squiffer
# 	240 builds found
# Extracting builds for: Snipewriter 5B
# 	225 builds found
# Extracting builds for: Snipewriter 5H
# 	240 builds found
# Extracting builds for: Splat Charger
# 	240 builds found
# Extracting builds for: Splatterscope
# 	240 builds found
# Extracting builds for: Z+F Splat Charger
# 	240 builds found
# Extracting builds for: Z+F Splatterscope
# 	240 builds found
# Extracting builds for: Bloblobber
# 	240 builds found
# Extracting builds for: Bloblobber Deco
# 	200 builds found
# Extracting builds for: Custom Explosher
# 	240 builds found
# Extracting builds for: Dread Wringer
# 	240 builds found
# Extracting builds for: Dread Wringer D
# 	170 builds found
# Extracting builds for: Explosher
# 	240 builds found
# Extracting builds for: Slosher
# 	240 builds found
# Extracting builds for: Slosher Deco
# 	240 builds found
# Extracting builds for: Sloshing Machine
# 	240 builds found
# Extracting builds for: Sloshing Machine Neo
# 	240 builds found
# Extracting builds for: Tri-Slosher
# 	240 builds found
# Extracting builds for: Tri-Slosher Nouveau
# 	240 builds found
# Extracting builds for: Ballpoint Splatling
# 	240 builds found
# Extracting builds for: Ballpoint Splatling Nouveau
# 	240 builds found
# Extracting builds for: Custom Hydra Splatling
# 	191 builds found
# Extracting builds for: Heavy Edit Splatling
# 	240 builds found
# Extracting builds for: Heavy Edit Splatling Nouveau
# 	240 builds found
# Extracting builds for: Heavy Splatling
# 	240 builds found
# Extracting builds for: Heavy Splatling Deco
# 	240 builds found
# Extracting builds for: Hydra Splatling
# 	240 builds found
# Extracting builds for: Mini Splatling
# 	240 builds found
# Extracting builds for: Nautilus 47
# 	240 builds found
# Extracting builds for: Nautilus 79
# 	240 builds found
# Extracting builds for: Zink Mini Splatling
# 	240 builds found
# Extracting builds for: Custom Douser Dualies FF
# 	240 builds found
# Extracting builds for: Custom Dualie Squelchers
# 	240 builds found
# Extracting builds for: Dapple Dualies
# 	240 builds found
# Extracting builds for: Dapple Dualies Nouveau
# 	240 builds found
# Extracting builds for: Dark Tetra Dualies
# 	240 builds found
# Extracting builds for: Douser Dualies FF
# 	240 builds found
# Extracting builds for: Dualie Squelchers
# 	240 builds found
# Extracting builds for: Enperry Splat Dualies
# 	240 builds found
# Extracting builds for: Glooga Dualies
# 	240 builds found
# Extracting builds for: Glooga Dualies Deco
# 	240 builds found
# Extracting builds for: Light Tetra Dualies
# 	240 builds found
# Extracting builds for: Splat Dualies
# 	240 builds found
# Extracting builds for: Recycled Brella 24 Mk I
# 	172 builds found
# Extracting builds for: Recycled Brella 24 Mk II
# 	144 builds found
# Extracting builds for: Sorella Brella
# 	240 builds found
# Extracting builds for: Splat Brella
# 	240 builds found
# Extracting builds for: Tenta Brella
# 	240 builds found
# Extracting builds for: Tenta Sorella Brella
# 	240 builds found
# Extracting builds for: Undercover Brella
# 	240 builds found
# Extracting builds for: Undercover Sorella Brella
# 	202 builds found
# Extracting builds for: Custom Wellstring V
# 	240 builds found
# Extracting builds for: Inkline Tri-Stringer
# 	240 builds found
# Extracting builds for: REEF-LUX 450
# 	240 builds found
# Extracting builds for: REEF-LUX 450 Deco
# 	238 builds found
# Extracting builds for: Tri-Stringer
# 	240 builds found
# Extracting builds for: Wellstring V
# 	240 builds found
# Extracting builds for: Charcoal Decavitator
# 	240 builds found
# Extracting builds for: Mint Decavitator
# 	240 builds found
# Extracting builds for: Splatana Stamper
# 	240 builds found
# Extracting builds for: Splatana Stamper Nouveau
# 	240 builds found
# Extracting builds for: Splatana Wiper
# 	240 builds found
# Extracting builds for: Splatana Wiper Deco
# 	240 builds found
# Done! Created a builds dataframe!
#                Weapon_name          Main_1             Sub_1  \
# 0                  .52 Gal  Opening Gambit  Intensify Action
# 1                  .52 Gal        Comeback  Intensify Action
# 2                  .52 Gal   Swim Speed Up  Intensify Action
# 3                  .52 Gal        Comeback  Intensify Action
# 4                  .52 Gal  Opening Gambit  Intensify Action
# ...                    ...             ...               ...
# 30292  Splatana Wiper Deco        Comeback     Swim Speed Up
# 30293  Splatana Wiper Deco    Sub Power Up   Ink Saver (Sub)
# 30294  Splatana Wiper Deco        Comeback     Quick Respawn
# 30295  Splatana Wiper Deco        Comeback     Quick Respawn
# 30296  Splatana Wiper Deco    Sub Power Up      Sub Power Up
#
#                   Sub_2             Sub_3         Main_2              Sub_4  \
# 0      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 1      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 2      Intensify Action  Intensify Action  Swim Speed Up    Ink Recovery Up
# 3      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# 4      Intensify Action  Intensify Action  Swim Speed Up      Swim Speed Up
# ...                 ...               ...            ...                ...
# 30292     Swim Speed Up     Special Saver   Sub Power Up       Sub Power Up
# 30293   Ink Saver (Sub)   Ink Saver (Sub)  Swim Speed Up      Swim Speed Up
# 30294     Quick Respawn     Quick Respawn          Haunt      Swim Speed Up
# 30295     Quick Respawn     Quick Respawn   Sub Power Up  Special Charge Up
# 30296      Sub Power Up  Quick Super Jump  Swim Speed Up      Swim Speed Up
#
#                    Sub_5              Sub_6        Main_3              Sub_7  \
# 0          Swim Speed Up  Ink Resistance Up  Stealth Jump   Quick Super Jump
# 1          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# 2          Special Saver   Quick Super Jump  Stealth Jump  Ink Resistance Up
# 3          Swim Speed Up      Swim Speed Up  Stealth Jump      Special Saver
# 4          Swim Speed Up      Special Saver  Stealth Jump   Quick Super Jump
# ...                  ...                ...           ...                ...
# 30292       Sub Power Up       Sub Power Up  Sub Power Up   Special Power Up
# 30293  Ink Resistance Up  Sub Resistance Up  Stealth Jump   Quick Super Jump
# 30294      Swim Speed Up       Sub Power Up  Stealth Jump      Quick Respawn
# 30295  Special Charge Up  Special Charge Up  Stealth Jump      Quick Respawn
# 30296      Swim Speed Up  Special Charge Up  Stealth Jump      Quick Respawn
#
#                    Sub_8              Sub_9  \
# 0       Quick Super Jump  Sub Resistance Up
# 1      Ink Resistance Up   Intensify Action
# 2      Sub Resistance Up   Intensify Action
# 3       Quick Super Jump  Ink Resistance Up
# 4      Ink Resistance Up  Sub Resistance Up
# ...                  ...                ...
# 30292   Quick Super Jump       Sub Power Up
# 30293   Quick Super Jump   Quick Super Jump
# 30294      Quick Respawn       Sub Power Up
# 30295   Quick Super Jump       Sub Power Up
# 30296      Quick Respawn      Special Saver
#
#                                               game_modes
# 0      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 1      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 2      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 3      [Splat Zones, Tower Control, Rainmaker, Clam B...
# 4      [Splat Zones, Tower Control, Rainmaker, Clam B...
# ...                                                  ...
# 30292  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30293  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30294  [Splat Zones, Tower Control, Rainmaker, Clam B...
# 30295  [Turf War, Splat Zones, Tower Control, Clam Bl...
# 30296  [Turf War, Splat Zones, Tower Control, Rainmaker]
#
# [30297 rows x 14 columns]

# %%
import pandas as pd
from bs4 import BeautifulSoup  ## the BeautifulSoup library for scraping from the bs4 package
import requests ## Establish website connection using the requests library

# create pandas series for each gear type's possible options for main abilities
main_1 = df_builds['Main_1'].drop_duplicates()  # ability options for head gear
main_2 = df_builds['Main_2'].drop_duplicates()  # ability options for clothing  
main_3 = df_builds['Main_3'].drop_duplicates()  # ability options for shoes

# combine to form a series of all possible options (no repeats)
all_abilities = pd.concat([main_1, main_2, main_3]).drop_duplicates()

# Convert the series to a dataframe
# reset the index so we have abilities 0 to 25
# there should be 26 found in total
abilities_df = pd.DataFrame(all_abilities, columns=['Abilities']).reset_index(drop=True)

display(abilities_df)

gallery_path = 'https://splatoonwiki.org/wiki/Category:Splatoon_3_ability_icons'

response = requests.get(gallery_path) 
soup = BeautifulSoup(response.content, 'html.parser') 


images = soup.find_all('img')

image_urls = [] 

for img in images:
    src = img.get('src')
     # Check if the 'src' attribute exists and contains 'Ability'
     # We also want to exclude the 'locked' used for when
     # an ability slot is empty
    if src and 'Ability' in src and 'Locked' not in src:
        # add the image URL to the list
        image_urls.append('https:' + src) 

image_urls

# check length of image urls
len(image_urls) ## Get the number of image URLs found
print(image_urls)
# Out:
#             Abilities
# 0      Opening Gambit
# 1            Comeback
# 2       Swim Speed Up
# 3    Intensify Action
# 4       Quick Respawn
# 5    Special Power Up
# 6   Special Charge Up
# 7   Last-Ditch Effort
# 8     Ink Saver (Sub)
# 9        Sub Power Up
# 10           Tenacity
# 11      Special Saver
# 12  Ink Resistance Up
# 13   Ink Saver (Main)
# 14   Quick Super Jump
# 15  Sub Resistance Up
# 16       Run Speed Up
# 17    Ink Recovery Up
# 18        Ninja Squid
# 19              Haunt
# 20        Thermal Ink
# 21   Respawn Punisher
# 22    Ability Doubler
# 23       Stealth Jump
# 24        Drop Roller
# 25    Object Shredder
# ['https://cdn.wikimg.net/en/splatoonwiki/images/thumb/9/9d/S3_Ability_Ability_Doubler.png/120px-S3_Ability_Ability_Doubler.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/0/09/S3_Ability_Comeback.png/120px-S3_Ability_Comeback.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/0/05/S3_Ability_Drop_Roller.png/120px-S3_Ability_Drop_Roller.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/2/2b/S3_Ability_Haunt.png/120px-S3_Ability_Haunt.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/3/3c/S3_Ability_Ink_Recovery_Up.png/120px-S3_Ability_Ink_Recovery_Up.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/6/6d/S3_Ability_Ink_Resistance_Up.png/120px-S3_Ability_Ink_Resistance_Up.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/3/35/S3_Ability_Ink_Saver_%28Main%29.png/120px-S3_Ability_Ink_Saver_%28Main%29.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/a/a2/S3_Ability_Ink_Saver_%28Sub%29.png/120px-S3_Ability_Ink_Saver_%28Sub%29.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/5/52/S3_Ability_Intensify_Action.png/120px-S3_Ability_Intensify_Action.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/c/c7/S3_Ability_Last-Ditch_Effort.png/120px-S3_Ability_Last-Ditch_Effort.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/7/78/S3_Ability_Ninja_Squid.png/120px-S3_Ability_Ninja_Squid.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/f/f0/S3_Ability_Object_Shredder.png/120px-S3_Ability_Object_Shredder.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/b/b3/S3_Ability_Opening_Gambit.png/120px-S3_Ability_Opening_Gambit.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/9/98/S3_Ability_Quick_Respawn.png/120px-S3_Ability_Quick_Respawn.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/d/d5/S3_Ability_Quick_Super_Jump.png/120px-S3_Ability_Quick_Super_Jump.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/6/68/S3_Ability_Respawn_Punisher.png/120px-S3_Ability_Respawn_Punisher.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/a/a0/S3_Ability_Run_Speed_Up.png/120px-S3_Ability_Run_Speed_Up.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/9/97/S3_Ability_Special_Charge_Up.png/120px-S3_Ability_Special_Charge_Up.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/e/ea/S3_Ability_Special_Power_Up.png/120px-S3_Ability_Special_Power_Up.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/e/e0/S3_Ability_Special_Saver.png/120px-S3_Ability_Special_Saver.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/5/5a/S3_Ability_Stealth_Jump.png/120px-S3_Ability_Stealth_Jump.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/6/61/S3_Ability_Sub_Power_Up.png/120px-S3_Ability_Sub_Power_Up.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/d/d4/S3_Ability_Sub_Resistance_Up.png/120px-S3_Ability_Sub_Resistance_Up.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/6/61/S3_Ability_Swim_Speed_Up.png/120px-S3_Ability_Swim_Speed_Up.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/6/60/S3_Ability_Tenacity.png/120px-S3_Ability_Tenacity.png', 'https://cdn.wikimg.net/en/splatoonwiki/images/thumb/3/33/S3_Ability_Thermal_Ink.png/120px-S3_Ability_Thermal_Ink.png']

# %% [markdown]
# # NEXT ADD FUNCTIONS

# %%
import pandas as pd
from bs4 import BeautifulSoup  ## the BeautifulSoup library for scraping from the bs4 package
import requests ## Establish website connection using the requests library
from etl.extract.url_request import make_request

ABILITY_GALLERY_PATH = 'https://splatoonwiki.org/wiki/Category:Splatoon_3_ability_icons'





# function extract ability chunk images from inkipedia
# returns a dataframe for abilities and urls
def extract_ability_images(df_builds):
    # first call a function that returns all possible abilities
    # as a dataframe
    abilities_df = find_ability_names(df_builds)
    # find all image urls for ability images
    image_urls = find_all_ability_images()
    # add these to the original ability dataframe
    abilities_df = create_ability_df(abilities_df, image_urls)
    # return the completed abilities dataframe
    return abilities_df


# function that using the builds dataframe find all possible ability names
def find_ability_names(df_builds):
    # create pandas series for each gear type's possible options for main abilities
    main_1 = df_builds['Main_1'].drop_duplicates()  # ability options for head gear
    main_2 = df_builds['Main_2'].drop_duplicates()  # ability options for clothing  
    main_3 = df_builds['Main_3'].drop_duplicates()  # ability options for shoes

    # combine to form a series of all possible options (no repeats)
    all_abilities = pd.concat([main_1, main_2, main_3]).drop_duplicates()

    # Convert the series to a dataframe
    # reset the index so we have abilities 0 to 25
    # there should be 26 found in total
    abilities_df = pd.DataFrame(all_abilities, columns=['Abilities']).reset_index(drop=True)

    #display(abilities_df)
    # return the dataframe of ability names
    return abilities_df


# function that find all the images of possible abilities
def find_all_ability_images():
    soup = BeautifulSoup(make_request(ABILITY_GALLERY_PATH).text, "html.parser")
    # find all images on the page
    images = soup.find_all('img')
    image_urls = []  # empty list to store urls
    # loop through each image on the page
    for img in images:
        # call the function to check if the image is for an ability
        # and adds it to the list
         image_urls = find_ability_image(img, image_urls)
    return image_urls

# function to check if the image is of an ability
# if so add to the list or urls
def find_ability_image(img, image_urls):
    src = img.get('src')
    # Check if the 'src' attribute exists and contains 'Ability'
    # We also want to exclude the 'locked' used for when
    # an ability slot is empty
    if src and 'Ability' in src and 'Locked' not in src:
        # add the image URL to the list
        image_urls.append('https:' + src)  
    return image_urls


# function to use both the list of images
# and dataframe of ability names
# to create a complete dataframe of ability images
def create_ability_df(abilities_df, image_urls):
    # first order the abilities alphabetically
    abilities_df = abilities_df.sort_values(by='Abilities')
    # reset the index again
    abilities_df.reset_index(drop=True, inplace=True)
    # --- Assistance from ChatGPT ---------------------------------------
    image_urls = sorted(image_urls, key=lambda img: img.split('/')[-1])
    # -------------------------------------------------------------------
    # add a new column called Image URL
    # add the urls here
    abilities_df['Image URL'] = image_urls
    # return the complete dataframe
    return abilities_df

# %%
extract_ability_images(df_builds)

# %% [markdown]
# # complete (need to add tests)

# %%
import pandas as pd
from bs4 import BeautifulSoup
from etl.extract.url_request import make_request
import time

ABILITY_GALLERY_PATH = (
    'https://splatoonwiki.org/wiki/Category:Splatoon_3_ability_icons'
    )


# function extract ability chunk images from inkipedia
# returns a dataframe for abilities and urls
def extract_ability_images(df_builds):
    print("Creating a dataframe of ability images...")
    # first call a function that returns all possible abilities
    # as a dataframe
    abilities_df = find_ability_names(df_builds)
    # find all image urls for ability images
    image_urls = find_all_ability_images()
    # add these to the original ability dataframe
    abilities_df = create_ability_df(abilities_df, image_urls)
    print("Done! " + str(abilities_df.shape[0]) + "/26 images found")
    # return the completed abilities dataframe
    return abilities_df


# function that using the builds dataframe find all possible ability names
def find_ability_names(df_builds):
    # create pandas series for each gear type's
    # possible options for main abilities
    # ability options for head gear:
    main_1 = df_builds['Main_1'].drop_duplicates()
    # ability options for clothing
    main_2 = df_builds['Main_2'].drop_duplicates()
    # ability options for shoes
    main_3 = df_builds['Main_3'].drop_duplicates()

    # combine to form a series of all possible options (no repeats)
    all_abilities = pd.concat([main_1, main_2, main_3]).drop_duplicates()

    # Convert the series to a dataframe
    # reset the index so we have abilities 0 to 25
    # there should be 26 found in total
    abilities_df = pd.DataFrame(
        all_abilities, columns=['Abilities']).reset_index(drop=True)

    # display(abilities_df)
    # return the dataframe of ability names
    return abilities_df


# function that find all the images of possible abilities
def find_all_ability_images():
    # request to website
    soup = BeautifulSoup(
        make_request(ABILITY_GALLERY_PATH).text, "html.parser"
        )
    # find all images on the page
    images = soup.find_all('img')
    # pause
    time.sleep(1)
    image_urls = []  # empty list to store urls
    # loop through each image on the page
    for img in images:
        # pause
        time.sleep(0.05)
        # call the function to check if the image is for an ability
        # and adds it to the list
        image_urls = find_ability_image(img, image_urls)
    return image_urls


# function to check if the image is of an ability
# if so add to the list or urls
def find_ability_image(img, image_urls):
    src = img.get('src')
    # Check if the 'src' attribute exists and contains 'Ability'
    # We also want to exclude the 'locked' used for when
    # an ability slot is empty
    if src and 'Ability' in src and 'Locked' not in src:
        # add the image URL to the list
        image_urls.append('https:' + src)
    return image_urls


# function to use both the list of images
# and dataframe of ability names
# to create a complete dataframe of ability images
def create_ability_df(abilities_df, image_urls):
    # first order the abilities alphabetically
    abilities_df = abilities_df.sort_values(by='Abilities')
    # reset the index again
    abilities_df.reset_index(drop=True, inplace=True)
    # --- Assistance from ChatGPT ---------------------------------------
    image_urls = sorted(image_urls, key=lambda img: img.split('/')[-1])
    # -------------------------------------------------------------------
    # add a new column called Image URL
    # add the urls here
    abilities_df['Image URL'] = image_urls
    # return the complete dataframe
    return abilities_df

# %%
extract_ability_images(df_builds)
# Out:
# Creating a dataframe of ability images...
# Done! 26/26 images found
#             Abilities                                          Image URL
# 0     Ability Doubler  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 1            Comeback  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 2         Drop Roller  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 3               Haunt  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 4     Ink Recovery Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 5   Ink Resistance Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 6    Ink Saver (Main)  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 7     Ink Saver (Sub)  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 8    Intensify Action  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 9   Last-Ditch Effort  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 10        Ninja Squid  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 11    Object Shredder  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 12     Opening Gambit  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 13      Quick Respawn  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 14   Quick Super Jump  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 15   Respawn Punisher  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 16       Run Speed Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 17  Special Charge Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 18   Special Power Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 19      Special Saver  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 20       Stealth Jump  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 21       Sub Power Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 22  Sub Resistance Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 23      Swim Speed Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 24           Tenacity  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 25        Thermal Ink  https://cdn.wikimg.net/en/splatoonwiki/images/...

# %%
import pandas as pd
from bs4 import BeautifulSoup
from etl.extract.url_request import make_request
import time

ABILITY_GALLERY_PATH = (
    'https://splatoonwiki.org/wiki/Category:Splatoon_3_ability_icons'
    )


# function extract ability chunk images from inkipedia
# returns a dataframe for abilities and urls
def extract_ability_images(df_builds):
    print("\nCreating a dataframe of ability images...")
    # first call a function that returns all possible abilities
    # as a dataframe
    abilities_df = find_ability_names(df_builds)
    # find all image urls for ability images
    image_urls = find_all_ability_images()
    # add these to the original ability dataframe
    abilities_df = create_ability_df(abilities_df, image_urls)
    print("Done! " + str(abilities_df.shape[0]) + "/26 images found")
    # check the length
    if abilities_df.shape[0] == 26:
        # return the completed abilities dataframe
        return abilities_df
    else:
        raise Exception(
            "Error: Abilities data frame only has " +
            str(abilities_df.shape[0]) +
            " abilities, some are missing"
        )


# function that using the builds dataframe find all possible ability names
def find_ability_names(df_builds):
    # create pandas series for each gear type's
    # possible options for main abilities
    # ability options for head gear:
    main_1 = df_builds['Main_1'].drop_duplicates()
    # ability options for clothing
    main_2 = df_builds['Main_2'].drop_duplicates()
    # ability options for shoes
    main_3 = df_builds['Main_3'].drop_duplicates()

    # combine to form a series of all possible options (no repeats)
    all_abilities = pd.concat([main_1, main_2, main_3]).drop_duplicates()

    # Convert the series to a dataframe
    # reset the index so we have abilities 0 to 25
    # there should be 26 found in total
    abilities_df = pd.DataFrame(
        all_abilities, columns=['Abilities']).reset_index(drop=True)

    # display(abilities_df)
    # return the dataframe of ability names
    return abilities_df


# function that find all the images of possible abilities
def find_all_ability_images():
    # request to website
    soup = BeautifulSoup(
        make_request(ABILITY_GALLERY_PATH).text, "html.parser"
        )
    # find all images on the page
    images = soup.find_all('img')
    # pause
    time.sleep(1)
    image_urls = []  # empty list to store urls
    # loop through each image on the page
    for img in images:
        # pause
        time.sleep(0.05)
        # call the function to check if the image is for an ability
        # and adds it to the list
        image_urls = find_ability_image(img, image_urls)
    return image_urls


# function to check if the image is of an ability
# if so add to the list or urls
def find_ability_image(img, image_urls):
    print("hello")
    print(img)
    src = img.get('src')
    print(src)
    # Check if the 'src' attribute exists and contains 'Ability'
    # We also want to exclude the 'locked' used for when
    # an ability slot is empty
    if src and 'Ability' in src and 'Locked' not in src:
        # add the image URL to the list
        image_urls.append('https:' + src)
    return image_urls


# function to use both the list of images
# and dataframe of ability names
# to create a complete dataframe of ability images
def create_ability_df(abilities_df, image_urls):
    # first order the abilities alphabetically
    abilities_df = abilities_df.sort_values(by='Abilities')
    # reset the index again
    abilities_df.reset_index(drop=True, inplace=True)
    # --- Assistance from ChatGPT ---------------------------------------
    image_urls = sorted(image_urls, key=lambda img: img.split('/')[-1])
    # -------------------------------------------------------------------
    # add a new column called Image URL
    # add the urls here
    abilities_df['Image URL'] = image_urls
    # return the complete dataframe
    return abilities_df

# %% [markdown]
# <img height="32" src="//cdn.wikimg.net/en/splatoonwiki/images/7/7f/Site-wordmark.svg" width="152"/>
#
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/0/09/S3_Ability_Comeback.png/120px-S3_Ability_Comeback.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/0/09/S3_Ability_Comeback.png 1.5x" width="120"/>

# %%
extract_ability_images(df_builds)
# Out:
# Creating a dataframe of ability images...
# hello
# <img height="32" src="//cdn.wikimg.net/en/splatoonwiki/images/7/7f/Site-wordmark.svg" width="152"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/9/9d/S3_Ability_Ability_Doubler.png/120px-S3_Ability_Ability_Doubler.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/9/9d/S3_Ability_Ability_Doubler.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/0/09/S3_Ability_Comeback.png/120px-S3_Ability_Comeback.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/0/09/S3_Ability_Comeback.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/0/05/S3_Ability_Drop_Roller.png/120px-S3_Ability_Drop_Roller.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/0/05/S3_Ability_Drop_Roller.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/2/2b/S3_Ability_Haunt.png/120px-S3_Ability_Haunt.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/2/2b/S3_Ability_Haunt.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/3/3c/S3_Ability_Ink_Recovery_Up.png/120px-S3_Ability_Ink_Recovery_Up.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/3/3c/S3_Ability_Ink_Recovery_Up.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/6/6d/S3_Ability_Ink_Resistance_Up.png/120px-S3_Ability_Ink_Resistance_Up.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/6/6d/S3_Ability_Ink_Resistance_Up.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/3/35/S3_Ability_Ink_Saver_%28Main%29.png/120px-S3_Ability_Ink_Saver_%28Main%29.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/3/35/S3_Ability_Ink_Saver_%28Main%29.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/a/a2/S3_Ability_Ink_Saver_%28Sub%29.png/120px-S3_Ability_Ink_Saver_%28Sub%29.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/a/a2/S3_Ability_Ink_Saver_%28Sub%29.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/5/52/S3_Ability_Intensify_Action.png/120px-S3_Ability_Intensify_Action.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/5/52/S3_Ability_Intensify_Action.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/c/c7/S3_Ability_Last-Ditch_Effort.png/120px-S3_Ability_Last-Ditch_Effort.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/c/c7/S3_Ability_Last-Ditch_Effort.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/8/80/S3_Ability_Locked.png/120px-S3_Ability_Locked.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/8/80/S3_Ability_Locked.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/7/78/S3_Ability_Ninja_Squid.png/120px-S3_Ability_Ninja_Squid.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/7/78/S3_Ability_Ninja_Squid.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/f/f0/S3_Ability_Object_Shredder.png/120px-S3_Ability_Object_Shredder.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/f/f0/S3_Ability_Object_Shredder.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/b/b3/S3_Ability_Opening_Gambit.png/120px-S3_Ability_Opening_Gambit.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/b/b3/S3_Ability_Opening_Gambit.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/9/98/S3_Ability_Quick_Respawn.png/120px-S3_Ability_Quick_Respawn.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/9/98/S3_Ability_Quick_Respawn.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/d/d5/S3_Ability_Quick_Super_Jump.png/120px-S3_Ability_Quick_Super_Jump.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/d/d5/S3_Ability_Quick_Super_Jump.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/6/68/S3_Ability_Respawn_Punisher.png/120px-S3_Ability_Respawn_Punisher.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/6/68/S3_Ability_Respawn_Punisher.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/a/a0/S3_Ability_Run_Speed_Up.png/120px-S3_Ability_Run_Speed_Up.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/a/a0/S3_Ability_Run_Speed_Up.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/9/97/S3_Ability_Special_Charge_Up.png/120px-S3_Ability_Special_Charge_Up.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/9/97/S3_Ability_Special_Charge_Up.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/e/ea/S3_Ability_Special_Power_Up.png/120px-S3_Ability_Special_Power_Up.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/e/ea/S3_Ability_Special_Power_Up.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/e/e0/S3_Ability_Special_Saver.png/120px-S3_Ability_Special_Saver.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/e/e0/S3_Ability_Special_Saver.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/5/5a/S3_Ability_Stealth_Jump.png/120px-S3_Ability_Stealth_Jump.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/5/5a/S3_Ability_Stealth_Jump.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/6/61/S3_Ability_Sub_Power_Up.png/120px-S3_Ability_Sub_Power_Up.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/6/61/S3_Ability_Sub_Power_Up.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/d/d4/S3_Ability_Sub_Resistance_Up.png/120px-S3_Ability_Sub_Resistance_Up.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/d/d4/S3_Ability_Sub_Resistance_Up.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/6/61/S3_Ability_Swim_Speed_Up.png/120px-S3_Ability_Swim_Speed_Up.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/6/61/S3_Ability_Swim_Speed_Up.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/6/60/S3_Ability_Tenacity.png/120px-S3_Ability_Tenacity.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/6/60/S3_Ability_Tenacity.png 1.5x" width="120"/>
# hello
# <img alt="" decoding="async" height="120" loading="lazy" src="//cdn.wikimg.net/en/splatoonwiki/images/thumb/3/33/S3_Ability_Thermal_Ink.png/120px-S3_Ability_Thermal_Ink.png" srcset="//cdn.wikimg.net/en/splatoonwiki/images/3/33/S3_Ability_Thermal_Ink.png 1.5x" width="120"/>
# hello
# <img src="//cdn.wikimg.net/en/splatoonwiki/images/e/ea/Site-wiki.svg"/>
# hello
# <img alt="Creative Commons Attribution-ShareAlike 4.0" height="31" loading="lazy" src="/w/resources/assets/licenses/cc-by-sa.png" width="88"/>
# hello
# <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/w/resources/assets/poweredby_mediawiki_88x31.png" srcset="/w/resources/assets/poweredby_mediawiki_132x47.png 1.5x, /w/resources/assets/poweredby_mediawiki_176x62.png 2x" width="88"/>
# hello
# <img alt="Powered by StrategyWiki" height="31" loading="lazy" src="https://cdn.wikimg.net/en/strategywiki/images/e/e5/Powered_by_StrategyWiki_Button.png" srcset="https://cdn.wikimg.net/en/strategywiki/images/f/f0/Powered_by_StrategyWiki_Button2x.png 2x" width="88"/>
# Done! 26/26 images found
#             Abilities                                          Image URL
# 0     Ability Doubler  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 1            Comeback  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 2         Drop Roller  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 3               Haunt  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 4     Ink Recovery Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 5   Ink Resistance Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 6    Ink Saver (Main)  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 7     Ink Saver (Sub)  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 8    Intensify Action  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 9   Last-Ditch Effort  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 10        Ninja Squid  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 11    Object Shredder  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 12     Opening Gambit  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 13      Quick Respawn  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 14   Quick Super Jump  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 15   Respawn Punisher  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 16       Run Speed Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 17  Special Charge Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 18   Special Power Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 19      Special Saver  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 20       Stealth Jump  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 21       Sub Power Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 22  Sub Resistance Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 23      Swim Speed Up  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 24           Tenacity  https://cdn.wikimg.net/en/splatoonwiki/images/...
# 25        Thermal Ink  https://cdn.wikimg.net/en/splatoonwiki/images/...
